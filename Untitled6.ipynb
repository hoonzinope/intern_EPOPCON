# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
engine = create_engine("mysql+pymysql://eums:eums00!q@192.168.0.50:3306/eums?charset=utf8mb4", encoding = 'utf8',pool_size=20,pool_recycle=3600,connect_args={'connect_timeout':1000000} )

# %%
query = """
select *
from COMPANY_REG_ADDR_TEST
limit 100000
"""

# %%
test = pd.read_sql_query(query, engine)
test.head()
# Out:
#    ID    CO_NAME_R                   ADDR     LATITUDE    LONGITUDE  \
# 0   1       M바로크가구     대전광역시 서구 관저동 610-1  36.30151958  127.3262864
# 1   2       샵스크린골프      강원도 원주시 명륜동 286-1   37.3366487  127.9506159
# 2   3     IN2인투미용실  인천광역시 부평구 갈산1동 169-25  37.51796617  126.7262206
# 3   4  K금탑공인중개사사무소  울산광역시 남구 신정2동 1644-30   35.5357482  129.3010192
# 4   5    IVY아이비페이셜       광주광역시 북구 신용동 717    35.206511  126.8619063
#
#   REP_PHONE_NUM MSISDN
# 0    0425423777   None
# 1    0337434343   None
# 2    0325036336   None
# 3    0522614959   None
# 4    0625730035   None

# %%
test[1000:2000]
# Out:
#         ID            CO_NAME_R                       ADDR     LATITUDE  \
# 1000  1018  재단기독교대한감리회교회학교전국연합회          서울특별시 종로구 세종로 211   37.5696746
# 1001  1019         재단글로벌녹색성장연구소           서울특별시 중구 정동 15-5   37.5678816
# 1002  1020           재단금호직업전문학교        전라남도 목포시 산정동 74-219  34.79865181
# 1003  1021       재단기독교대한감리회김포교회            경기도 김포시 북변동 산51   37.6230173
# 1004  1022              재단글로벌에듀      인천광역시 부평구 부평5동 124-18   37.5004044
# 1005  1023       재단기독교대한감리회광장교회         강원도 춘천시 효자2동 105-4   37.8754908
# 1006  1024       재단기독교감리회고강제일교회     경기도 부천시 오정구 고강1동 458-1   37.5248073
# 1007  1025             재단금남문화재단          전라남도 나주시 중앙동 95-5  35.03313574
# 1008  1026         재단그리스도의교육수녀원          서울특별시 종로구 평창동 393   37.6119864
# 1009  1027       재단기독교대한감리회대성교회         대전광역시 동구 대성동 169-2   36.2951734
# 1010  1028       재단기독교대한감리회성민교회          강원도 동해시 발한동 242-3   37.5486602
# 1011  1029       재단기독교대한감리회신남교회      경기도 화성시 남양읍 신남리 산51-2   37.1865354
# ...

# %%
test.to_pickle('company_test.pkl')

# %%
path = 'C:\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('https://www.whox2.com/view/main.jsp')

# %%
input = driver.find_element_by_id("search")

# %%
input.clear()
input.send_keys('0425423777	')

# %%
button = driver.find_element_by_class_name('search_input').find_element_by_tag_name('button')

# %%
button.click()

# %%
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')
text = soup.find('dl').get_text().split('\n')

# %%
text
# Out:
# ['',
#  '',
#  '',
#  '042-542-3777',
#  '',
#  '\t\t',
#  '',
#  '',
#  '',
#  '상호정보',
#  '레이디가구',
#  '대전광역시 서구 관저동',
#  '가구',
#  '',
#  '',
#  '',
#  '']

# %%
while True:
    try:
        text.remove("")
    except ValueError:
        break
text
# Out:
# ['042-542-3777', '\t\t', '상호정보', '레이디가구', '대전광역시 서구 관저동', '가구']

# %%
info = []
info.append(text[0])
info.append(text[3])
info.append(text[4])
info.append(text[5])
info
# Out:
# ['042-542-3777', '레이디가구', '대전광역시 서구 관저동', '가구']

# %%
result = []
for phone_num in test.REP_PHONE_NUM:
    driver.get('https://www.whox2.com/view/main.jsp')
    driver.implicitly_wait(3)
    input = driver.find_element_by_id("search")
    driver.implicitly_wait(3)
    input.clear()
    driver.implicitly_wait(3)
    input.send_keys(phone_num)
    driver.implicitly_wait(3)
    button = driver.find_element_by_class_name('search_input').find_element_by_tag_name('button')
    button.click()
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.find('dl').get_text().split('\n')
    while True:
        try:
            text.remove("")
        except ValueError:
            break
    print(text)
    for t in text:
        if '검색결과가 없습니다.' in t:
            text = [phone_num,'','','','','','']
    info = []
    info.append(text[0])
    info.append(text[3])
    if len(text) < 5:
        info.append('')
        info.append('')
    else:
        info.append(text[4])
        info.append(text[5])
    result.append(info)
result = pd.DataFrame(result, columns = ['phone_num', 'co_name_rr','addr', 'cate'])
result
# Out:
# ['042-542-3777', '\t\t', '상호정보', '레이디가구', '대전광역시 서구 관저동', '가구']
# ['033-743-4343', '\t\t', '상호정보', '#샵스크린골프', '강원도 원주시 명륜동', '스크린골프장']
# ['032-503-6336', '\t\t', '상호정보', '(IN2)인투미용실', '인천광역시 부평구 갈산1동', '미용실']
# ['052-261-4959', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-573-0035', '\t\t', '상호정보', '(IVY)아이비페이셜', '광주광역시 북구 신용동', '피부,체형관리']
# ['055-338-3342', '\t\t', '상호정보', '강성옥공인중개사사무소', '경상남도 김해시 관동동', '부동산']
# ['02-6002-6787', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-286-6426', '\t\t', '상호정보', '#(샵)피어싱레드캣츠', '경상남도 창원시 성산구 상남동', '액세서리판매']
# ['052-265-8924', '\t\t', '상호정보', '(K)금탑공인중개사사무소(합동)', '울산광역시 남구 신정2동', '부동산']
# ['053-818-5002', '\t\t', '상호정보', '(NEW)원룸마을공인중개사사무소', '경상북도 경산시 조영동', '부동산']
# ['053-793-0052', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-975-2000', '\t\t', '상호정보', '(광산)브라이튼어학원', '광주광역시 광산구 도천동', '외국어학원']
# ['02-2299-4355', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ...

# %%
result = pd.DataFrame(result, columns = ['phone_num', 'co_name_rr','addr', 'cate'])
result
# Out:
#          phone_num                 co_name_rr                  addr  \
# 0     042-542-3777                      레이디가구          대전광역시 서구 관저동
# 1     033-743-4343                    #샵스크린골프           강원도 원주시 명륜동
# 2     032-503-6336                 (IN2)인투미용실        인천광역시 부평구 갈산1동
# 3       0522614959
# 4     062-573-0035                (IVY)아이비페이셜          광주광역시 북구 신용동
# 5     055-338-3342                강성옥공인중개사사무소          경상남도 김해시 관동동
# 6       0260026787
# 7     055-286-6426                #(샵)피어싱레드캣츠      경상남도 창원시 성산구 상남동
# 8     052-265-8924          (K)금탑공인중개사사무소(합동)         울산광역시 남구 신정2동
# 9     053-818-5002          (NEW)원룸마을공인중개사사무소          경상북도 경산시 조영동
# 10      0537930052
# 11    062-975-2000                (광산)브라이튼어학원         광주광역시 광산구 도천동
# 12      0222994355
# 13    052-264-9623                      일루아호텔  울산광역시 울주군 상북면 등억알프스리
# 14    032-772-6895                    (구)서울떡집          인천광역시 중구 신포동
# 15    061-763-9789             (광양매화주공관리소)이성규      전라남도 광양시 광양읍 구산리
# ...

# %%
test[test.index == 1251]
# Out:
#         ID        CO_NAME_R                   ADDR   LATITUDE    LONGITUDE  \
# 1251  1274  재단인천교구천주교회부천교육관  경기도 부천시 원미구 상2동 588-6  37.494582  126.7452104
#
#      REP_PHONE_NUM MSISDN
# 1251    0323269882   None
