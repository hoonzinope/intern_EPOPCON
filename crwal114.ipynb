# %%
import pandas as pd

# %%
hana = pd.read_pickle('HANA_JJW_NOMAP.pk')

# %%
len(hana)
# Out:
# 463917

# %%
len(hana.TEL.unique())
# Out:
# 334970

# %%
hana.head()
# Out:
#       ID    HANA_ID STATUS BUSINESS_NUM      MER_NAME          TEL  MER_TYPE3  \
# 116  117  700005704      1   2420900382  노가리비어(강서1호점)   0430000000       2601
# 287  288  700015396      1   6280500462     코그커피(COG)      0000000       2305
# 409  410  700019187      1   2221802942     보떼(목포연산점)   0610000000       1501
# 410  411  700019333      1   2243100181         신도DNS                    3203
# 427  428  700020316      1   4163400160        올리비아핸즈  00000000000       5302
#
#     MER_TYPE3_NAME            X            Y                 LAT  \
# 116             주점     993685.9  1847361.806   36.62410560243727
# 287           서양음식  1099658.032  1763591.197  35.863815412233215
# 409            화장품   897690.038  1646883.839    34.8114027786893
# 410        사무용OA기기   960323.914  1950241.319   37.55065848865481
# 427           기타잡화  1039783.617  1927980.339  37.350005305816424
#
#                     LON       GEOHASH MER_NAME_SYN
# 116   127.4293820758067  wyd87epnzu45         None
# ...

# %%
head = hana.head()

# %%
head['valid'] = 0
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
head
# Out:
#       ID    HANA_ID STATUS BUSINESS_NUM      MER_NAME          TEL  MER_TYPE3  \
# 116  117  700005704      1   2420900382  노가리비어(강서1호점)   0430000000       2601
# 287  288  700015396      1   6280500462     코그커피(COG)      0000000       2305
# 409  410  700019187      1   2221802942     보떼(목포연산점)   0610000000       1501
# 410  411  700019333      1   2243100181         신도DNS                    3203
# 427  428  700020316      1   4163400160        올리비아핸즈  00000000000       5302
#
#     MER_TYPE3_NAME            X            Y                 LAT  \
# 116             주점     993685.9  1847361.806   36.62410560243727
# 287           서양음식  1099658.032  1763591.197  35.863815412233215
# 409            화장품   897690.038  1646883.839    34.8114027786893
# 410        사무용OA기기   960323.914  1950241.319   37.55065848865481
# 427           기타잡화  1039783.617  1927980.339  37.350005305816424
#
#                     LON       GEOHASH MER_NAME_SYN  valid
# ...

# %%
hana['valid'] = 0

# %%
hana.head()
# Out:
#       ID    HANA_ID STATUS BUSINESS_NUM      MER_NAME          TEL  MER_TYPE3  \
# 116  117  700005704      1   2420900382  노가리비어(강서1호점)   0430000000       2601
# 287  288  700015396      1   6280500462     코그커피(COG)      0000000       2305
# 409  410  700019187      1   2221802942     보떼(목포연산점)   0610000000       1501
# 410  411  700019333      1   2243100181         신도DNS                    3203
# 427  428  700020316      1   4163400160        올리비아핸즈  00000000000       5302
#
#     MER_TYPE3_NAME            X            Y                 LAT  \
# 116             주점     993685.9  1847361.806   36.62410560243727
# 287           서양음식  1099658.032  1763591.197  35.863815412233215
# 409            화장품   897690.038  1646883.839    34.8114027786893
# 410        사무용OA기기   960323.914  1950241.319   37.55065848865481
# 427           기타잡화  1039783.617  1927980.339  37.350005305816424
#
#                     LON       GEOHASH MER_NAME_SYN  valid
# ...

# %%
hana = hana.reset_index()

# %%
hana.TEL.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d4cb75ff784> in <module>()
# ----> 1 hana.TEL.unique()
#
# NameError: name 'hana' is not defined

# %%
len(hana)
# Out:
# 463917

# %%
path = 'C:\chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
def naver_search(phone_num):
    driver.get('https://map.naver.com/')
    driver.implicitly_wait(3)
    input = driver.find_element_by_id('search-input')
    input.clear()
    input.send_keys(phone_num)
    input.send_keys(keys.Keys.ENTER)
    driver.implicitly_wait(3)
    text = driver.find_element_by_xpath('//*[@id="panel"]/div[2]/div[1]/div[2]/div[2]').text
    text = text.split('\n')
    for t in text:
        if '검색결과가 없습니다' in t:
            return -1
    return 1

# %%
text
# Out:
# ['검색결과가 없습니다.']

# %%
# %%time
hana = pd.read_pickle('HANA_JJW_NOMAP.pk')
hana = hana.reset_index()
hana['valid'] = 0
count = 0
result = 0
print(len(hana.TEL.unique()))
for phone_num in hana.TEL.unique():
    count += 1    
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(1)
    
    html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
    data = urlopen(html, timeout = 1000)
    resp = json.loads(data.read())
    
    try:
        r = pd.DataFrame(resp)
        r = pd.DataFrame(r['data'][0])
        if r['results']['totalCount'] == 0:
            text = whowho_search(phone_num)
            if text == -1:
#                 print(phone_num)
                hana[hana.TEL == phone_num] = hana[hana.TEL == phone_num].replace({'valid':0}, -1)
                result += len(hana[hana.TEL == phone_num])
                print(result)
            else:
                hana[hana.TEL == phone_num] = hana[hana.TEL == phone_num].replace({'valid':0}, 1)
        else:
#             r = pd.DataFrame(r['results']['result'])
#             r = pd.DataFrame(r['field'][0])
#             info = []
#             info = r['value']
            print (r['value'][1])
            result += len(hana[hana.TEL == phone_num])
            print(result)
            hana[hana.TEL == phone_num] = hana[hana.TEL == phone_num].replace({'valid':0}, 1)
    except:
        hana[hana.TEL == phone_num] = hana[hana.TEL == phone_num].replace({'valid':0}, -1)
# Out:
# 334970
# 711
# 715
# 765
# 1133
# 2648
# 2674
# 6858
# 8510
# 8583
# 8602
# 9101
# 9131
# 9206
# 10613
# 11610
# 12331
# 12980
# 13097
# 13099
# 13101
# 13701
# 13710
# 13857
# 13860
# 13907
# 13909
# 13925
# 13940
# 13944
# 13945
# 13951
# 13952
# 13953
# 13955
# 13956
# 13957
# 13958
# 13959
# 13960
# 13962
# 13964
# 13966
# 13968
# 13970
# 13972
# 13974
# 13975
# 13983
# 13985
# 13987
# 13989
# 13991
# 13993
# 13995
# 13997
# 13999
# 14005
# 14007
# 14009
# 14011
# 14013
# 14015
# 14017
# 14019
# 14024
# 14028
# 14032
# 14034
# 14036
# 14037
# running... 0518079180 1.0
# 14038
# 14039
# 14041
# 14043
# 14045
# 14047
# 14057
# 14059
# 14061
# 14063
# 14065
# 14067
# 14069
# 14070
# 14072
# 14074
# 14076
# 14078
# 14080
# 14082
# 14088
# 14090
# 14092
# 14094
# 14096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ...

# %%
result
# Out:
# 14038

# %%
hana[0:100]
# Out:
#     index     ID    HANA_ID STATUS BUSINESS_NUM           MER_NAME  \
# 0     116    117  700005704      1   2420900382       노가리비어(강서1호점)
# 1     287    288  700015396      1   6280500462          코그커피(COG)
# 2     409    410  700019187      1   2221802942          보떼(목포연산점)
# 3     410    411  700019333      1   2243100181              신도DNS
# 4     427    428  700020316      1   4163400160             올리비아핸즈
# 5     453    454  700021921      1   4525200118            쥬씨인천구월점
# 6     458    459  700022163      1   1271480626               닉PC방
# 7     759    760  700035415      1   8253100233    아시아마트(ASIAMART)
# 8     830    831  700038991      1   1756700118               모던보이
# 9    1246   1247  700058308      1   1434900193   비노수아브(Vinosuave)
# 10   1257   1258  700058616      1   2063186162             넷도날드pc
# 11   1604   1605  700074874      1   6936700111       쥬씨(서울대녹두거리점)
# 12   1706   1707  700079726      1   5773100033             스토리PC방
# ...

# %%
hana.head()
# Out:
#    index   ID    HANA_ID STATUS BUSINESS_NUM      MER_NAME          TEL  \
# 0    116  117  700005704      1   2420900382  노가리비어(강서1호점)   0430000000
# 1    287  288  700015396      1   6280500462     코그커피(COG)      0000000
# 2    409  410  700019187      1   2221802942     보떼(목포연산점)   0610000000
# 3    410  411  700019333      1   2243100181         신도DNS
# 4    427  428  700020316      1   4163400160        올리비아핸즈  00000000000
#
#    MER_TYPE3 MER_TYPE3_NAME            X            Y                 LAT  \
# 0       2601             주점     993685.9  1847361.806   36.62410560243727
# 1       2305           서양음식  1099658.032  1763591.197  35.863815412233215
# 2       1501            화장품   897690.038  1646883.839    34.8114027786893
# 3       3203        사무용OA기기   960323.914  1950241.319   37.55065848865481
# 4       5302           기타잡화  1039783.617  1927980.339  37.350005305816424
#
#                   LON       GEOHASH MER_NAME_SYN  valid
# ...

# %%
result = pd.DataFrame(result, columns = ['valid'])

# %%
hana_100 = hana.head(100).reset_index()
hana_100[hana_100.MER_NAME == '딥벨리데이션']
# Out:
# Empty DataFrame
# Columns: [index, ID, HANA_ID, STATUS, BUSINESS_NUM, MER_NAME, TEL, MER_TYPE3, MER_TYPE3_NAME, X, Y, LAT, LON, GEOHASH, MER_NAME_SYN]
# Index: []

# %%
# %%time
hana = pd.read_pickle('HANA_JJW_NOMAP.pk')
hana = hana.reset_index()
hana['valid'] = 0
count = 0
num_pair = {}
print(len(hana.TEL.unique()))
for phone_num in hana.TEL:
    count += 1    
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(1)
    try:
        if num_pair[phone_num] != 0:
            continue
    except:
        html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
        data = urlopen(html, timeout = 1000)
        resp = json.loads(data.read())

        try:
            r = pd.DataFrame(resp)
            r = pd.DataFrame(r['data'][0])
            if r['results']['totalCount'] == 0:
                text = whowho_search(phone_num)
                if text == -1:
                    num_pair.update({phone_num:-1})
                    
                else:
                    num_pair.update({phone_num:1})
            else:
    #             r = pd.DataFrame(r['results']['result'])
    #             r = pd.DataFrame(r['field'][0])
    #             info = []
    #             info = r['value']
                print (r['value'][1])
                num_pair.update({phone_num:1})
        except:
            num_pair.update({phone_num:-1})
# Out:
# 334970
# running... 020000000 1.0
# running... 0200000000 2.0
# running... 020000000 3.0
# running... 00000000 4.0
# running... 05500000000 5.0
# running... 020000000 6.0
# running... 0530000000 7.0
# running... 0420000000 8.0
# running... 0310000000 9.0
# running... 0410000000 10.0
# running... 06400000000 11.0
# running... 020000000 12.0
# running... 020000000 13.0
# running... 0310000000 14.0
# running... 020000000 15.0
# running... 0640000000 16.0
# running... 0310000000 17.0
# running... 0330000000 18.0
# running... 020000000 19.0
# running... 020000000 20.0
# running... 0540000000 21.0
# running... 0640000000 22.0
# running... 0310000000 23.0
# running... 0530000000 24.0
# running... 020000000 25.0
# running... 0540000000 26.0
# running... 0640000000 27.0
# running... 020000000 28.0
# running... 020000000 29.0
# running... 020000000 30.0
# running... 0630000000 31.0
# running... 020000000 32.0
# running... 0440000000 33.0
# running... 0550000000 34.0
# ...

# %%
len(num_pair)
# Out:
# 1296

# %%
s = pd.Series(num_pair, name='Valid')

# %%
s.index.name = 'TEL'
s = s.reset_index()
s
# Out:
#                TEL  Valid
# 0                      -1
# 1          0000000     -1
# 2         00000000     -1
# 3        000000000     -1
# 4       0000000000     -1
# 5      00000000000     -1
# 6     000000000000     -1
# 7     000016000125     -1
# 8       0016703357     -1
# 9       0018771221     -1
# 10     01020110239     -1
# 11     01020217288     -1
# 12     01020236999     -1
# 13     01020339705     -1
# 14     01020653337     -1
# 15     01020812661     -1
# 16     01020852345     -1
# 17     01021902295     -1
# 18     01022047019     -1
# 19     01022058900     -1
# 20     01022598000     -1
# 21     01022756364     -1
# 22     01023664756     -1
# 23     01023693596     -1
# 24     01023918951     -1
# 25     01024077706     -1
# 26     01024464217     -1
# 27     01024703900     -1
# 28     01025178690     -1
# 29     01025280745     -1
# ...            ...    ...
# 1266   07087686031     -1
# 1267   07087826859     -1
# 1268   07087893912     -1
# ...

# %%
r = pd.merge(hana, s, on = 'TEL')

# %%
len(r[r.Valid == -1])
# Out:
# 27967

# %%
r[r.Valid == None]
# Out:
# Empty DataFrame
# Columns: [index, ID, HANA_ID, STATUS, BUSINESS_NUM, MER_NAME, TEL, MER_TYPE3, MER_TYPE3_NAME, X, Y, LAT, LON, GEOHASH, MER_NAME_SYN, valid, Valid]
# Index: []

# %%
r = hana.join(s.set_index('TEL'), on='TEL')
r
# Out:
#           index       ID      HANA_ID STATUS BUSINESS_NUM          MER_NAME  \
# 0           116      117    700005704      1   2420900382      노가리비어(강서1호점)
# 1           287      288    700015396      1   6280500462         코그커피(COG)
# 2           409      410    700019187      1   2221802942         보떼(목포연산점)
# 3           410      411    700019333      1   2243100181             신도DNS
# 4           427      428    700020316      1   4163400160            올리비아핸즈
# 5           453      454    700021921      1   4525200118           쥬씨인천구월점
# 6           458      459    700022163      1   1271480626              닉PC방
# 7           759      760    700035415      1   8253100233   아시아마트(ASIAMART)
# 8           830      831    700038991      1   1756700118              모던보이
# 9          1246     1247    700058308      1   1434900193  비노수아브(Vinosuave)
# 10         1257     1258    700058616      1   2063186162            넷도날드pc
# ...

# %%
r1 = r[r.Valid != -1]
r2 = r1[r1.Valid != 1]
r2
# Out:
#           index       ID      HANA_ID STATUS BUSINESS_NUM  \
# 34736      6103     6104    700327978      1   1048136565
# 34737      6118     6119    700328557      1   7132100270
# 34738      6121     6122    700329092      1   5680100556
# 34739      6126     6127    700329288      1   4852500257
# 34740      6130     6131    700329669      1   5298800116
# 34741      6131     6132    700329677      1   7255000161
# 34742      6132     6133    700329693      1   6799400182
# 34743      6133     6134    700329756      1   5648100110
# 34744      6136     6137    700329847      1   5680500383
# 34745      6141     6142    700330061      1   3154400100
# 34746      6145     6146    700330216      1   6429000294
# 34747      6147     6148    700330241      1   3744500106
# 34748      6152     6153    700330419      1   8951200401
# 34749      6167     6168    700331310      1   6654000123
# 34751      6177     6178    700331651      1   6601300229
# ...

# %%
driver = webdriver.Chrome(path)
count = 0
for phone_num in r2.TEL:
    count += 1    
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(1)
    try:
        if num_pair[phone_num] != 0:
            continue
    except:
        html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
        data = urlopen(html, timeout = 1000)
        resp = json.loads(data.read())

        try:
            r = pd.DataFrame(resp)
            r = pd.DataFrame(r['data'][0])
            if r['results']['totalCount'] == 0:
                text = whowho_search(phone_num)
                if text == -1:
                    num_pair.update({phone_num:-1})
                    
                else:
                    num_pair.update({phone_num:1})
            else:
    #             r = pd.DataFrame(r['results']['result'])
    #             r = pd.DataFrame(r['field'][0])
    #             info = []
    #             info = r['value']
                print (r['value'][1])
                num_pair.update({phone_num:1})
        except:
            num_pair.update({phone_num:-1})
# Out:
# running... 01033114011 1.0
# running... 01052209877 2.0
# running... 0215991530 3.0
# running... 01020789969 4.0
# running... 0222148244 5.0
# running... 0318098555 6.0
# running... 0539816558 7.0
# running... 0555863375 8.0
# running... 0419366249 9.0
# running... 0532433535 10.0
# running... 024719749 11.0
# running... 029883541 12.0
# running... 0428633666 13.0
# running... 0537660080 14.0
# running... 01077579381 15.0
# running... 029778788 16.0
# running... 01093845449 17.0
# running... 01073559984 18.0
# running... 0317083354 19.0
# running... 0319489513 20.0
# running... 07051410825 21.0
# running... 0515521993 22.0
# running... 01026748182 23.0
# running... 01067650245 24.0
# running... 07077520015 25.0
# running... 0635345054 26.0
# running... 07044509969 27.0
# running... 07041530022 28.0
# running... 07082830157 29.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
len(num_pair)
# Out:
# 4206

# %%
options = webdriver.ChromeOptions()
#options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

# %%
s = pd.Series(num_pair, name='Valid')
s.index.name = 'TEL'
s = s.reset_index()
r = hana.join(s.set_index('TEL'), on='TEL')
r1 = r[r.Valid != -1]
r2 = r1[r1.Valid != 1]
print(len(r2))
driver = webdriver.Chrome(path, chrome_options = options)
count = 0
for phone_num in r2.TEL:
    count += 1    
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(1)
    try:
        if num_pair[phone_num] != 0:
            continue
    except:
        html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
        data = urlopen(html, timeout = 1000)
        resp = json.loads(data.read())

        try:
            r = pd.DataFrame(resp)
            r = pd.DataFrame(r['data'][0])
            if r['results']['totalCount'] == 0:
                text = whowho_search(phone_num)
                if text == -1:
                    num_pair.update({phone_num:-1})
                    
                else:
                    num_pair.update({phone_num:1})
            else:
    #             r = pd.DataFrame(r['results']['result'])
    #             r = pd.DataFrame(r['field'][0])
    #             info = []
    #             info = r['value']
                print (r['value'][1])
                num_pair.update({phone_num:1})
        except:
            num_pair.update({phone_num:-1})
# Out:
# 418658
# running... 0313839036 1.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-4e932ec5b18d> in <module>()
#      15     try:
# ---> 16         if num_pair[phone_num] != 0:
#      17             continue
#
# KeyError: '0629438113'
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# ...

# %%
r1 = r[r.Valid != -1]
r2 = r1[r1.Valid != 1]
r2
# Out:
# Empty DataFrame
# Columns: [index, ID, HANA_ID, STATUS, BUSINESS_NUM, MER_NAME, TEL, MER_TYPE3, MER_TYPE3_NAME, X, Y, LAT, LON, GEOHASH, MER_NAME_SYN, valid, Valid]
# Index: []

# %%
s = pd.Series(num_pair, name='Valid')
print(s)
s.index.name = 'TEL'
s = s.reset_index()
s
# Out:
#                -1
# 0000000        -1
# 00000000       -1
# 000000000      -1
# 0000000000     -1
# 00000000000    -1
# 000000000000   -1
# 000015223589   -1
# 000016000125   -1
# 000016441860   -1
# 000016443366   -1
# 00015667440    -1
# 00015998826    -1
# 0015223630     -1
# 0015227585     -1
# 0016703357     -1
# 0018771221     -1
# 01020110239    -1
# 01020217288    -1
# 01020236999    -1
# 01020258000    -1
# 01020276142    -1
# 01020339705    -1
# 01020348978    -1
# 01020437748    -1
# 01020447548    -1
# 01020531551    -1
# 01020570600    -1
# 01020608610    -1
# 01020636899    -1
#                ..
# 07089487234    -1
# 07089515800    -1
# 07089591238    -1
# 07089598860    -1
# 07089701012    -1
# 07089770916    -1
# 07089807512    -1
# 07089919159    -1
# 07089927781    -1
# 0709000887     -1
# 07090747979    -1
# 07091141804    -1
# 07091483841    -1
# 07094110556    -1
# 07094561468    -1
# 07094705605    -1
# 07097431633    -1
# 07098166004    -1
# 07099418377    -1
# ...

# %%
r = pd.merge(hana, s, on = 'TEL')
len(r)
# Out:
# 44272

# %%
num_pair
# Out:
# {'0430000000': -1,
#  '0000000': -1,
#  '0610000000': 1,
#  '': -1,
#  '00000000000': -1,
#  '0310000000': 1,
#  '03100000000': -1,
#  '0530000000': -1,
#  '000000000000': -1,
#  '020000000': -1,
#  '0200000000': -1,
#  '0000000000': -1,
#  '000000000': -1,
#  '0330000000': 1,
#  '0640000000': -1,
#  '06400000000': -1,
#  '05300000000': -1,
#  '0510000000': -1,
#  '0320000000': -1,
#  '05500000000': 1,
#  '0550000000': 1,
#  '0540000000': 1,
#  '05400000000': 1,
#  '0520000000': 1,
#  '0420000000': 1,
#  '03200000000': 1,
#  '0630000000': -1,
#  '0410000000': -1,
#  '06300000000': -1,
#  '00000000': -1,
#  '05000000000': -1,
#  '07000000000': -1,
#  '05200000000': -1,
#  '0620000000': 1,
#  '04100000000': 1,
#  '05100000000': 1,
#  '0440000000': -1,
#  '02000000000': -1,
#  '04200000000': -1,
#  '04300000000': 1,
#  '0680000000': -1,
#  '03300000000': -1,
#  '04400000000': -1,
#  '06200000000': 1,
#  '0700000000': 1,
#  '07010000000': -1,
#  '06100000000': 1,
#  '0300000000': 1,
# ...

# %%
s = pd.Series(num_pair, name='Valid')
s.index.name = 'TEL'
s = s.reset_index()
s.head()
# Out:
#           TEL  Valid
# 0                 -1
# 1     0000000     -1
# 2    00000000     -1
# 3   000000000     -1
# 4  0000000000     -1

# %%
s.to_pickle('phone_num_pair.pkl')

# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium
import json
from urllib.request import urlopen
import urllib

# %%
import random

# %%
hana = pd.read_pickle('HANA_JJW_NOMAP.pk')

# %%
num_pair = pd.read_pickle('phone_num_pair_total.pkl').to_dict('split')
num_pair = dict(num_pair['data'])
# num_pair = pd.read_pickle('phone_num_pair2.pkl')
# num_pair

# %%
while len(num_pair) != len(hana.TEL.unique()):
    try:
        s = pd.Series(num_pair, name='Valid')
        s.index.name = 'TEL'
        s = s.reset_index()
        r = hana.join(s.set_index('TEL'), on='TEL')
        r1 = r[r.Valid != -1]
        r2 = r1[r1.Valid != 1]
        print(len(r2))
        # driver = webdriver.Chrome(path, chrome_options = options)
        count = 0
        for phone_num in r2.TEL:
            count += 1    
            if count % 1000 == 0:
                print('running...', phone_num, count / 100)
                time.sleep(random.randrange(1,7))
            try:
                if num_pair[phone_num] != 0:
                    continue
            except:
                html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
                data = urlopen(html, timeout = 1000)
                resp = json.loads(data.read())

                try:
                    r = pd.DataFrame(resp)
                    r = pd.DataFrame(r['data'][0])
                    if r['results']['totalCount'] == 0:
                        num_pair.update({phone_num:-1})
                    else:
                        print (r['value'][1])
                        num_pair.update({phone_num:1})
                except:
                    num_pair.update({phone_num:-1})
    except:
        print('exception occured!')
        f = open('num.txt','a')
        f.write(str(len(r2))+'\n')
        f.close()
        s = pd.Series(num_pair, name='Valid')
        s.index.name = 'TEL'
        s = s.reset_index()
        s.to_pickle('phone_num_pair_total.pkl')
        continue
# Out:
# 6657
# running... 01050214013 10.0
# exception occured!
# 5224
# exception occured!
# 5010
# running... 01084025335 10.0
# exception occured!
# 3783
# running... 0427668877 10.0
# running... 01079418689 20.0
# running... 0432343422 30.0

# %%
463917 - 417236 - 395120 - 394791 - 392119 - 369093 - 366704 - 352745 - 345004 - 344671 - 342366 - 312734 - 310806 - 298713 - 288762 - 288231 - 285648 - 279923 - 263281 - 263023

# %%
s.to_pickle('phone_num_pair2.pkl')

# %%
len(num_pair)
# Out:
# 334970

# %%
s = pd.Series(num_pair, name='Valid')
s.index.name = 'TEL'
s = s.reset_index()
s.to_pickle('phone_num_pair_total.pkl')

# %%
r = hana.join(s.set_index('TEL'), on='TEL')
r.head()
# Out:
#       ID    HANA_ID STATUS BUSINESS_NUM      MER_NAME          TEL  MER_TYPE3  \
# 116  117  700005704      1   2420900382  노가리비어(강서1호점)   0430000000       2601
# 287  288  700015396      1   6280500462     코그커피(COG)      0000000       2305
# 409  410  700019187      1   2221802942     보떼(목포연산점)   0610000000       1501
# 410  411  700019333      1   2243100181         신도DNS                    3203
# 427  428  700020316      1   4163400160        올리비아핸즈  00000000000       5302
#
#     MER_TYPE3_NAME            X            Y                 LAT  \
# 116             주점     993685.9  1847361.806   36.62410560243727
# 287           서양음식  1099658.032  1763591.197  35.863815412233215
# 409            화장품   897690.038  1646883.839    34.8114027786893
# 410        사무용OA기기   960323.914  1950241.319   37.55065848865481
# 427           기타잡화  1039783.617  1927980.339  37.350005305816424
#
#                     LON       GEOHASH MER_NAME_SYN  Valid
# ...

# %%
len(r[r.Valid == -1]) / len(r) * 100
# Out:
# 98.05245334833602

# %%
len(r[r.Valid == 1]) / len(r) * 100
# Out:
# 1.9475466516639828

# %%
r[r.Valid == 1]
# Out:
#               ID      HANA_ID STATUS BUSINESS_NUM         MER_NAME  \
# 409          410    700019187      1   2221802942        보떼(목포연산점)
# 453          454    700021921      1   4525200118          쥬씨인천구월점
# 3956        3957    700200266      1   1353267180           고릴라PC방
# 5143        5144    700271719      1   6620100431            제노pc방
# 5369        5370    700285895      1   4381700315       크린토피아원주혁신점
# 5453        5454    700290374      1   7575300081            언니네옷장
# 5919        5920    700318695      1   7783500196               나봄
# 6418        6419    700344765      1   2371800363         울트라짱구PC방
# 7190        7191    700387277      1   1283887894           NICPC방
# 8138        8139    700435071      1   5083300138            횡성생고기
# 8452        8453    700451443      1   2960900486         코기리스크린골프
# 8671        8672    700462823      1   5703900023        노상5권공영주차장
# 9854        9855    700522148      1   1020266127              골목길
# ...

# %% [markdown]
# <h1> whowho가 유효하다고 판단한 전화 번호와 114가 유효하다고 판단한 전화번호를 구분 <h1>

# %%
pair1 = pd.read_pickle('phone_num_pair.pkl') #whowho+114 약 5만개 분류
pair1.head()
# Out:
#           TEL  Valid
# 0                 -1
# 1     0000000     -1
# 2    00000000     -1
# 3   000000000     -1
# 4  0000000000     -1

# %%
pair1[pair1.Valid == 1].head() #whowho+114가 유효하다고 판단?
# Out:
#              TEL  Valid
# 1269  0215220728      1
# 1288  0216669114      1
# 1424  0226585428      1
# 1510  0234070611      1
# 1652   024491253      1

# %%
pair2 = pd.read_pickle('phone_num_pair2.pkl') #114+whowho (+extra 114)
pair2.head()
# Out:
#           TEL  Valid
# 0                 -1
# 1     0000000     -1
# 2    00000000     -1
# 3   000000000     -1
# 4  0000000000     -1

# %%
pair2[pair2.Valid == 1].head()
# Out:
#               TEL  Valid
# 15986  0215220728      1
# 16174  0216669114      1
# 17580  0226585428      1
# 18500  0234070611      1
# 19907   024491253      1

# %%
len(pair1)
# Out:
# 4789

# %% [markdown]
# <h3> whowho+114 정보에서 whowho가 1이라고 표시한 정보만 가져오기 위해 크롤 다시 진행... <h3>

# %%
pair1 = pair1.reset_index()

# %%
result = {}
count = 0
for phone_num in pair1['TEL']:
    count+=1
    if count % 1000 ==0:
        print(phone_num)
    html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
    data = urlopen(html, timeout = 1000)
    resp = json.loads(data.read())
    try:
        r = pd.DataFrame(resp)
        r = pd.DataFrame(r['data'][0])
        if r['results']['totalCount'] == 0:
            result.update({phone_num:-1})
        else:
            print (r['value'][1])
            result.update({phone_num:1})
    except:
        result.update({phone_num:-1})
# Out:
# 01085152173
# 028987680
# 03343334325
# 0610000000

# %%
result = pd.Series(result, name='Valid')
result.index.name = 'TEL'
result = result.reset_index()
result
# Out:
#                TEL  Valid
# 0                      -1
# 1          0000000     -1
# 2         00000000     -1
# 3        000000000     -1
# 4       0000000000     -1
# 5      00000000000     -1
# 6     000000000000     -1
# 7     000015223589     -1
# 8     000016000125     -1
# 9     000016441860     -1
# 10    000016443366     -1
# 11     00015667440     -1
# 12     00015889359     -1
# 13     00015998826     -1
# 14     00016442494     -1
# 15      0015223630     -1
# 16      0015227585     -1
# 17      0016703357     -1
# 18      0018771221     -1
# 19     01010196815     -1
# 20     01020110239     -1
# 21     01020112452     -1
# 22     01020169858     -1
# 23     01020217288     -1
# 24     01020236999     -1
# 25     01020258000     -1
# 26     01020276142     -1
# 27     01020339705     -1
# 28     01020348978     -1
# 29     01020400773     -1
# ...            ...    ...
# 4759   07089807512     -1
# 4760   07089873111     -1
# 4761   07089919159     -1
# ...

# %%
result[result.Valid == 1]
# Out:
# Empty DataFrame
# Columns: [TEL, Valid]
# Index: []

# %% [markdown]
# 확인결과 pair1 에는 114는 전부 유효하지 않다고 판단

# %%
len(pair1[pair1.Valid == 1])
# Out:
# 50

# %% [markdown]
# 확인결과 pair1 과 다르지 않음 -> whowho의 결과 값 50!

# %%
len(pair2[pair2.Valid == 1])
# Out:
# 50

# %%
pair_total = pd.read_pickle('phone_num_pair_total.pkl')
len(pair_total[pair_total.Valid == 1])
# Out:
# 50

# %%
p = pair1[pair1.Valid == 1]
p = p.reset_index()

# %%
p
# Out:
#     level_0  index          TEL  Valid
# 0      1269   1269   0215220728      1
# 1      1288   1288   0216669114      1
# 2      1424   1424   0226585428      1
# 3      1510   1510   0234070611      1
# 4      1652   1652    024491253      1
# 5      1669   1669    024652079      1
# 6      1680   1680    024750731      1
# 7      1696   1696    024971696      1
# 8      1741   1741    025522735      1
# 9      1794   1794   0260535010      1
# 10     1820   1820   0263978887      1
# 11     1948   1948    028427798      1
# 12     1956   1956    028523525      1
# 13     2048   2048    029552877      1
# 14     2103   2103   0300000000      1
# 15     2105   2105   0310000000      1
# 16     2572   2572   0317750433      1
# 17     2595   2595  03180259270      1
# 18     2746   2746   0319868442      1
# 19     2766   2766  03200000000      1
# 20     2913   2913   0327248575      1
# 21     2942   2942   0328655277      1
# 22     2971   2971   0330000000      1
# ...

# %%
def whowho_search(phone_num):
    driver.get('https://www.whox2.com/view/main.jsp')
    driver.implicitly_wait(3)
    input = driver.find_element_by_id('search')
    input.clear()
    input.send_keys(phone_num)
    input.send_keys(keys.Keys.ENTER)
    driver.implicitly_wait(3)
    try:
        text = driver.find_element_by_xpath('//*[@id="result"]/dl/div/dd[1]').text
        text = text.split('\n')
        return text[1]
    except:
        text = driver.find_element_by_xpath('//*[@id="result"]/dl/dt[2]').text
        text = text.split('\n')
        return text[1]

# %%
path = 'C:\chromedriver.exe'
driver = webdriver.Chrome(path)
new_MER_NAME = {}
for phone_num in p['TEL']:
    new_MER_NAME.update({phone_num:whowho_search(phone_num)})

# %%
new_name = pd.Series(new_MER_NAME, name = 'new_MER_NAME')
new_name.index.name = 'TEL'
new_name = new_name.reset_index()
new_name
# Out:
#             TEL      new_MER_NAME
# 0    0215220728             (주)임다
# 1    0216669114           (주)스마트로
# 2    0226585428           베이커리 몽소
# 3    0234070611             평안엘엔시
# 4     024491253      믿음한우착한돼지(위례)
# 5     024652079          바닐라슈 쇼핑몰
# 6     024750731             비너스모텔
# 7     024971696            세무법인한맥
# 8     025522735           와이즈만 학원
# 9    0260535010               알뜰폰
# 10   0263978887       북경 상도1동 중국집
# 11    028427798          크린데이대림동점
# 12    028523525              한일세탁
# 13    029552877          블루클럽방학역점
# 14   0300000000     통합메시징서비스(UMS)
# 15   0310000000         유솔,로엠,키즈덤
# 16   0317750433               예마당
# 17  03180259270          곱창고수지구청점
# 18   0319868442             신명이엔시
# 19  03200000000             살구PC방
# 20   0327248575            반디동물병원
# 21   0328655277               우리호
# 22   0330000000      강릉(경포여자중학교)!
# 23  04100000000       S-OIL이순신주유소
# 24   0420000000         대덕구재난안내문자
# 25  04215770711           세븐일레븐본사
# ...

# %%
r = hana.join(s.set_index('TEL'), on='TEL')
r = r[r.Valid == 1]

# %%
final = r.join(new_name.set_index('TEL'), on='TEL')
final.head()
# Out:
#         ID    HANA_ID STATUS BUSINESS_NUM    MER_NAME         TEL  MER_TYPE3  \
# 409    410  700019187      1   2221802942   보떼(목포연산점)  0610000000       1501
# 453    454  700021921      1   4525200118     쥬씨인천구월점  0310000000       2305
# 3956  3957  700200266      1   1353267180      고릴라PC방  0310000000       8310
# 5143  5144  700271719      1   6620100431       제노pc방  0310000000       8310
# 5369  5370  700285895      1   4381700315  크린토피아원주혁신점  0330000000       1301
#
#      MER_TYPE3_NAME           X            Y                 LAT  \
# 409             화장품  897690.038  1646883.839    34.8114027786893
# 453            서양음식  929386.901  1938672.977    37.4445437248903
# 3956         기타레져업소  959520.923  1917984.226   37.25987348883293
# 5143         기타레져업소  936615.597  1966193.298   37.69310398832259
# 5369            세탁소  1042953.92  1925009.205  37.323083378858236
#
#                      LON       GEOHASH MER_NAME_SYN  Valid    new_MER_NAME
# ...

# %%
final
# Out:
#               ID      HANA_ID STATUS BUSINESS_NUM         MER_NAME  \
# 409          410    700019187      1   2221802942        보떼(목포연산점)
# 453          454    700021921      1   4525200118          쥬씨인천구월점
# 3956        3957    700200266      1   1353267180           고릴라PC방
# 5143        5144    700271719      1   6620100431            제노pc방
# 5369        5370    700285895      1   4381700315       크린토피아원주혁신점
# 5453        5454    700290374      1   7575300081            언니네옷장
# 5919        5920    700318695      1   7783500196               나봄
# 6418        6419    700344765      1   2371800363         울트라짱구PC방
# 7190        7191    700387277      1   1283887894           NICPC방
# 8138        8139    700435071      1   5083300138            횡성생고기
# 8452        8453    700451443      1   2960900486         코기리스크린골프
# 8671        8672    700462823      1   5703900023        노상5권공영주차장
# 9854        9855    700522148      1   1020266127              골목길
# ...

# %%
final.to_pickle('final_result.pkl')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://eums:eums00!q@133.186.146.142:3306/eums-poi?charset=utf8mb4", encoding = 'utf8' ,
                   pool_size=20,pool_recycle=3600,connect_args={'connect_timeout':1000000} )

# %%
query = """
select ID,CO_NAME
from MEUMS_COMPANY
where CATE ='외식'
"""

# %%
company = pd.read_sql_query(query, engine)
company.head()
# Out:
#        ID  CO_NAME
# 0   21425  BBQ 전농점
# 1   65305       가향
# 2   94396   고메이494
# 3  119000     국수나무
# 4  121417     군산횟집

# %%
company.CO_NAME[1].split(' ')
# Out:
# ['가향']

# %%
for name in comapny.CO_NAME.unique():

# %%
len(company)
# Out:
# 500000

# %%
num_pair = {}
while len(num_pair) != len(company.REP_PHONE_NUM.unique()):
    try:
        s = pd.Series(num_pair, name='Valid')
        s.index.name = 'REP_PHONE_NUM'
        s = s.reset_index()
        r = company.join(s.set_index('REP_PHONE_NUM'), on='REP_PHONE_NUM')
        r1 = r[r.Valid != -1]
        r2 = r1[r1.Valid != 1]
        print(len(r2))
        # driver = webdriver.Chrome(path, chrome_options = options)
        count = 0
        for phone_num in r2.TEL:
            count += 1    
            if count % 1000 == 0:
                print('running...', phone_num, count / 1000)
                time.sleep(random.randrange(1,7))
            try:
                if num_pair[phone_num] != 0:
                    continue
            except:
                html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
                data = urlopen(html, timeout = 1000)
                resp = json.loads(data.read())

                try:
                    r = pd.DataFrame(resp)
                    r = pd.DataFrame(r['data'][0])
                    if r['results']['totalCount'] == 0:
                        num_pair.update({phone_num:-1})
                    else:
                        print (r['value'][1])
                        num_pair.update({phone_num:1})
                except:
                    num_pair.update({phone_num:-1})
    except:
        print('exception occured!')
        f = open('num2.txt','a')
        f.write(str(len(r2))+'\n')
        f.close()
        s = pd.Series(num_pair, name='Valid')
        s.index.name = 'REP_PHONE_NUM'
        s = s.reset_index()
        s.to_pickle('company_phone_num_pair_total.pkl')
        continue
# Out:
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# exception occured!
# 500000
# ...

# %%
f2 = open("unigram.txt", 'r')
li = f2.read().encode('cp949').encode('utf-8').encode('utf-8').split('\n')
f2.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-8b7128317301> in <module>()
#       1 f2 = open("unigram.txt", 'r')
# ----> 2 li = f2.read().encode('cp949').encode('utf-8').encode('utf-8').split('\n')
#       3 f2.close()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x80 in position 14: illegal multibyte sequence

# %%
with open("unigram.txt", 'r',) as f:
    f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-7485f5c45601> in <module>()
#       1 with open("unigram.txt", 'r',) as f:
# ----> 2     f.read()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x80 in position 14: illegal multibyte sequence

# %%
company[company.CO_NAME == '형제슈퍼']
# Out:
# Empty DataFrame
# Columns: [ID, CO_NAME]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine
impor

# %%
engine = create_engine("mysql+pymysql://eums:eums00!q@133.186.146.142:3306/eums-poi?charset=utf8mb4", encoding = 'utf8' ,
                   pool_size=20,pool_recycle=3600,connect_args={'connect_timeout':1000000} )

# %%
query = """
select *
from MEUMS_COMPANY
"""

# %%
company = pd.read_sql_query(query,engine)
company.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\anaconda\lib\site-packages\sqlalchemy\engine\result.py in fetchall(self)
#    1130         try:
# -> 1131             l = self.process_rows(self._fetchall_impl())
#    1132             self._soft_close()
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\result.py in process_rows(self, rows)
#    1110             return [process_row(metadata, row, processors, keymap)
# -> 1111                     for row in rows]
#    1112
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\result.py in <listcomp>(.0)
#    1110             return [process_row(metadata, row, processors, keymap)
# -> 1111                     for row in rows]
#    1112
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionAbortedError                    Traceback (most recent call last)
# ...

# %%
result = {}
count = 0
for phone_num in company.REP_PHONE_NUM:
    count+=1
    if count % 10000 ==0:
        print(phone_num)
    html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
    data = urlopen(html, timeout = 1000)
    resp = json.loads(data.read())
    try:
        r = pd.DataFrame(resp)
        r = pd.DataFrame(r['data'][0])
        if r['results']['totalCount'] == 0:
            result.update({phone_num:-1})
        else:
            print (r['value'][1])
            result.update({phone_num:1})
    except:
        result.update({phone_num:-1})
