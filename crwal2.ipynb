# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium

test = pd.read_pickle('company_test.pkl')
test = test[2001:4000]
path = 'C:\chromedriver.exe'
driver2 = webdriver.Chrome(path)

# %%
# %%time
driver2 = webdriver.Chrome(path)
result2 = []
for phone_num in test.REP_PHONE_NUM:
    driver2.get('https://www.whox2.com/view/main.jsp')
    driver2.implicitly_wait(3)
    input = driver2.find_element_by_id("search")
    driver2.implicitly_wait(3)
    input.clear()
    driver2.implicitly_wait(3)
    input.send_keys(phone_num)
    driver2.implicitly_wait(3)
    input.send_keys(keys.Keys.ENTER)
    html = driver2.page_source
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.find('dl').get_text().split('\n')
    while True:
        try:
            text.remove("")
        except ValueError:
            break
    print(text)
    for t in text:
        if '검색결과가 없습니다.' in t:
            text = [phone_num,'','','','','','']
    info = []
    info.append(text[0])
    info.append(text[3])
    if len(text) < 5:
        info.append('')
        info.append('')
    else:
        info.append(text[4])
        if len(text) < 6:
            info.append("")
        else:
            info.append(text[5])
    result2.append(info)
result2 = pd.DataFrame(result2, columns = ['phone_num', 'co_name_rr','addr', 'cate'])
result2
# Out:
# ['070-7964-4910', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 장안동', '자동차관련대행서비스(기타)']
# ['070-7964-5619', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-5801', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-5469', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 감일동', '자동차관련대행서비스(종합)']
# ['070-7964-7458', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-7501', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 역삼1동', '자동차관련대행서비스(기타)']
# ['070-7964-6286', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 상산곡동', '자동차관련대행서비스(종합)']
# ['070-7964-6200', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-7038', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-7742', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 배알미동', '자동차관련대행서비스(종합)']
# ['070-7964-7227', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 회기동', '자동차관련대행서비스(종합)']
# ['070-7964-6221', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 학암동', '자동차관련대행서비스(종합)']
# ['070-7964-7769', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-8067', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-9895', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 휘경동', '자동차관련대행서비스(기타)']
# ['070-7964-9127', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 중랑구 망우3동', '자동차관련대행서비스(종합)']
# ['070-7964-8235', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 성동구 금호동3가', '자동차관련대행서비스(종합)']
# ['070-7965-0147', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강동구 명일동', '자동차관련대행서비스(기타)']
# ['070-7964-8140', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 성동구 성수2가1동', '자동차관련대행서비스(기타)']
# ['070-7964-9056', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-9617', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-0319', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 휘경2동', '렌트카']
# ['070-7964-8649', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7964-9635', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 압구정동', '자동차관련대행서비스(종합)']
# ['070-7965-2352', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 성동구 금호동2가', '렌트카']
# ['070-7965-1502', '\t\t', '상호정보', '(주)건영렌트카', '경기도 구리시 동구동', '자동차관련대행서비스(종합)']
# ['070-7965-1328', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-1063', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-1607', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-0441', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-2220', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 일원2동', '렌트카']
# ['070-7965-1853', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 성동구 금호동1가', '자동차관련대행서비스(기타)']
# ['070-7965-2183', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-2842', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 송파구 장지동', '자동차관련대행서비스(종합)']
# ['070-7965-3031', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 중랑구 망우1동', '자동차관련대행서비스(기타)']
# ['070-7965-5206', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강동구 고덕2동', '자동차관련대행서비스(기타)']
# ['070-7965-3867', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 광진구 자양4동', '렌트카']
# ['070-7965-3269', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 용두동', '자동차관련대행서비스(종합)']
# ['070-7965-4443', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-3329', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 송파구 문정동', '자동차관련대행서비스(기타)']
# ['070-7965-5575', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 중랑구 묵1동', '렌트카']
# ['070-7965-3250', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 항동', '자동차관련대행서비스(종합)']
# ['070-7965-4479', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-4827', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 신장동', '자동차관련대행서비스(기타)']
# ['070-7965-6442', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-6248', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 전농동', '렌트카']
# ['070-7965-7375', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 중랑구 망우동', '렌트카']
# ['070-7965-6498', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-6639', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 송파구 가락동', '렌트카']
# ['070-7965-6632', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-6785', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 광진구 군자동', '자동차관련대행서비스(종합)']
# ['070-7965-7385', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 도곡동', '렌트카']
# ['070-7965-7446', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 상사창동', '자동차관련대행서비스(종합)']
# ['070-7965-7760', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-7548', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 역삼2동', '렌트카']
# ['070-7965-8128', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-9225', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-8981', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-9535', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 동대문구 답십리2동', '렌트카']
# ['070-7965-8934', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 신사동', '자동차관련대행서비스(종합)']
# ['070-7965-9257', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 송파구 마천1동', '렌트카']
# ['070-7965-7937', '\t\t', '상호정보', '(주)건영렌트카', '경기도 하남시 창우동', '자동차관련대행서비스(종합)']
# ['070-7970-1034', '\t\t', '상호정보', '24시출장열쇠디지털도어락보조키게이트맨', '경기도 군포시 당정동', '열쇠판매,수리']
# ['070-7970-4943', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-9936', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 광진구 중곡2동', '자동차관련대행서비스(기타)']
# ['070-7965-9909', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 성동구 행당2동', '렌트카']
# ['070-7965-9628', '\t\t', '상호정보', '(주)건영렌트카', '서울특별시 강남구 논현1동', '렌트카']
# ['070-7965-9722', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7970-1554', '\t\t', '상호정보', '웅진코웨이(정수기,공기청정기,비데)렌탈', '인천광역시 부평구 부평동', '정수기']
# ['070-7965-9897', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7965-9748', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7970-5061', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7970-6403', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7972-2010', '\t\t', '상호정보', '24시출장열쇠,자동차키스마트키복사제작', '부산광역시 중구 동광동1가', '열쇠판매,수리']
# ['070-7972-4023', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7971-0723', '\t\t', '상호정보', 'SK브로드밴드', '대구광역시 달서구 송현동', '유선방송']
# ['070-7971-3195', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7971-5254', '\t\t', '상호정보', '공장사무실이전이사전문', '서울특별시 양천구 목동', '이삿짐센터']
# ['070-7970-9840', '\t\t', '상호정보', '일사랑철거', '부산광역시 금정구 장전동', '건축폐기물수집처리']
# ['070-7970-8535', '\t\t', '상호정보', '자동차배터리출장밧데리로케트델코배터리', '경기도 성남시 분당구 백현동', '밧데리']
# ['070-7971-8456', '\t\t', '상호정보', '아이폰사설수리점아이폰배터리교체', '경기도 용인시 기흥구 상하동', '통신기기도매']
# ['070-7971-9112', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7972-6400', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7973-1262', '\t\t', '상호정보', '견인차렉카대형렉카견인업체', '대전광역시 서구 평촌동', '견인운송']
# ['070-7972-9627', '\t\t', '상호정보', '케이티(KT)인터넷/올레스카이라이프유선방송', '경상남도 밀양시 남포동', '유선방송']
# ['070-7973-8351', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7972-9468', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7973-9257', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7973-1438', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7973-8435', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7973-6254', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7974-0001', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7974-1421', '\t\t', '상호정보', '햇빛줄눈시공입주준공주차장청소철거페인트', '서울특별시 관악구 신림동', '청소,소독대행']
# ['070-7974-6617', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7974-5269', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-3134', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-0730', '\t\t', '상호정보', '케이티(KT)인터넷/올레스카이라이프유선방송', '전라북도 정읍시 신태인읍 백산리', '유선방송']
# ['070-7975-0722', '\t\t', '상호정보', '가인도배장판', '인천광역시 중구 항동4가', '도배공사']
# ['070-7975-5673', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7974-4717', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-1849', '\t\t', '상호정보', '고객만족1위/하수구변기싱크대수전막힘뚫는곳업체', '울산광역시 울주군 언양읍 평리', '배관,난방공사']
# ['070-7974-9929', '\t\t', '상호정보', '하나수도설비배관', '경기도 수원시 장안구 파장동', '배관,난방공사']
# ['070-7976-0600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-6729', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-9084', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7976-8266', '\t\t', '상호정보', '번개맨열쇠자동문', '경상남도 통영시 산양읍 삼덕리', '열쇠판매,수리']
# ['070-7976-5015', '\t\t', '상호정보', '송광생수총판', '경기도 용인시 기흥구 상갈동', '생수']
# ['070-7978-0259', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7978-3107', '\t\t', '상호정보', '가나누수하수구탐지수도설비', '경기도 남양주시 지금동', '수도설비공사']
# ['070-7976-9846', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7982-0549', '\t\t', '상호정보', '킹스카이차(스카이외벽유리간판방수조경)', '서울특별시 종로구 사간동', '스카이대여']
# ['070-7978-4395', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7982-2453', '\t\t', '상호정보', '폐기물유품정리가정폐기물하나알앤씨(R&C)', '경기도 성남시 중원구 상대원동', '폐기물수집처리(기타)']
# ['070-7982-0704', '\t\t', '상호정보', '헌옷.수거.중고.옷.업체.팔기.매입.파는곳', '서울특별시 강남구 일원동', '의류판매(종합)']
# ['070-7982-5650', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7982-6617', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7982-7343', '\t\t', '상호정보', '입주청소이사청소후드청소줄눈시공바닥왁스', '경기도 안산시 상록구 일동', '청소,소독대행']
# ['070-7983-3275', '\t\t', '상호정보', '케이티(KT)인터넷/올레스카이라이프유선방송', '전라남도 여수시 소라면 덕양리', '인터넷전화판매']
# ['070-7982-8596', '\t\t', '상호정보', '위니아에어컨설치서비스', '경기도 수원시 영통구 이의동', '에어컨설치']
# ['070-7983-3144', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7983-5073', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7983-5461', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7984-2299', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7984-4558', '\t\t', '상호정보', '중고피아노(피아노매입,매매)', '경기도 안성시 보개면 기좌리', '중고피아노판매']
# ['070-7983-7537', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7984-8868', '\t\t', '상호정보', '샷시방충망방범창방화문유리문방화문흰지', '경기도 고양시 덕양구 선유동', '방화문']
# ['070-7984-6024', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7984-9093', '\t\t', '상호정보', '100프로흥신소심부름센타', '광주광역시 광산구 송정동', '흥신소']
# ['070-7985-1241', '\t\t', '상호정보', '에어컨설치판매수리가스충전냉장냉동기수리', '서울특별시 송파구 잠실동', '에어컨설치']
# ['070-7984-8913', '\t\t', '상호정보', '출장열쇠.도장', '서울특별시 성북구 하월곡2동', '열쇠제조']
# ['070-7985-3193', '\t\t', '상호정보', '대성폐차장', '경기도 광명시 소하동', '무역업(기타)']
# ['070-7985-3391', '\t\t', '상호정보', '에어컨설치', '경기도 안산시 상록구 건건동', '냉난방기판매(종합)']
# ['070-7985-7222', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7985-7353', '\t\t', '상호정보', '도배장판전문점벽지로', '서울특별시 용산구 동자동', '벽지,장판지제조(종합)']
# ['070-7985-3452', '\t\t', '상호정보', '대성폐차장', '경기도 화성시 능동', '무역업(종합)']
# ['070-7985-7905', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7985-6697', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7986-0987', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7986-0113', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7986-1811', '\t\t', '상호정보', '집/가구/방문/수거/피아노/유품/정리/비용/업체', '서울특별시 노원구 공릉2동', '건축폐기물수집처리']
# ['070-7986-2974', '\t\t', '상호정보', '청주콜밴', '충청북도 청주시 상당구 남일면 가산리', '콜밴']
# ['070-7986-2779', '\t\t', '상호정보', '샷시수리.미세방충망.추락방지망.외풍차단', '부산광역시 사하구 당리동', '방충망,방범창판매설치']
# ['070-7986-5029', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-966-7409', '\t\t', '공유정보', '건우상사']
# ['070-7986-9849', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7986-8598', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7986-9677', '\t\t', '상호정보', '선진키월드게이트맨디지털도어락번호키열쇠', '서울특별시 구로구 천왕동', '열쇠판매,수리']
# ['02-303-7477', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-565-8189', '\t\t', '상호정보', '(주)건웅', '인천광역시 서구 연희동', '관리사무소']
# ['02-971-1325', '\t\t', '상호정보', '(주)건영스포렉스', '서울특별시 노원구 하계동', '부동산']
# ['070-7986-5994', '\t\t', '상호정보', '케이티(KT)인터넷/올레스카이라이프유선방송', '충청남도 서산시 지곡면 산성리', '인터넷전화판매']
# ['051-866-7890', '\t\t', '상호정보', '(주)건인이앤씨', '부산광역시 부산진구 양정동', '건물분양(종합)']
# ['043-653-6868', '\t\t', '상호정보', '(주)건일기술단', '충청북도 제천시 청전동', '측량업']
# ['031-662-4275', '\t\t', '상호정보', '(주)건종', '경기도 평택시 진위면 동천리', '가죽제품소매(기타)']
# ['055-634-1203', '\t\t', '상호정보', '(주)건축공방지음', '경상남도 거제시 상동동', '부동산']
# ['054-534-6114', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-598-3655', '\t\t', '상호정보', '(주)건축사사무소뷰', '서울특별시 서초구 서초동', '부동산']
# ['054-256-5220', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-255-9800', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3288-8877', '\t\t', '상호정보', '(주)감정평가법인경무', '서울특별시 강남구 삼성동', '부동산']
# ['064-772-4748', '\t\t', '상호정보', '(주)건풍바이오부설연구소', '제주특별자치도 제주시 한림읍 금능리', '식품첨가물제조']
# ['043-648-0312', '\t\t', '상호정보', '(주)건화건기', '충청북도 제천시 천남동', '건설기계대여']
# ['070-4709-9003', '\t\t', '상호정보', '(주)경기렌트카', '경기도 평택시 포승읍 내기리', '렌트카']
# ['02-555-1928', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-275-3575', '\t\t', '상호정보', '(주)경국건설', '경상남도 창원시 의창구 사림동', '관리사무소']
# ['031-567-9627', '\t\t', '상호정보', '(주)경기구주이배', '경기도 구리시 수택동', '서적도매']
# ['031-386-8366', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-663-6001', '\t\t', '상호정보', '(주)경기남부유통', '경기도 평택시 가재동', '잡화점']
# ['055-312-1070', '\t\t', '상호정보', '(주)경', '경상남도 김해시 구산동', '실외골프연습장']
# ['02-942-0066', '\t\t', '공유정보', '정릉경기마트', '경기마트 광고']
# ['02-6291-7300', '\t\t', '상호정보', '(주)하나관광투어', '서울특별시 금천구 가산동', '전세버스']
# ['02-483-0655', '\t\t', '상호정보', '(주)경기에너지', '서울특별시 강동구 성내2동', '주유소']
# ['055-263-1331', '\t\t', '상호정보', '(주)경남산업컨설팅', '경상남도 창원시 의창구 두대동', '창업상담']
# ['052-266-7175', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-644-2944', '\t\t', '상호정보', '경남동화', '경상남도 통영시 용남면 동달리', '인테리어']
# ['055-633-1759', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-311-1670', '\t\t', '상호정보', '(주)경동특수주강', '부산광역시 사상구 학장동', '금속가공']
# ['053-621-6278', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-752-7671', '\t\t', '상호정보', '(주)경남주택건설', '대구광역시 수성구 범어1동', '관리사무소']
# ['055-746-8030', '\t\t', '상호정보', '(주)경문', '경상남도 진주시 평거동', '부동산']
# ['051-747-7826', '\t\t', '상호정보', '(주)경민', '부산광역시 해운대구 중2동', '부동산']
# ['02-3666-8332', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-544-8311', '\t\t', '상호정보', '(주)경산구조안전기술원', '서울특별시 광진구 자양동', '관리사무소']
# ['052-275-4890', '\t\t', '공유정보', '경산 건물관리업체']
# ['054-636-5113', '\t\t', '상호정보', '(주)서진환경', '경상북도 영주시 휴천3동', '건축설비설치공사(종합)']
# ['064-738-0005', '\t\t', '상호정보', '(주)경성', '제주특별자치도 서귀포시 동홍동', '부동산']
# ['054-777-1380', '\t\t', '상호정보', '(주)경북나무종합병원', '경상북도 경주시 충효동', '임업 ']
# ['054-436-8272', '\t\t', '상호정보', '(주)경북혁신닷컴', '경상북도 김천시 율곡동', '부동산']
# ['054-432-8278', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2253-2902', '\t\t', '상호정보', '(주)영림유업', '서울특별시 중구 신당동', '부동산']
# ['02-999-7033', '\t\t', '상호정보', '(주)경성디자인', '서울특별시 강북구 수유3동', '인테리어']
# ['054-244-5770', '\t\t', '상호정보', '(주)경성주택', '경상북도 포항시 북구 장성동', '주택수리']
# ['054-273-2734', '\t\t', '상호정보', '(주)경안산업', '경상북도 포항시 남구 해도동', '부동산']
# ['070-4185-9900', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-205-5911', '\t\t', '상호정보', '(주)경성종합관리', '부산광역시 사하구 당리동', '관리사무소']
# ['02-3667-8575', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-437-9170', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2214-8575', '\t\t', '상호정보', '(주)경원흥산', '서울특별시 동대문구 답십리동', '사무실임대']
# ['043-648-1701', '\t\t', '상호정보', '(주)경우크린텍', '충청북도 제천시 강제동', 'FRP']
# ['032-503-9908', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-549-6472', '\t\t', '상호정보', '(주)경인네트웍스', '인천광역시 계양구 계산동', '부동산']
# ['032-889-0025', '\t\t', '상호정보', '(주)경인에셋', '인천광역시 중구 신흥동3가', '공장임대']
# ['02-596-5514', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-323-0403', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-812-3416', '\t\t', '상호정보', '(주)경인통상', '인천광역시 남동구 고잔동', '벨트제조']
# ['041-576-5749', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-581-2700', '\t\t', '상호정보', '(주)경인센타', '인천광역시 부평구 십정1동', '부동산']
# ['032-889-9013', '\t\t', '상호정보', '(주)경인에셋', '인천광역시 중구 항동7가', '공장임대']
# ['02-2212-1383', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2212-1383', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-899-0429', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-402-0550', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-407-3223', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-443-5859', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2233-2534', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-457-1415', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-457-2218', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-477-1556', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-462-1655', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-525-2174', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-525-2242', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-525-4431', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-605-5454', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-573-3040', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-557-3433', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-553-0036', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-562-3222', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-572-0059', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-542-4655', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-605-8282', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-713-7990', '\t\t', '상호정보', '리싸이클시티소사본점', '경기도 부천시 상동', '중고가구판매']
# ['031-607-5454', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-773-1479', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-253-0089', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-943-3816', '\t\t', '상호정보', '(주)경진가구그룹', '경기도 파주시 광탄면 용미리', '사무용가구제조']
# ['055-745-8421', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-768-0088', '\t\t', '상호정보', '(주)경정소풍가', '대구광역시 수성구 두산동', '한식']
# ['02-785-3659', '\t\t', '상호정보', '(주)경쟁력평가원', '서울특별시 영등포구 문래동5가', '경영연구소']
# ['041-549-7509', '\t\t', '상호정보', '경진아산터미널점', '충청남도 아산시 모종동', '관리사무소']
# ['041-338-1600', '\t\t', '상호정보', '(주)경진테크', '충청남도 예산군 삽교읍 두리', '단조']
# ['053-521-0254', '\t\t', '상호정보', '(주)경천산업', '대구광역시 달서구 본리동', '인테리어']
# ['070-8224-7671', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-730-3717', '\t\t', '상호정보', '(주)경훈상사', '부산광역시 해운대구 우동', '주방가구']
# ['051-802-3061', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-325-0026', '\t\t', '상호정보', '(주)경풍', '경상남도 김해시 안동', '신발제조(기타)']
# ['043-652-6428', '\t\t', '상호정보', '(주)계림건설', '충청북도 제천시 신백동', '철근콘크리트공사']
# ['02-2234-9211', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-475-6339', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-985-2311', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-488-1428', '\t\t', '상호정보', '(주)계룡관리', '서울특별시 강동구 성내동', '관리사무소']
# ['02-2237-9211', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-744-3939', '\t\t', '상호정보', '(주)계양씨앤씨', '강원도 원주시 단계동', '부동산']
# ['02-823-7008', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2644-9994', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-438-8034', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-472-5590', '\t\t', '상호정보', '(주)고구려', '경기도 하남시 감일동', '인테리어']
# ['02-529-0222', '\t\t', '상호정보', '(주)고객사랑마트', '서울특별시 강남구 개포4동', '슈퍼마켓', '스팸이력', '3개월 내 스팸신고 12건', '                \t', '기타유형스팸 4건', '텔레마케팅 3건', '휴대폰판매 2건']
# ['055-312-2662', '\t\t', '상호정보', '(주)고려토지개발', '경상남도 김해시 삼계동', '부동산']
# ['041-523-0186', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-446-5590', '\t\t', '상호정보', '(주)고구려', '경기도 안양시 만안구 박달동', '인테리어']
# ['031-541-0931', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-542-5241', '\t\t', '상호정보', '(주)고려공구백화점홈앤툴', '경기도 포천시 가산면 금현리', '수공구도매']
# ['02-711-7322', '\t\t', '상호정보', '(주)고려경영연구소', '서울특별시 마포구 공덕동', '보험']
# ['02-2115-8222', '\t\t', '상호정보', '(주)고려기초연구소', '서울특별시 성동구 성수2가동', '형틀공사']
# ['042-531-5342', '\t\t', '상호정보', '(주)고려광학', '대전광역시 대덕구 신일동', '안경렌즈제조']
# ['02-797-5245', '\t\t', '상호정보', '(주)고려당', '서울특별시 용산구 한강로3가', '제과점']
# ['02-540-4330', '\t\t', '상호정보', '(주)고려디앤씨', '서울특별시 강남구 삼성동', '부동산']
# ['02-552-4332', '\t\t', '상호정보', '(주)고려디앤씨', '서울특별시 강남구 논현동', '부동산']
# ['02-482-1946', '\t\t', '상호정보', '(주)고려나무병원', '서울특별시 강동구 명일동', '임업 ']
# ['02-825-4256', '\t\t', '상호정보', '(주)고려명진', '서울특별시 동작구 노량진동', '부동산']
# ['031-953-4811', '\t\t', '상호정보', '(주)고려시스템', '경기도 파주시 조리읍 오산리', '사무용가구제조']
# ['041-673-8788', '\t\t', '상호정보', '(주)고려씨엔씨', '충청남도 태안군 안면읍 창기리', '건물분양(종합)']
# ['02-2001-9700', '\t\t', '상호정보', '(주)고려이앤씨', '서울특별시 용산구 갈월동', '인터넷교육']
# ['031-997-4310', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-328-3500', '\t\t', '상호정보', '원조사상자유양곱창센타1코너서울이모네', '부산광역시 사상구 괘법동', '한식']
# ['044-863-7726', '\t\t', '상호정보', '(주)고매푸드디지텍고', '세종특별자치시 어진동', '유흥주점']
# ['055-335-0908', '\t\t', '상호정보', '(주)고려종합건설', '경상남도 김해시 부원동', '부동산']
# ['02-593-5855', '\t\t', '상호정보', '고려주택관리', '서울특별시 서초구 반포동', '기타']
# ['055-251-4533', '\t\t', '상호정보', '(주)고려환지기술공사', '경상남도 창원시 의창구 소답동', '부동산']
# ['031-916-1733', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-722-6232', '\t\t', '상호정보', '(주)고성공영', '부산광역시 기장군 기장읍 동부리', '관리사무소']
# ['02-873-9152', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-644-5663', '\t\t', '상호정보', '(주)고성관광개발', '부산광역시 남구 문현4동', '골프장']
# ['055-673-2852', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-326-3011', '\t\t', '상호정보', '(주)고암', '서울특별시 마포구 창전동', '관리사무소']
# ['051-302-0706', '\t\t', '상호정보', '(주)고암', '부산광역시 사상구 모라1동', '관리사무소']
# ['02-2068-3388', '\t\t', '상호정보', '(주)고암', '서울특별시 영등포구 당산동6가', '관리사무소']
# ['02-2069-2581', '\t\t', '상호정보', '(주)고암', '서울특별시 영등포구 문래동3가', '관리사무소']
# ['053-636-1420', '\t\t', '상호정보', '(주)고신', '대구광역시 달서구 진천동', '관리사무소']
# ['051-244-4422', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2631-3011', '\t\t', '상호정보', '(주)고암에이스', '서울특별시 영등포구 당산동6가', '관리사무소']
# ['031-963-3056', '\t\t', '공유정보', '고양낙농치즈체험장']
# ['02-572-9922', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-679-0163', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-624-8431', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-921-7701', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2142-4242', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-293-3573', '\t\t', '상호정보', '(주)골드그린', '부산광역시 사하구 괴정1동', '부동산']
# ['031-908-0678', '\t\t', '상호정보', '(주)고일기업', '경기도 고양시 일산동구 장항동', '부동산']
# ['051-636-0202', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-245-1375', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2659-2050', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-703-8880', '\t\t', '공유정보', '신화종합건설']
# ['02-553-1343', '\t\t', '상호정보', '(주)골드마인건설', '서울특별시 강남구 역삼1동', '호텔']
# ['062-233-9500', '\t\t', '상호정보', '(주)골드프로', '광주광역시 동구 충장로5가', '귀금속,장신구제조(종합)']
# ['02-429-8655', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-798-0203', '\t\t', '상호정보', '(주)골드마인무역', '경기도 광주시 오포읍 추자리', '가죽,모피제품도매(종합)']
# ['02-2157-5258', '\t\t', '공유정보', '엔씨백화점 쥬얼리샵']
# ['02-517-8411', '\t\t', '상호정보', '(주)골든듀', '서울특별시 강남구 압구정동', '귀금속,장신구제조(종합)']
# ['02-416-7461', '\t\t', '상호정보', '(주)골든듀', '서울특별시 송파구 잠실3동', '귀금속,장신구제조(종합)']
# ['02-3415-5700', '\t\t', '상호정보', '(주)골든듀', '서울특별시 서초구 서초3동', '비금속재생재료가공처리(종합)']
# ['062-222-2451', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-730-3355', '\t\t', '상호정보', '(주)골든벨금속', '부산광역시 해운대구 우동', '귀금속,장신구제조(종합)']
# ['061-383-3415', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4911-9330', '\t\t', '상호정보', '(유한)남부상사', '경기도 고양시 덕양구 토당동', '주류제조(종합)']
# ['02-586-5067', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-241-7711', '\t\t', '상호정보', '(주)골든시티오피스텔', '부산광역시 중구 부평동4가', '관리사무소']
# ['042-221-0367', '\t\t', '상호정보', '(주)골든트러스트', '대전광역시 중구 용두동', '부동산']
# ['031-932-8932', '\t\t', '상호정보', '(주)골든코스컴퍼니', '경기도 고양시 일산동구 마두동', '서적도매']
# ['042-546-9400', '\t\t', '상호정보', '(주)골든파라다이스', '대전광역시 서구 가수원동', '부동산']
# ['070-4174-7001', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3390-4015', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-471-8553', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-772-8100', '\t\t', '상호정보', '(주)골프샷존', '경상북도 경주시 신평동', '스크린골프장']
# ['062-944-7978', '\t\t', '상호정보', '케이엠골프', '광주광역시 광산구 황룡동', '골프용품']
# ['032-875-6700', '\t\t', '상호정보', '(주)공간', '인천광역시 남구 도화1동', '부동산']
# ['02-3446-9292', '\t\t', '상호정보', '(주)곰바우', '서울특별시 강남구 삼성동', '한식']
# ['02-439-1222', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-767-5717', '\t\t', '상호정보', '(주)공간수장', '대구광역시 수성구 상동', '장식용품도매']
# ['031-582-1472', '\t\t', '상호정보', '(주)공간인테리어건설', '경기도 가평군 가평읍 대곡리', '인테리어']
# ['032-815-4533', '\t\t', '상호정보', '(주)공간아트', '인천광역시 남동구 고잔동', '인테리어']
# ['02-3665-4319', '\t\t', '상호정보', '(주)공간종합관리', '서울특별시 강서구 가양1동', '관리사무소']
# ['031-584-9174', '\t\t', '상호정보', '(주)공문교육연구원', '경기도 가평군 설악면 회곡리', '학습지']
# ['02-525-2578', '\t\t', '상호정보', '(주)민창개발', '서울특별시 영등포구 영등포동1가', '물탱크청소']
# ['02-451-0985', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['052-716-6999', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2644-9225', '\t\t', '상호정보', '(주)공익프로그램전문기획사그리고', '서울특별시 양천구 신정동', '교육상담']
# ['02-2636-8884', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-535-4031', '\t\t', '상호정보', '(주)과학전문그룹펜타스', '서울특별시 서초구 잠원동', '보습학원']
# ['031-965-7003', '\t\t', '상호정보', '(주)관악도서유통', '경기도 고양시 일산동구 식사동', '서적도매']
# ['031-421-7637', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-753-3981', '\t\t', '상호정보', '(주)광덕', '대구광역시 수성구 수성동2가', '관리사무소']
# ['061-791-9332', '\t\t', '상호정보', '(주)광동기업', '전라남도 광양시 광영동', '관리사무소']
# ['02-365-9600', '\t\t', '상호정보', '(주)광림아이앤씨', '서울특별시 서대문구 북아현동', '부동산']
# ['031-529-2604', '\t\t', '상호정보', '(주)광릉나무병원', '경기도 남양주시 진접읍 장현리', '임업']
# ['02-582-1857', '\t\t', '상호정보', '(주)광명이엔지', '서울특별시 서초구 서초동', '관리사무소']
# ['02-777-2804', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-931-1054', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['052-251-1905', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-642-7259', '\t\t', '상호정보', '(주)광민전기', '충청북도 제천시 명지동', '전기공사']
# ['053-642-0153', '\t\t', '상호정보', '(주)광성개발', '대구광역시 달서구 상인1동', '부동산']
# ['062-945-8600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-278-1463', '\t\t', '상호정보', '(주)광안', '경상북도 포항시 남구 상도동', '관리사무소']
# ['063-261-9965', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-537-6226', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-331-1233', '\t\t', '상호정보', '(주)광일', '전라남도 나주시 남평읍 풍림리', '가구']
# ['061-724-2076', '\t\t', '상호정보', '(주)광영', '전라남도 순천시 야흥동', '벨트제조']
# ['043-271-3933', '\t\t', '상호정보', '(주)광영주택', '충청북도 청주시 서원구 개신동', '관리사무소']
# ['061-908-2076', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-793-9987', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-525-9437', '\t\t', '상호정보', '(주)광일푸드시스템', '광주광역시 북구 임동', '잡화점']
# ['02-6952-1500', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6952-1500', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4594-6500', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 청파동1가', '열쇠판매,수리']
# ['070-4594-6472', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 이촌동', '열쇠판매,수리']
# ['070-4594-6487', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 이태원동', '열쇠판매,수리']
# ['070-4594-6519', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 한강로2가', '열쇠판매,수리']
# ['070-4594-6532', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 한남동', '열쇠판매,수리']
# ['070-4594-6563', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 후암동', '열쇠판매,수리']
# ['070-4594-6546', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 용산구 효창동', '열쇠판매,수리']
# ['070-4594-6581', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 중구 광희동1가', '열쇠판매,수리']
# ['070-4594-6600', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 중구 명동1가', '열쇠판매,수리']
# ['070-4594-6623', '\t\t', '상호정보', '차키,자동차키,스마트키,분실,번호키,디지탈키', '서울특별시 중구 방산동', '열쇠판매,수리']
# ['02-578-1435', '\t\t', '상호정보', '광주은행', '서울특별시 서초구 서초동', '은행']
# ['062-370-9005', '\t\t', '상호정보', '(주)광주세정아울렛', '광주광역시 서구 치평동', '쇼핑센터,할인매장']
# ['02-878-4090', '\t\t', '상호정보', '(주)광진기업', '서울특별시 관악구 신림[신림5동]동', '부동산']
# ['061-322-3955', '\t\t', '상호정보', '광주일보사함평다이너스티CC', '전라남도 함평군 학교면 곡창리', '골프장']
# ['053-351-7939', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-637-2116', '\t\t', '상호정보', '(주)광해', '부산광역시 해운대구 우2동', '부동산']
# ['051-637-2116', '\t\t', '상호정보', '(주)광해', '부산광역시 해운대구 우2동', '부동산']
# ['043-644-5151', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-733-9436', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-733-9436', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-868-8344', '\t\t', '상호정보', '(주)광호', '부산광역시 남구 용호동', '부동산']
# ['055-314-7878', '\t\t', '상호정보', '(주)교림유통', '경상남도 김해시 풍유동', '슈퍼마켓']
# ['02-3474-2335', '\t\t', '상호정보', '(주)교보실업', '서울특별시 동작구 사당1동', '관리사무소']
# ['02-3392-1550', '\t\t', '상호정보', '(주)교보실업', '서울특별시 노원구 상계동', '관리사무소']
# ['055-284-3501', '\t\t', '공유정보', '창원 교보문고']
# ['033-482-2521', '\t\t', '상호정보', '(주)교보건설', '강원도 양구군 양구읍 상리', '관리사무소']
# ['02-707-3481', '\t\t', '상호정보', '(주)교보실업', '서울특별시 마포구 노고산동', '관리사무소']
# ['02-2297-8081', '\t\t', '상호정보', '(주)교우푸드', '서울특별시 성동구 마장동', '부동산']
# ['02-991-1810', '\t\t', '상호정보', '(주)교보실업', '서울특별시 강북구 번1동', '관리사무소']
# ['031-766-1450', '\t\t', '상호정보', '(주)교원', '경기도 광주시 경안동', '학습지']
# ['054-332-0327', '\t\t', '상호정보', '(주)교원', '경상북도 영천시 완산동', '학습지']
# ['0000-0000', '\t\t', '상호정보', '잘못된 국제전화 형식(주의요망)', '스팸이력', '안심등록 64건', '3개월 내 스팸신고 60건', '                \t', '보이스피싱 24건', '대출안내 18건', '전화유도 10건']
# ['0000-0000', '\t\t', '상호정보', '잘못된 국제전화 형식(주의요망)', '스팸이력', '안심등록 64건', '3개월 내 스팸신고 60건', '                \t', '보이스피싱 24건', '대출안내 18건', '전화유도 10건']
# ['031-918-9004', '\t\t', '상호정보', '(주)교원구몬', '경기도 고양시 일산서구 주엽동', '학습지']
# ['031-911-1829', '\t\t', '상호정보', '교원빨간펜', '경기도 고양시 일산서구 주엽동', '학습지']
# ['0000-0000', '\t\t', '상호정보', '잘못된 국제전화 형식(주의요망)', '스팸이력', '안심등록 64건', '3개월 내 스팸신고 60건', '                \t', '보이스피싱 24건', '대출안내 18건', '전화유도 10건']
# ['052-275-1677', '\t\t', '상호정보', '(주)교원빨간펜', '울산광역시 북구 상안동', '학습지']
# ['054-734-7228', '\t\t', '상호정보', '(주)교원빨간펜', '경상북도 영덕군 영덕읍 남석리', '학습지']
# ['043-651-3352', '\t\t', '상호정보', '(주)교원아카데미', '충청북도 제천시 청전동', '서적출판(종합)']
# ['032-324-0866', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8071-4070', '\t\t', '상호정보', '(주)교육중심', '경기도 파주시 문발동', '인터넷교육']
# ['031-969-6150', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-856-0245', '\t\t', '상호정보', '(주)구공관리', '서울특별시 금천구 가산동', '관리사무소']
# ['055-680-0262', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-861-8191', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-421-8756', '\t\t', '상호정보', '(주)구미인터내셔날', '대구광역시 중구 대봉1동', '셔츠판매']
# ['070-4694-4467', '\t\t', '상호정보', '(주)구미개발', '대구광역시 동구 신천4동', '골프장']
# ['061-781-0691', '\t\t', '상호정보', '(주)구원목재산업', '전라남도 구례군 구례읍 원방리', '목재가구제조']
# ['031-911-2992', '\t\t', '상호정보', '(주)구성컴퍼니', '경기도 고양시 일산서구 대화동', '건물분양(종합)']
# ['02-2232-3582', '\t\t', '상호정보', '(주)구일에쏘르', '서울특별시 중구 신당동', '부동산']
# ['02-522-6196', '\t\t', '상호정보', '(주)구정', '서울특별시 서초구 서초동', '가공식품도매(기타)']
# ['053-427-1862', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-574-2552', '\t\t', '상호정보', '(주)국광부동산', '충청남도 천안시 서북구 성정2동', '부동산']
# ['032-777-3577', '\t\t', '상호정보', '(주)국보', '인천광역시 동구 송림동', '부동산']
# ['041-592-3880', '\t\t', '상호정보', '(주)국광부동산', '충청남도 천안시 서북구 성정2동', '부동산']
# ['031-244-0980', '\t\t', '상호정보', '(주)구천동공구시장', '경기도 수원시 팔달구 구천동', '관리사무소']
# ['02-2058-1649', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-942-0126', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-536-0664', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6953-9530', '\t\t', '스팸이력', '3개월 내 스팸신고 22건', '                \t', '휴대폰판매 15건', '텔레마케팅 6건', '불법게임, 도박 1건', '공유정보', 'kt', 'kt', '공유정보 키워드', 'KT']
# ['02-6953-9550', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6953-9570', '\t\t', '공유정보', 'kt', 'KT 폰  판매', '공유정보 키워드', 'KT']
# ['02-6956-9005', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-522-5084', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-522-5096', '\t\t', '상호정보', '쿠쿠정수기', '경기도 남양주시 화도읍 마석우리', '정수기']
# ['053-744-5990', '\t\t', '상호정보', '(주)국일종합관리', '대구광역시 동구 신천4동', '청소,소독대행']
# ['031-795-9300', '\t\t', '상호정보', '(주)국보렌트카', '경기도 하남시 천현동', '저울']
# ['051-255-3546', '\t\t', '상호정보', '드림크루즈해운(주)', '부산광역시 중구 동광동2가', '선박해체']
# ['02-325-1329', '\t\t', '상호정보', '(주)국제기업전략연구소', '서울특별시 마포구 신수동', '사회과학연구소']
# ['032-751-3650', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-337-7088', '\t\t', '상호정보', '(주)국제상사', '경상남도 김해시 부원동', '신발제조(종합)']
# ['054-435-6474', '\t\t', '상호정보', '(주)국제실업', '경상북도 김천시 교동', '부동산']
# ['02-514-9533', '\t\t', '상호정보', '(주)국제품질연구소', '서울특별시 서초구 잠원동', '경영상담(종합)']
# ['02-542-1146', '\t\t', '상호정보', '(주)국제패션디자인직업전문학교', '서울특별시 서초구 양재동', '패션디자인학원']
# ['032-321-1737', '\t\t', '상호정보', '(주)국천산업', '인천광역시 계양구 계산동', '부동산']
# ['02-416-5382', '\t\t', '상호정보', '(주)국진섬유', '서울특별시 송파구 석촌동', '가방장식품제조']
# ['02-419-8712', '\t\t', '상호정보', '(주)유성시에스((주)유성CS', '서울특별시 송파구 신천동', '관리사무소']
# ['063-452-1011', '\t\t', '상호정보', '(주)군산종합모터스', '전라북도 군산시 개정면 발산리', '모터,원동기수리']
# ['063-445-8700', '\t\t', '상호정보', '(주)군장에이엠씨', '전라북도 군산시 경장동', '부동산']
# ['053-622-2000', '\t\t', '상호정보', '(주)군청빌딩', '대구광역시 남구 대명11동', '부동산']
# ['02-598-4200', '\t\t', '상호정보', '한국밥', '서울특별시 서초구 서초동', '한식']
# ['043-643-1900', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-532-5185', '\t\t', '상호정보', '(주)굿데이굿플라워', '서울특별시 서초구 방배동', '카페']
# ['031-631-6015', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-511-5690', '\t\t', '상호정보', '(주)굿도매', '경기도 남양주시 호평동', '스포츠웨어판매']
# ['043-233-9611', '\t\t', '상호정보', '좋은도시개발(주)', '충청북도 청주시 흥덕구 가경동', '부동산']
# ['02-835-7275', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-989-4546', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-949-8798', '\t\t', '상호정보', '(주)굿뜨래유통', '경기도 파주시 야당동', '슈퍼마켓']
# ['054-852-4600', '\t\t', '상호정보', '(주)굿랜드', '경상북도 안동시 동문동', '부동산']
# ['02-925-2189', '\t\t', '상호정보', '글로리아항공(주)', '서울특별시 동대문구 용두동', '인터넷교육']
# ['041-522-5717', '\t\t', '상호정보', '(주)굿모닝관리', '충청남도 천안시 동남구 신부동', '부동산']
# ['041-558-7116', '\t\t', '상호정보', '(주)굿모닝관리', '충청남도 천안시 서북구 백석동', '건물분양(종합)']
# ['041-567-9007', '\t\t', '상호정보', '(주)굿모닝관리', '충청남도 천안시 서북구 두정동', '관리사무소']
# ['062-971-3320', '\t\t', '상호정보', '(주)굿모닝산업개발', '광주광역시 광산구 쌍암동', '부동산']
# ['02-819-8512', '\t\t', '상호정보', '(주)굿모닝포유', '서울특별시 구로구 구로1동', '부동산']
# ['02-819-8512', '\t\t', '상호정보', '(주)굿모닝포유', '서울특별시 구로구 구로1동', '부동산']
# ['02-553-0222', '\t\t', '상호정보', '(주)굿모닝포유', '서울특별시 강남구 역삼동', '부동산']
# ['02-819-8517', '\t\t', '상호정보', '(주)굿모닝포유', '서울특별시 구로구 구로동', '관리사무소']
# ['02-819-8518', '\t\t', '상호정보', '(주)굿모닝포유', '서울특별시 구로구 구로1동', '부동산']
# ['02-733-2156', '\t\t', '상호정보', '(주)굿채널시스템', '서울특별시 서대문구 홍제4동', '통신,방송장비제조(종합)']
# ['044-865-9001', '\t\t', '상호정보', '굿하우스관리사무소', '세종특별자치시 조치원읍 남리', '부동산']
# ['02-394-3774', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-582-6140', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-452-5030', '\t\t', '상호정보', '(주)굿테크', '경기도 군포시 금정동', '정보통신기기수리']
# ['051-746-0770', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-701-7955', '\t\t', '상호정보', '(주)굿프랜즈부동산투자', '부산광역시 기장군 정관읍 모전리', '부동산']
# ['02-3663-0245', '\t\t', '상호정보', '(주)굿헬스케어코리아', '서울특별시 강서구 가양동', '화장품도매']
# ['02-434-8177', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-959-3100', '\t\t', '상호정보', '(주)권동용평생세무교육원', '서울특별시 동대문구 청량리동', '학원(종합)']
# ['041-531-1688', '\t\t', '상호정보', '(주)그늘집스크린골프', '충청남도 아산시 배방읍 공수리', '스크린골프장']
# ['031-232-5807', '\t\t', '상호정보', '(주)귀농귀촌연구소', '경기도 수원시 팔달구 인계동', '부동산']
# ['051-207-0550', '\t\t', '상호정보', '(주)그라운드', '부산광역시 사하구 하단1동', '부동산']
# ['02-761-1211', '\t\t', '상호정보', '(주)신미산개발', '서울특별시 마포구 도화동', '부동산']
# ['02-2062-5550', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-555-7867', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-945-1332', '\t\t', '상호정보', '(주)그라지에파티쉐', '경기도 파주시 조리읍 대원리', '제과점']
# ['051-755-7700', '\t\t', '상호정보', '(주)부백건설', '부산광역시 수영구 광안동', '주택전시장']
# ['02-851-2351', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-573-1600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-508-8441', '\t\t', '상호정보', '(주)그루샘수학보습학원', '서울특별시 강남구 대치동', '보습학원']
# ['070-4161-5954', '\t\t', '상호정보', '(주)그루스튜디오', '서울특별시 종로구 통의동', '인테리어']
# ['055-356-2221', '\t\t', '상호정보', '(주)그랜드케니언컨트리클럽', '경상남도 밀양시 단장면 안법리', '골프장']
# ['02-540-0166', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-755-0835', '\t\t', '상호정보', '(주)그리쉼', '서울특별시 중구 남창동', '주거용건물임대(종합)']
# ['070-4145-0410', '\t\t', '상호정보', '(주)그리다컴퍼니', '서울특별시 마포구 성산동', '인테리어']
# ['031-527-8374', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-977-2188', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-442-7886', '\t\t', '상호정보', '(주)그린개발', '인천광역시 남동구 구월1동', '부동산']
# ['051-502-4131', '\t\t', '상호정보', '(주)그린도시정비사업단', '부산광역시 금정구 구서동', '부동산']
# ['063-905-2314', '\t\t', '상호정보', '(주)그린랜트', '전라북도 전주시 덕진구 송천동1가', '렌트카']
# ['063-905-1314', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-386-8701', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-552-2656', '\t\t', '상호정보', '(주)그린메리칼', '서울특별시 강남구 대치동', '의약품소매(종합)']
# ['041-942-6633', '\t\t', '상호정보', '(주)그린뷰', '충청남도 청양군 비봉면 방한리', '바이오,미생물연구개발']
# ['031-382-3376', '\t\t', '상호정보', '(주)그린비교역', '경기도 안양시 동안구 관양동', '잡화점']
# ['033-761-3972', '\t\t', '상호정보', '(주)그린빌', '강원도 원주시 단계동', '관리사무소']
# ['070-4262-8873', '\t\t', '상호정보', '(주)그린빌', '강원도 태백시 황지동', '관리사무소']
# ['070-4473-8853', '\t\t', '상호정보', '(주)그린빌', '강원도 태백시 황지동', '관리사무소']
# ['070-7733-8569', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-554-4978', '\t\t', '상호정보', '(주)그린사이언스', '강원도 태백시 장성동', '자연과학연구개발(종합)']
# ['02-869-3535', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3394-6633', '\t\t', '상호정보', '(주)그린시티디앤씨', '서울특별시 성동구 용답동', '부동산']
# ['031-752-6605', '\t\t', '상호정보', '(주)그린씨엠에스', '경기도 성남시 수정구 복정동', '벽지,장판']
# ['051-974-0901', '\t\t', '상호정보', '(주)그린앤테크', '부산광역시 강서구 지사동', '부동산']
# ['053-746-0915', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3444-7500', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4188-3840', '\t\t', '상호정보', '(주)그린에프앤제이', '경기도 과천시 과천동', '꽃,꽃집']
# ['031-222-4918', '\t\t', '상호정보', '(주)그린월드팜', '경기도 화성시 안녕동', '의약품소매(기타)']
# ['055-388-3196', '\t\t', '상호정보', '그린우드', '경상남도 양산시 원동면 화제리', '주방가구제조']
# ['02-2666-5050', '\t\t', '상호정보', '(주)그린유통', '서울특별시 강서구 공항동', '슈퍼마켓']
# ['043-644-9488', '\t\t', '상호정보', '(주)그린임업엔지니어링', '충청북도 제천시 화산동', '임업']
# ['053-783-3119', '\t\t', '상호정보', '(주)그린이노텍연구소', '대구광역시 수성구 지산동', '자연과학연구개발(기타)']
# ['02-2201-0368', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-314-6018', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-321-6351', '\t\t', '상호정보', '(주)그린진바이오텍', '경기도 용인시 처인구 남동', '자연과학연구개발(종합)']
# ['031-904-8230', '\t\t', '상호정보', '(주)그린케터링', '경기도 고양시 일산동구 장항동', '한식']
# ['052-256-4926', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2209-8204', '\t\t', '상호정보', '(주)그린홈테크', '서울특별시 중랑구 면목2동', '인테리어']
# ['051-802-7711', '\t\t', '상호정보', '(주)극동감정평가서', '부산광역시 부산진구 전포동', '부동산']
# ['043-743-7792', '\t\t', '상호정보', '(주)극동건설', '충청북도 영동군 영동읍 계산리', '관리사무소']
# ['054-253-6655', '\t\t', '상호정보', '(주)극동오토렌탈', '경상북도 포항시 북구 장성동', '렌트카']
# ['055-311-5300', '\t\t', '상호정보', '(주)근영', '경상남도 김해시 내동', '부동산']
# ['02-3159-9534', '\t\t', '상호정보', '근우산업이엔지', '경기도 고양시 덕양구 덕은동', '재활용품수집', '스팸이력', '3개월 내 스팸신고 27건', '                \t', '텔레마케팅 13건', '기타유형스팸 7건', '전화유도 2건']
# ['053-644-3848', '\t\t', '상호정보', '(주)근영', '경상북도 칠곡군 지천면 연호리', '커튼도매']
# ['054-441-0369', '\t\t', '상호정보', '(주)근아주택', '경상북도 구미시 원평동', '부동산']
# ['042-632-9351', '\t\t', '상호정보', '(주)근대화체인', '대전광역시 대덕구 오정동', '슈퍼마켓']
# ['041-522-5804', '\t\t', '상호정보', '(주)극동미라주', '충청남도 천안시 동남구 신부동', '부동산']
# ['055-723-3305', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7010-7925', '\t\t', '상호정보', '(주)글로리데이즈코리아', '서울특별시 중구 신당동', '무역업(종합)']
# ['032-622-7128', '\t\t', '상호정보', '(주)근하빌트라인', '경기도 부천시 원미구 상동', '관리사무소']
# ['02-6952-6668', '\t\t', '상호정보', '(주)글로리렌트여행사', '서울특별시 동대문구 청량리동', '렌트카']
# ['031-506-8863', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-506-8816', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6356-7677', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4980-0664', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성북구 정릉동', '렌트카']
# ['031-513-7674', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4980-0662', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강북구 미아동', '렌트카']
# ['070-4980-0663', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 중랑구 망우동', '렌트카']
# ['070-4980-0665', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 광진구 자양동', '렌트카']
# ['070-4980-0667', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 동대문구 휘경동', '렌트카']
# ['070-4980-0675', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성동구 홍익동', '렌트카']
# ['070-4980-6962', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 광진구 구의동', '렌트카']
# ['070-4980-0671', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성동구 성수1가동', '렌트카']
# ['070-4980-6965', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 중랑구 묵동', '렌트카']
# ['070-4980-0670', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 중랑구 면목동', '렌트카']
# ['070-4980-0674', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강남구 역삼동', '렌트카']
# ['070-4980-6961', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성북구 보문동2가', '렌트카']
# ['070-4980-6960', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강북구 번동', '렌트카']
# ['070-4980-5110', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 동대문구 답십리동', '렌트카']
# ['070-4980-6964', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강북구 수유동', '렌트카']
# ['070-4987-6070', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성동구 금호동1가', '렌트카']
# ['070-4987-6077', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 동대문구 장안동', '렌트카']
# ['070-4980-6966', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성동구 하왕십리동', '렌트카']
# ['070-4980-6969', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 중랑구 중화동', '렌트카']
# ['070-4987-6076', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강북구 우이[수유4동]동', '렌트카']
# ['070-4980-6968', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성북구 길음동', '렌트카']
# ['070-4987-6071', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강남구 대치동', '렌트카']
# ['070-4987-6073', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 광진구 능동', '렌트카']
# ['070-4987-6074', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 광진구 중곡동', '렌트카']
# ['070-4987-6072', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성북구 안암동2가', '렌트카']
# ['070-4987-6078', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 동대문구 이문동', '렌트카']
# ['070-4987-6804', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 강남구 압구정동', '렌트카']
# ['070-7920-5748', '\t\t', '상호정보', '활주로퀵서비스라보다마스트럭용달1톤5톤', '경기도 평택시 유천동', '퀵서비스']
# ['070-7324-8797', '\t\t', '상호정보', '(주)글로리렌트카여행사', '서울특별시 성북구 돈암동', '렌트카']
# ['070-7926-5578', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7924-8358', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7922-7831', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7920-7607', '\t\t', '상호정보', '대형견인차대형렉카,견인구난렉카업체', '경기도 용인시 처인구 남동', '견인운송']
# ['070-7923-0844', '\t\t', '상호정보', '스카이라이프', '인천광역시 중구 을왕동', '유선방송']
# ['070-7922-5344', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7926-7442', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-1205', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-5235', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7975-3492', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-388-0993', '\t\t', '상호정보', '(주)글로벌금융판매', '서울특별시 은평구 불광동', '부동산']
# ['02-474-5033', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-785-4803', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-338-1991', '\t\t', '상호정보', '(주)글로벌리더스', '경기도 용인시 처인구 매산리', '치킨']
# ['031-434-6871', '\t\t', '상호정보', '(주)글로벌랩', '경기도 시흥시 월곶동', '화학연구소']
# ['070-7983-1288', '\t\t', '상호정보', '활주로퀵서비스라보다마스트럭용달1톤5톤', '인천광역시 강화군 하점면 장정리', '퀵서비스']
# ['032-433-0010', '\t\t', '상호정보', '(주)글로벌씨앤디', '인천광역시 남동구 구월1동', '건물분양(종합)']
# ['02-422-3423', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-821-8211', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-540-0565', '\t\t', '상호정보', '(주)디와이디에듀', '서울특별시 강남구 논현2동', '교육상담']
# ['043-651-9700', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-833-9165', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-821-8215', '\t\t', '상호정보', '(주)글로벌컨셉츠코리아', '인천광역시 남동구 고잔동', '가구장식품제조']
# ['055-312-5553', '\t\t', '상호정보', '(주)글로비젼아이엔디', '경상남도 김해시 관동동', '부동산']
# ['031-8021-1899', '\t\t', '상호정보', '(주)글로벌케이', '경기도 용인시 기흥구 중동', '온풍기판매']
# ['055-312-4283', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-782-0747', '\t\t', '상호정보', '(주)금강', '경상북도 울진군 울진읍 읍내리', '부동산']
# ['053-783-1599', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-428-6000', '\t\t', '상호정보', '백억부동산', '서울특별시 강동구 강일동', '부동산']
# ['061-331-8645', '\t\t', '상호정보', '(주)금강교구', '전라남도 나주시 남평읍 풍림리', '목재가구제조']
# ['02-718-6651', '\t\t', '상호정보', '(주)금강비엠', '서울특별시 용산구 용문동', '부동산']
# ['02-893-1637', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-252-8835', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3427-1356', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3775-3275', '\t\t', '상호정보', '(주)금강엔케이에스', '서울특별시 영등포구 여의도동', '부동산']
# ['055-547-0068', '\t\t', '상호정보', '본데이옵티칼', '경상남도 창원시 진해구 화천동', '안경원']
# ['02-561-4817', '\t\t', '상호정보', '(주)금강용역', '서울특별시 강남구 삼성동', '관리사무소']
# ['052-261-6000', '\t\t', '상호정보', '(주)금강인더스트리', '울산광역시 남구 삼산동', '실리콘제조']
# ['02-445-1615', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-418-7973', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-534-9500', '\t\t', '상호정보', '(주)금광앰엔디', '서울특별시 서초구 서초동', '부동산']
# ['051-342-0707', '\t\t', '상호정보', '(주)금곡골프프라자', '부산광역시 북구 금곡동', '실내골프연습장']
# ['061-791-2552', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-963-3210', '\t\t', '상호정보', '(주)금동에스씨', '서울특별시 동대문구 제기동', '홀딩도어']
# ['053-551-6230', '\t\t', '상호정보', '(주)금동텍스', '대구광역시 중구 시장북로', '섬유제면']
# ['02-861-8628', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-535-7071', '\t\t', '상호정보', '(주)금마피앤에스', '강원도 동해시 천곡동', '관리사무소']
# ['042-484-4022', '\t\t', '상호정보', '(주)금명', '대전광역시 서구 둔산2동', '부동산']
# ['051-515-9850', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-930-1700', '\t\t', '상호정보', '(주)금보주예리', '서울특별시 노원구 상계동', '귀금속,장신구제조(종합)']
# ['02-599-3500', '\t\t', '상호정보', '(주)금복', '서울특별시 서초구 방배본동', '부동산']
# ['02-486-3520', '\t\t', '상호정보', '(주)금복', '서울특별시 강동구 천호2동', '부동산']
# ['041-751-2447', '\t\t', '상호정보', '(주)금산식품', '충청남도 금산군 금산읍 양지리', '주거용건물임대(기타)']
# ['043-653-9800', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-873-3778', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-420-5676', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-252-5355', '\t\t', '상호정보', '(주)금성', '강원도 춘천시 퇴계동', '렌트카']
# ['053-382-0977', '\t\t', '상호정보', '(주)금성개발', '대구광역시 북구 산격2동', '부동산']
# ['051-311-7779', '\t\t', '상호정보', '(주)금성사', '부산광역시 사상구 학장동', '부동산']
# ['031-965-2547', '\t\t', '상호정보', '(주)금성강철', '경기도 고양시 일산동구 식사동', '금속가구제조']
# ['055-758-7932', '\t\t', '상호정보', '(주)금성출판사', '경상남도 진주시 상대동', '학습지']
# ['055-327-5689', '\t\t', '상호정보', '(주)금성출판사', '경상남도 김해시 부곡동', '공부방']
# ['02-443-9382', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-855-0086', '\t\t', '상호정보', '꿈빛유치원', '경상북도 안동시 풍천면 갈전리', '유치원']
# ['052-257-3200', '\t\t', '상호정보', '(주)금양개발', '울산광역시 남구 달동', '비주거용건물임대(종합)']
# ['061-282-3857', '\t\t', '상호정보', '(주)금성출판사', '전라남도 목포시 옥암동', '학습지']
# ['02-3443-9538', '\t\t', '상호정보', '(주)금양교역', '서울특별시 강남구 신사동', '의복,액세서리도매']
# ['054-476-5002', '\t\t', '상호정보', '향기여행사', '경상북도 구미시 황상동', '여행사']
# ['02-438-6663', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-335-4353', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-261-8991', '\t\t', '상호정보', '(주)금오퍼니처', '부산광역시 사하구 괴정동', '가구']
# ['062-952-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-863-5726', '\t\t', '상호정보', '(주)금우', '세종특별자치시 나성동', '침구류도매']
# ['062-952-6620', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-833-0401', '\t\t', '상호정보', '(주)금진', '경상남도 사천시 사천읍 선인리', '부동산']
# ['062-610-5602', '\t\t', '상호정보', '(주)금진건설', '광주광역시 서구 매월동', '부동산']
# ['051-972-1988', '\t\t', '상호정보', '(주)금진기업', '부산광역시 강서구 대저2동', '인테리어']
# ['070-4276-4614', '\t\t', '상호정보', '(주)금풍', '경상북도 영주시 봉현면 오현리', '의류판매(종합)']
# ['02-2298-6700', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-866-0805', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-335-7813', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-326-1196', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-955-8887', '\t\t', '상호정보', '(주)금하', '광주광역시 광산구 우산동', '부동산']
# ['070-4276-9346', '\t\t', '상호정보', '(주)금풍', '경상북도 영주시 봉현면 오현리', '의류판매(종합)']
# ['02-576-6210', '\t\t', '상호정보', '(주)금해티앤디', '경기도 광명시 가학동', '가구']
# ['042-625-7788', '\t\t', '상호정보', '(주)금호개발', '대전광역시 동구 대동', '관리사무소']
# ['055-372-5542', '\t\t', '공유정보', '한양수자인조합사무소']
# ['061-842-7592', '\t\t', '상호정보', '(주)금호조선', '전라남도 고흥군 도양읍 용정리', '선박수리']
# ['031-949-8116', '\t\t', '상호정보', '(주)금호종합건설', '경기도 파주시 문산읍 선유리', '인테리어']
# ['062-382-8879', '\t\t', '상호정보', '(주)금호주택', '광주광역시 서구 농성동', '아파트임대']
# ['02-898-2080', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-644-7003', '\t\t', '상호정보', '(주)금홍', '대구광역시 달서구 상인3동', '온천']
# ['051-638-1129', '\t\t', '상호정보', '(주)금화엔터프라이즈', '부산광역시 해운대구 우동', '부동산']
# ['055-638-2376', '\t\t', '상호정보', '(주)금화', '경상남도 거제시 장평동', '선박수리']
# ['042-526-7679', '\t\t', '상호정보', '(주)금효건설', '대전광역시 중구 태평2동', '관리사무소']
# ['054-972-0056', '\t\t', '상호정보', '(주)기곤', '경상북도 칠곡군 지천면 금호리', '부동산']
# ['044-868-4302', '\t\t', '상호정보', '(주)기가사이버', '세종특별자치시 조치원읍 원리', '관리사무소']
# ['031-416-5686', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-416-5684', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-743-7086', '\t\t', '상호정보', '(주)서현디앤씨', '부산광역시 해운대구 중동', '부동산']
# ['063-652-9992', '\t\t', '상호정보', '(주)기백', '전라북도 순창군 풍산면 삼촌리', '잡화점']
# ['02-980-6093', '\t\t', '상호정보', '(주)기범이앤에스', '서울특별시 성북구 종암동', '부동산']
# ['031-419-8922', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-759-0044', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-815-0000', '\t\t', '상호정보', '(주)기성산업개발', '대구광역시 수성구 상동', '부동산']
# ['032-566-8520', '\t\t', '상호정보', '(주)기연기업', '인천광역시 서구 오류동', '목재가구제조']
# ['062-223-8223', '\t\t', '상호정보', '(주)기암', '광주광역시 동구 황금동', '관리사무소']
# ['02-3446-0514', '\t\t', '상호정보', '(주)기영약품', '서울특별시 성동구 성수2가동', '의약품도매(종합)']
# ['062-232-5553', '\t\t', '상호정보', '(주)기천산업개발', '광주광역시 동구 지산동', '관리사무소']
# ['02-2631-1174', '\t\t', '상호정보', '(주)기임', '서울특별시 구로구 신도림동', '부동산']
# ['02-859-5163', '\t\t', '상호정보', '(주)길드디자인', '서울특별시 구로구 구로3동', '소프트웨어개발(종합)']
# ['032-576-1505', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2611-5293', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-501-6661', '\t\t', '상호정보', '(주)솔싱크', '서울특별시 강남구 역삼동', '태양광에너지']
# ['031-906-5165', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['052-273-3388', '\t\t', '상호정보', '(주)길리', '울산광역시 남구 야음동', '정보통신기기수리']
# ['02-2143-7701', '\t\t', '상호정보', '(주)길무역', '서울특별시 송파구 잠실동', '가정용가구']
# ['02-522-8803', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-451-5400', '\t\t', '상호정보', '(주)김앤원', '서울특별시 강남구 자곡동', '부동산']
# ['02-335-3922', '\t\t', '상호정보', '(주)김민지컬렉션', '서울특별시 마포구 상수동', '액세서리소매(종합)']
# ['02-2297-7759', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ...
# ['031-603-1299', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6478-1290', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-603-1298', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-568-7790', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-516-3359', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-747-9911', '\t\t', '상호정보', '(주)뉴하이렌트카', '경상남도 진주시 상봉동', '렌트카']
# ['070-4418-7701', '\t\t', '공유정보', '프로월드컵뉴코아안산점']
# ['02-954-5432', '\t\t', '상호정보', '(주)늘빛', '서울특별시 도봉구 방학동', '의자,탁자제조']
# ['031-625-1299', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-672-8289', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-651-2355', '\t\t', '상호정보', '(주)느티나무종합인테리어', '경기도 부천시 송내동', '인테리어']
# ['031-609-1290', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-508-7970', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-467-1800', '\t\t', '상호정보', '(주)늘샘(화신빌딩)', '부산광역시 동구 초량동', '부동산']
# ['02-2253-6333', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-467-1809', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3427-1199', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-572-8024', '\t\t', '상호정보', '(주)늘푸른가구', '대구광역시 서구 이현동', '가구']
# ['02-2671-8388', '\t\t', '상호정보', '(주)두리유통', '서울특별시 구로구 신도림동', '슈퍼마켓']
# ['043-642-6604', '\t\t', '상호정보', '(주)늘푸른건설', '충청북도 제천시 동현동', '보링,그라우팅공사']
# ['031-709-3923', '\t\t', '상호정보', '(주)엔이교육', '경기도 성남시 분당구 이매1동', '어학교재', '스팸이력', '안심등록 38건', '스팸 이력이 없는 번호입니다.(최근 3개월)', '                \t']
# ['02-508-1688', '\t\t', '상호정보', '(주)늘크는나무', '서울특별시 강남구 대치동', '신발도매(기타)']
# ['02-3446-7802', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-230-7509', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-780-1916', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3494-1335', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-861-9377', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-971-2231', '\t\t', '상호정보', '(주)니케볼칸퍼니처', '부산광역시 강서구 강동동', '사무용가구']
# ['054-254-2230', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-429-4614', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-326-9397', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-741-0273', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-454-8336', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3412-5611', '\t\t', '상호정보', '(주)다니엘패드레이트', '서울특별시 강남구 일원동', '액세서리제조']
# ['054-456-0068', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-255-8589', '\t\t', '상호정보', '(주)다다엔터프라이즈', '경상북도 포항시 남구 장동리', '부동산']
# ['02-462-0725', '\t\t', '상호정보', '(주)다다아트알루팝', '서울특별시 송파구 문정동', '의류판매(종합)']
# ['02-511-7918', '\t\t', '상호정보', '(주)다다도프', '서울특별시 강동구 명일동', '사무용가구판매']
# ['061-331-3787', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-407-1171', '\t\t', '공유정보', '다농마트']
# ['053-525-1670', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-498-1213', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-427-3340', '\t\t', '상호정보', '(주)다니엘팜', '경기도 군포시 금정동', '의약품도매(종합)']
# ['02-3453-7341', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-264-2272', '\t\t', '상호정보', '(주)씨엘수금재', '경상남도 창원시 성산구 상남동', '한식']
# ['02-3486-4479', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-432-6535', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-492-7070', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-564-7555', '\t\t', '상호정보', '(주)다라씨앤씨', '충청남도 천안시 동남구 유량동', '건물분양(종합)']
# ['02-6462-0101', '\t\t', '상호정보', '자양12지역주택조합', '서울특별시 광진구 자양4동', '재건축조합']
# ['043-844-5900', '\t\t', '상호정보', '(주)다담', '충청북도 충주시 금릉동', '인테리어']
# ['054-444-0277', '\t\t', '상호정보', '(주)다락과마을', '경상북도 구미시 도량동', '카페']
# ['031-322-7064', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-868-0897', '\t\t', '상호정보', '(주)다모아', '세종특별자치시 나성동', '부동산']
# ['032-652-2397', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-706-1253', '\t\t', '상호정보', '(주)다보디아이씨', '서울특별시 마포구 공덕동', '부동산']
# ['02-2088-5067', '\t\t', '상호정보', '(주)다림엔지니어링', '서울특별시 용산구 한강로1가', '경비대행']
# ['055-332-3030', '\t\t', '상호정보', '팔딱활아구', '경상남도 김해시 삼문동', '한식']
# ['02-3445-6776', '\t\t', '상호정보', '(주)다목양행', '서울특별시 강남구 신사동', '부동산']
# ['042-224-6609', '\t\t', '상호정보', '(주)다비치안경체인', '대전광역시 동구 중동', '콘택트렌즈제조']
# ['053-263-1500', '\t\t', '상호정보', '(주)다물인터네셔날', '대구광역시 동구 용계동', '잡화점']
# ['053-745-4111', '\t\t', '상호정보', '(주)다모음', '대구광역시 수성구 수성동1가', '부동산']
# ['070-7770-2340', '\t\t', '상호정보', '(주)다림에프엠', '서울특별시 송파구 문정동', '관리사무소']
# ['052-265-8685', '\t\t', '상호정보', '(주)다빈디앤씨', '울산광역시 남구 삼산동', '부동산']
# ['041-573-6571', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-857-2528', '\t\t', '상호정보', '(주)다빈치', '경상북도 경산시 진량읍 선화리', '카페']
# ['031-476-8346', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-744-0246', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2273-8877', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-554-6571', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-425-5766', '\t\t', '상호정보', '(주)다산에프앤지', '서울특별시 강남구 역삼동', '호프']
# ['02-575-6417', '\t\t', '상호정보', '(주)다산테마파크디자인연구소', '서울특별시 강남구 개포동', '산업디자인']
# ['02-578-3138', '\t\t', '상호정보', '(주)다산에스엠', '서울특별시 서초구 양재1동', '관리사무소']
# ['042-623-1599', '\t\t', '상호정보', '(주)다성정보기술', '대전광역시 서구 정림동', '통신공사']
# ['044-868-9425', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-654-0465', '\t\t', '상호정보', '(주)클린나노바이오텍', '대구광역시 동구 동내동', '생명과학연구소']
# ['02-577-1998', '\t\t', '상호정보', '(주)다스에이앤씨', '서울특별시 서초구 양재동', '가구']
# ['061-331-5185', '\t\t', '상호정보', '(주)다솔나무병원', '전라남도 나주시 노안면 학산리', '임업 ']
# ['02-861-3293', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-748-4580', '\t\t', '상호정보', '(주)다스', '강원도 원주시 무실동', '부동산']
# ['02-2645-5411', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-546-3810', '\t\t', '상호정보', '(주)다시모아', '서울특별시 강남구 논현동', '화학연구소']
# ['031-451-9216', '\t\t', '상호정보', '(주)다승', '경기도 안양시 동안구 관양동', '부동산']
# ['02-477-0464', '\t\t', '상호정보', '(주)다영금속', '서울특별시 강동구 성내1동', '장신구제조']
# ['031-312-3990', '\t\t', '상호정보', '(주)다연홈마트', '경기도 시흥시 하중동', '슈퍼마켓', '스팸이력', '3개월 내 스팸신고 14건', '                \t', '기타유형스팸 6건', '텔레마케팅 6건', '설문조사 1건']
# ['051-506-2004', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-815-5117', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2633-2001', '\t\t', '상호정보', '(주)다옥', '서울특별시 영등포구 당산동6가', '상점임대']
# ['031-904-9683', '\t\t', '상호정보', '(주)다오디자인', '경기도 고양시 일산동구 장항2동', '가구']
# ['051-701-4300', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['064-723-3894', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-701-8777', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2060-8809', '\t\t', '상호정보', '(주)다온자원', '경기도 시흥시 과림동', '의류판매(종합)']
# ['032-329-6925', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-336-2440', '\t\t', '상호정보', '(주)다온평창랜드', '강원도 평창군 진부면 하진부리', '부동산']
# ['070-4226-7841', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-356-8277', '\t\t', '상호정보', '(주)다올건설산업', '충청남도 당진시 읍내동', '관리사무소']
# ['031-334-3695', '\t\t', '상호정보', '(주)다올로지스틱', '경기도 용인시 처인구 봉명리', '의약품소매(종합)']
# ['063-581-9900', '\t\t', '상호정보', '라떼르카페', '전라북도 부안군 진서면 곰소리', '카페']
# ['062-655-7833', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-742-8877', '\t\t', '상호정보', '(주)다옴', '부산광역시 해운대구 중1동', '부동산']
# ['052-260-0880', '\t\t', '상호정보', '(주)다옴아이앤디', '울산광역시 남구 삼산동', '부동산']
# ['031-297-9970', '\t\t', '상호정보', '(주)다우', '경기도 화성시 봉담읍 왕림리', '스포츠웨어판매']
# ['031-453-0991', '\t\t', '상호정보', '(주)다우', '경기도 의왕시 고천동', '캐주얼의류판매']
# ['070-4255-4111', '\t\t', '상호정보', '(주)다우', '경기도 양평군 강하면 전수리', '의약품소매(종합)']
# ['031-984-0810', '\t\t', '상호정보', '(주)다우리산업', '경기도 김포시 양촌읍 대포리', '사무용가구제조']
# ['02-474-8173', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3482-8300', '\t\t', '상호정보', '(주)우현', '서울특별시 서초구 서초동', '건물건설(종합)']
# ['02-582-0490', '\t\t', '상호정보', '(주)다우리치플러스', '서울특별시 서초구 방배3동', '부동산']
# ['062-953-2837', '\t\t', '상호정보', '(주)다우주택', '광주광역시 서구 매월동', '연립주택임대']
# ['02-2691-2500', '\t\t', '상호정보', '(주)다우애드', '서울특별시 강서구 화곡1동', '주택전시장']
# ['02-2697-3230', '\t\t', '상호정보', '(주)다우트레이딩', '서울특별시 양천구 신월1동', '가방제조']
# ['02-2143-7785', '\t\t', '상호정보', '(주)다우닝산업', '서울특별시 송파구 잠실동', '가구']
# ['02-2697-3230', '\t\t', '상호정보', '(주)다우트레이딩', '서울특별시 양천구 신월1동', '가방제조']
# ['053-634-2020', '\t\t', '상호정보', '(주)다운', '대구광역시 달서구 상인1동', '부동산']
# ['070-7618-3678', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2120-2231', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-222-4223', '\t\t', '상호정보', '(주)다우홈텍', '충청북도 청주시 청원구 내덕1동', '인테리어']
# ['032-677-1883', '\t\t', '상호정보', '(주)다원벨르', '경기도 부천시 춘의동', '의류판매(종합)']
# ['032-831-7922', '\t\t', '상호정보', '(주)다원', '인천광역시 연수구 송도동', '부동산']
# ['032-461-5199', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-701-5147', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-586-2055', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['0000-0000', '\t\t', '상호정보', '잘못된 국제전화 형식(주의요망)', '스팸이력', '안심등록 64건', '3개월 내 스팸신고 60건', '                \t', '보이스피싱 24건', '대출안내 18건', '전화유도 10건']
# ['063-856-8555', '\t\t', '상호정보', '(주)다은피앤피', '전라북도 익산시 창인동1가', '부동산']
# ['051-863-5555', '\t\t', '상호정보', '(주)다이내믹', '부산광역시 부산진구 양정동', '부동산']
# ['02-319-9814', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-303-3000', '\t\t', '상호정보', '(주)다이내믹', '서울특별시 은평구 증산동', '부동산']
# ['02-3141-6400', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-314-1108', '\t\t', '상호정보', '(주)다이랑씨엠', '경상남도 김해시 전하동', '잡화점']
# ['02-876-6681', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-889-0142', '\t\t', '상호정보', '(주)다이룸', '인천광역시 중구 신흥동3가', '인테리어']
# ['0000-0000', '\t\t', '상호정보', '잘못된 국제전화 형식(주의요망)', '스팸이력', '안심등록 64건', '3개월 내 스팸신고 60건', '                \t', '보이스피싱 24건', '대출안내 18건', '전화유도 10건']
# ['053-639-6016', '\t\t', '상호정보', '다이소대구상인점', '대구광역시 달서구 상인동', '잡화점']
# ['02-3789-8232', '\t\t', '상호정보', '(주)다이안옵티칼', '서울특별시 용산구 한강로2가', '안경렌즈제조']
# ['053-382-2215', '\t\t', '상호정보', '(주)다인', '대구광역시 북구 고성동3가', '스포츠웨어판매']
# ['02-897-2703', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-968-0026', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-424-1515', '\t\t', '상호정보', '(주)다인', '대구광역시 북구 고성동3가', '스포츠웨어판매']
# ['033-253-2710', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-512-2745', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-575-2777', '\t\t', '상호정보', '유진철거', '강원도 삼척시 남양동', '건설폐기물수집처리']
# ['031-902-1118', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-903-1102', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-282-7744', '\t\t', '상호정보', '(주)다인부동산', '경상남도 창원시 의창구 봉림동', '부동산']
# ['02-488-9607', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2684-0617', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-255-8100', '\t\t', '상호정보', '(주)다인에스앤씨', '대전광역시 동구 원동', '관리사무소']
# ['031-768-4972', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-561-0844', '\t\t', '상호정보', '(주)다인스', '인천광역시 서구 대곡동', '가구장식품제조']
# ['043-213-7557', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3474-5577', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-916-8918', '\t\t', '상호정보', '(주)다지트', '경기도 고양시 일산동구 설문동', '인테리어']
# ['032-547-0667', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-238-8812', '\t\t', '상호정보', '라이프디하우스', '충청북도 청주시 흥덕구 복대1동', '부동산']
# ['063-236-1050', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-306-4020', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-315-9891', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-326-3025', '\t\t', '상호정보', '(주)닥슨', '서울특별시 서대문구 창천동', '침대,가구제조']
# ['031-297-7227', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-707-3589', '\t\t', '상호정보', '(주)닥터오즈감천양조장', '서울특별시 마포구 구수동', '양식']
# ['02-3272-3114', '\t\t', '상호정보', '(주)닥터로빈', '서울특별시 마포구 공덕동', '카페']
# ['02-537-3621', '\t\t', '상호정보', '(주)닥터로빈', '서울특별시 서초구 반포동', '카페']
# ['054-253-5758', '\t\t', '상호정보', '(주)닥터홈', '경상북도 포항시 북구 두호동', '부동산']
# ['051-466-7488', '\t\t', '상호정보', '(주)단아주택', '부산광역시 동구 초량3동', '건물분양(종합)']
# ['031-481-9977', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['1899-2648', '\t\t', '상호정보', '(주)코마피엔지', '산업용기계제조']
# ['053-656-2000', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-546-1221', '\t\t', '상호정보', '(주)달콤한커뮤니케이션즈', '서울특별시 강남구 신사동', '부동산']
# ['02-595-0007', '\t\t', '상호정보', '(주)담꽃', '서울특별시 동작구 흑석동', '카페']
# ['042-536-1084', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-552-5529', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-383-3111', '\t\t', '상호정보', '(주)담양관광레져', '전라남도 담양군 수북면 대방리', '골프장']
# ['055-673-9617', '\t\t', '상호정보', '(주)당항포컨트리클럽', '경상남도 고성군 회화면 배둔리', '골프장']
# ['033-636-8664', '\t\t', '상호정보', '(주)대건', '강원도 속초시 청학동', '관리사무소']
# ['041-641-8742', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-834-7672', '\t\t', '상호정보', '(주)대건씨엔디', '인천광역시 서구 원창동', '부동산']
# ['043-652-0303', '\t\t', '상호정보', '(주)대건중전기', '충청북도 제천시 서부동', '전기용품']
# ['051-727-5444', '\t\t', '상호정보', '(주)대경', '부산광역시 기장군 정관읍 달산리', '가구판매(종합)']
# ['055-313-2289', '\t\t', '상호정보', '(주)대경', '경상남도 김해시 외동', '부동산']
# ['02-909-2174', '\t\t', '상호정보', '(주)대경디앤시', '서울특별시 성북구 정릉동', '비주거용건물임대(종합)']
# ['051-333-9962', '\t\t', '상호정보', '(주)대경무역', '부산광역시 북구 덕천동', '가구']
# ['054-464-7600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-754-9291', '\t\t', '상호정보', '(주)대경법률경매', '대구광역시 달서구 본동', '부동산']
# ['02-3442-5420', '\t\t', '상호정보', '(주)대경웍스', '서울특별시 성동구 성수2가동', '부동산']
# ['031-422-0730', '\t\t', '공유정보', '대경']
# ['054-654-0951', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-792-1577', '\t\t', '상호정보', '(주)대경하우시스', '대구광역시 동구 신천동', '부동산']
# ['053-253-2546', '\t\t', '상호정보', '(주)대경티엠에스', '대구광역시 중구 수창동', '부동산']
# ['031-436-8514', '\t\t', '상호정보', '(주)대고에셋', '경기도 안양시 동안구 부림동', '사무실임대']
# ['031-436-8544', '\t\t', '상호정보', '(주)대고에셋', '경기도 안양시 동안구 관양동', '사무실임대']
# ['033-641-5183', '\t\t', '상호정보', '(주)대관령이엔지', '강원도 강릉시 남문동', '주유소']
# ['02-2155-1839', '\t\t', '상호정보', '(주)대광알에스', '서울특별시 서초구 양재동', '부동산']
# ['032-818-6742', '\t\t', '상호정보', '(주)대광정밀', '인천광역시 남동구 고잔동', '귀금속,장신구제조(기타)']
# ['054-232-9132', '\t\t', '상호정보', '(주)대륜테크', '경상북도 포항시 북구 용한리', '선박부분품제조판매']
# ['02-2601-7205', '\t\t', '상호정보', '(주)대교', '서울특별시 양천구 신정5동', '학습지']
# ['02-3142-8982', '\t\t', '상호정보', '(주)대교', '서울특별시 서대문구 홍은동', '학습지']
# ['02-2060-2168', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     330         Loads a web page in the current browser session.
#     331         """
# --> 332         self.execute(Command.GET, {'url': url})
#     333
#     334     @property
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     316
#     317         params = self._wrap_value(params)
# --> 318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
#     320             self.error_handler.check_response(response)
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     470         data = utils.dump_json(params)
#     471         url = '%s%s' % (self._url, path)
# --> 472         return self._request(command_info[0], url, body=data)
#     473
#     474     def _request(self, method, url, body=None):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     494             try:
#     495                 self._conn.request(method, parsed_url.path, body, headers)
# --> 496                 resp = self._conn.getresponse()
#     497             except (httplib.HTTPException, socket.error):
#     498                 self._conn.close()
#
# C:\anaconda\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\anaconda\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\anaconda\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\anaconda\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
len(result2)
# Out:
# 1242

# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium
import json
from urllib.request import urlopen

# %%
test = pd.read_pickle('company_test.pkl')
test = test[10001:20000]

# %%
# %%time
result = []
count = 0
for phone_num in test['REP_PHONE_NUM']:
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(2)
    html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
    
    data = urlopen(html, timeout = 20)
    resp = json.loads(data.read())
    r = pd.DataFrame(resp)
    r = pd.DataFrame(r['data'][0])
    if r['results']['totalCount'] == 0:
        info = []
        info.append(phone_num)
        info.append('')
        info.append('')
        info.append('')
        info.append('')
        info.append('')
        continue
    else:
        r = pd.DataFrame(r['results']['result'])
        r = pd.DataFrame(r['field'][0])
        info = []
        info.append(r['value'][1])
        info.append(r['value'][2])
        info.append(r['value'][3])
        info.append(r['value'][7])
        info.append(r['value'][8])
        info.append(r['value'][9])
        result.append(info)
    count+=1
# Out:
# running... 0226710286 0.0
# running... 0517172870 0.0
# running... 025525259 0.0
# running... 0327513604 0.0
# running... 07079839671 1.0
# running... 07079841991 1.0
# running... 0623748230 2.0
# running... 0515575158 3.0
# running... 07073858825 4.0
# running... 0415322385 5.0
# running... 0222960044 5.0
# running... 0514655762 6.0
# running... 0326555632 6.0
# running... 0634466040 6.0
# running... 0318237005 7.0
# running... 0318258182 7.0
# running... 0544430853 7.0
# running... 0234525667 7.0
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\anaconda\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\anaconda\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# C:\anaconda\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# C:\anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <timed exec> in <module>()
#
# C:\anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\anaconda\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\anaconda\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error timed out>

# %%
len(result)
# Out:
# 1218
