# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium

test = pd.read_pickle('company_test.pkl')
test = test[4001:6000]
path = 'C:\chromedriver.exe'

# %%
# %%time
driver2 = webdriver.Chrome(path)
result2 = []
for phone_num in test.REP_PHONE_NUM:
    driver2.get('https://www.whox2.com/view/main.jsp')
    driver2.implicitly_wait(3)
    input = driver2.find_element_by_id("search")
    driver2.implicitly_wait(3)
    input.clear()
    driver2.implicitly_wait(3)
    input.send_keys(phone_num)
    driver2.implicitly_wait(3)
    input.send_keys(keys.Keys.ENTER)
    html = driver2.page_source
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.find('dl').get_text().split('\n')
    while True:
        try:
            text.remove("")
        except ValueError:
            break
    print(text)
    for t in text:
        if '검색결과가 없습니다.' in t:
            text = [phone_num,'','','','','','']
    info = []
    info.append(text[0])
    info.append(text[3])
    if len(text) < 5:
        info.append('')
        info.append('')
    else:
        info.append(text[4])
        if len(text) < 6:
            info.append("")
        else:
            info.append(text[5])
    result2.append(info)
result2 = pd.DataFrame(result2, columns = ['phone_num', 'co_name_rr','addr', 'cate'])
result2
# Out:
# ['031-314-8209', '\t\t', '공유정보', '마이드림하우스']
# ['02-838-1676', '\t\t', '상호정보', '(주)드림시티', '서울특별시 금천구 가산동', '의류판매(종합)']
# ['070-7766-1470', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-743-7760', '\t\t', '상호정보', '(주)드림월드관리사무실', '부산광역시 해운대구 우동', '관리사무소']
# ['053-527-0144', '\t\t', '상호정보', '(주)드림이노테크', '대구광역시 중구 달성동', '직장위탁교육']
# ['032-327-9061', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-888-6380', '\t\t', '상호정보', '알보젠코리아연구소', '경기도 수원시 영통구 이의동', '의약품제조']
# ['032-280-9111', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-355-7775', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-741-3908', '\t\t', '상호정보', '(주)디딤', '대구광역시 남구 봉덕3동', '관리사무소']
# ['031-768-1224', '\t\t', '상호정보', '(주)등용문', '경기도 광주시 초월읍 지월리', '학원(종합)']
# ['031-768-1224', '\t\t', '상호정보', '(주)등용문', '경기도 광주시 초월읍 지월리', '학원(종합)']
# ['031-764-3910', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-746-3884', '\t\t', '상호정보', '(주)디.에스.씨', '강원도 원주시 단계동', '부동산']
# ['041-358-2870', '\t\t', '상호정보', '(주)디덴탈', '충청남도 당진시 읍내동', '의학연구소']
# ['031-769-4471', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-243-0471', '\t\t', '상호정보', '(주)디딤돌건설', '강원도 춘천시 운교동', '건설업(종합)']
# ['02-785-7310', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-871-0965', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-254-0779', '\t\t', '상호정보', '디에떼에스프레소양덕점', '경상북도 포항시 북구 양덕동', '카페']
# ['02-458-2502', '\t\t', '상호정보', '(주)디멘션아이이지', '서울특별시 광진구 광장동', '인테리어']
# ['055-973-4602', '\t\t', '상호정보', '(주)디럭스테크놀러지', '경상남도 산청군 금서면 매촌리', '스포츠웨어도매']
# ['02-2677-8730', '\t\t', '상호정보', '(주)디멘파이브', '서울특별시 영등포구 당산동3가', '부동산']
# ['055-757-2323', '\t\t', '상호정보', '(주)디럭스개발', '경상남도 진주시 상대동', '관리사무소']
# ['02-561-1385', '\t\t', '상호정보', '(주)디딤돌이엔씨', '서울특별시 강남구 역삼1동', '미술학원']
# ['064-739-8421', '\t\t', '상호정보', '(주)디딤인', '제주특별자치도 서귀포시 강정동', '의복,액세서리도매']
# ['02-353-0199', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-562-2888', '\t\t', '상호정보', '(주)디벨코', '서울특별시 강남구 신사동', '부동산']
# ['02-2695-9091', '\t\t', '상호정보', '(주)디베스트', '서울특별시 양천구 신월5동', '슈퍼마켓']
# ['041-742-1170', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-584-2752', '\t\t', '상호정보', '(주)디씨타운', '경기도 가평군 청평면 대성리', '의류할인점']
# ['032-816-4814', '\t\t', '상호정보', '(주)듀오백', '인천광역시 서구 가좌동', '사무용가구판매']
# ['051-625-1810', '\t\t', '상호정보', '(주)디비', '부산광역시 수영구 남천동', '부동산']
# ['053-566-5566', '\t\t', '상호정보', '(주)디비에스', '대구광역시 서구 내당4동', '부동산']
# ['053-766-7480', '\t\t', '상호정보', '(주)디씨엔에스', '대구광역시 수성구 지산동', '인테리어']
# ['031-585-4765', '\t\t', '공유정보', '아식스가평상설점']
# ['031-996-8220', '\t\t', '상호정보', '(주)디아이건설', '경기도 김포시 고촌읍 신곡리', '단독주택임대']
# ['052-261-0000', '\t\t', '상호정보', '(주)디아너스', '울산광역시 남구 선암동', '골프장']
# ['052-261-0000', '\t\t', '상호정보', '(주)디아너스', '울산광역시 남구 선암동', '골프장']
# ['02-309-3206', '\t\t', '상호정보', '(주)디아이디', '서울특별시 마포구 상암동', '벽지,장판']
# ['02-854-3661', '\t\t', '상호정보', '(주)디아프레', '서울특별시 구로구 구로동', '여성정장판매']
# ['042-867-0060', '\t\t', '상호정보', '(주)디아이티그린', '대전광역시 유성구 도룡동', '자연과학연구개발(종합)']
# ['070-7793-7846', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-544-5603', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-943-1190', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-569-3994', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-905-7700', '\t\t', '상호정보', '(주)디앤디퍼시픽', '경기도 고양시 일산동구 식사동', '의류판매(종합)']
# ['070-4243-2177', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-528-3783', '\t\t', '상호정보', '(주)디앤스포츠', '경기도 구리시 토평동', '스포츠웨어도매']
# ['02-2658-7400', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-845-6955', '\t\t', '상호정보', '(주)디앤씨씨', '충청북도 충주시 앙성면 능암리', '주유소']
# ['031-972-6394', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-931-8660', '\t\t', '상호정보', '(주)디앤씨코리아', '경기도 고양시 일산동구 장항동', '부동산']
# ['051-704-2277', '\t\t', '상호정보', '아이스크림할인점해운대좌동점', '부산광역시 해운대구 좌동', '아이스크림']
# ['063-223-9661', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-786-5577', '\t\t', '상호정보', '(주)디앤피바이오텍', '서울특별시 서초구 서초동', '의학연구소']
# ['031-584-4592', '\t\t', '상호정보', '(주)디에스', '경기도 가평군 청평면 대성리', '주유소']
# ['053-252-5829', '\t\t', '상호정보', '(주)디앤피바이오텍', '대구광역시 북구 학정동', '의학연구소']
# ['053-982-7331', '\t\t', '상호정보', '(주)디어퍼니처', '대구광역시 동구 도동', '가구']
# ['02-431-6871', '\t\t', '상호정보', '(주)디어자인', '서울특별시 송파구 문정동', '인테리어']
# ['02-539-0258', '\t\t', '상호정보', '(주)디에스사칠', '서울특별시 강남구 역삼1동', '인테리어']
# ['044-868-9458', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-989-3600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-629-2733', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-701-7997', '\t\t', '상호정보', '(주)디에스유통', '경기도 성남시 분당구 야탑동', '슈퍼마켓']
# ['02-577-2593', '\t\t', '상호정보', '(주)디에스인테리어', '서울특별시 서초구 양재동', '인테리어']
# ['031-399-6632', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-720-0944', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-883-6821', '\t\t', '상호정보', '(주)디에스하우징', '충청북도 음성군 대소면 태생리', '부동산']
# ['043-883-6756', '\t\t', '상호정보', '(주)디에스하우징', '충청북도 음성군 대소면 태생리', '부동산']
# ['041-354-3307', '\t\t', '상호정보', '(주)디에이건설', '충청남도 당진시 고대면 항곡리', '관리사무소']
# ['032-837-5280', '\t\t', '상호정보', '(주)디에이치켐엔텍', '인천광역시 연수구 송도동', '귀금속,장신구제조(기타)']
# ['02-335-4076', '\t\t', '상호정보', '(주)디에이취리얼', '서울특별시 마포구 서교동', '부동산']
# ['02-596-0396', '\t\t', '상호정보', '(주)디에이치코리아', '서울특별시 서초구 서초동', '주방가구, 주방기기']
# ['031-377-1596', '\t\t', '상호정보', '(주)디에이치씨', '경기도 오산시 부산동', '잡화점']
# ['02-2697-9444', '\t\t', '상호정보', '(주)디에이치인터내셔날', '서울특별시 강서구 화곡6동', '잡화점']
# ['032-456-4192', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-640-5090', '\t\t', '공유정보', '신세계 네오리즘']
# ['032-568-0679', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['063-453-5006', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-802-2853', '\t\t', '상호정보', '(주)디엔디산업개발', '부산광역시 부산진구 부전2동', '부동산']
# ['042-635-7947', '\t\t', '상호정보', '(주)디엔에프', '대전광역시 대덕구 대화동', '자연과학연구개발(기타)']
# ['061-392-5990', '\t\t', '상호정보', '(주)디엔신한', '전라남도 장성군 동화면 남평리', '사무용가구제조']
# ['02-3402-1301', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-533-1194', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-206-7940', '\t\t', '상호정보', '(주)디엔에프', '경기도 화성시 반월동', '자연과학연구개발(종합)']
# ['053-660-3787', '\t\t', '상호정보', '(주)디엔제이머첸다이즈', '대구광역시 북구 칠성동2가', '의류판매(종합)']
# ['042-601-2095', '\t\t', '상호정보', '(주)디엔제이머첸다이즈', '대전광역시 서구 괴정동', '가구']
# ['032-564-1217', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3145-2864', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-554-0802', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-937-7415', '\t\t', '상호정보', '(주)디엠레이져산업', '인천광역시 강화군 불은면 두운리', '가구장식품제조']
# ['02-585-6787', '\t\t', '상호정보', '(주)디엠그랑프리', '서울특별시 송파구 문정동', '인테리어']
# ['02-581-9929', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-406-3393', '\t\t', '상호정보', '(주)디엘인더스', '서울특별시 서초구 방배1동', '건물분양(종합)']
# ['02-2658-0631', '\t\t', '상호정보', '(주)디엘이노베이션', '서울특별시 강서구 염창동', '가구']
# ['02-408-9118', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-524-9373', '\t\t', '상호정보', '(주)디엠코프레이숀', '부산광역시 금정구 금사동', '장갑제조']
# ['051-244-4918', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-421-0140', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-304-4488', '\t\t', '상호정보', '(주)디엠테크코리아', '부산광역시 강서구 대저2동', '신발제조(종합)']
# ['02-3487-3260', '\t\t', '상호정보', '(주)디오랜드', '서울특별시 서초구 서초동', '부동산']
# ['02-575-0079', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-972-8501', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-281-2292', '\t\t', '상호정보', '(주)디엠피', '전라남도 목포시 상동', '관리사무소']
# ['02-415-1753', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-262-6811', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-588-7766', '\t\t', '상호정보', '(주)디와이디엔씨', '대구광역시 달성군 다사읍 죽곡리', '부동산']
# ['051-605-8801', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-894-5261', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-768-8217', '\t\t', '상호정보', '(주)디와이엠글로벌에듀', '경기도 광주시 초월읍 지월리', '외국어학원']
# ['02-425-3258', '\t\t', '상호정보', '(주)디자인다함', '서울특별시 송파구 방이1동', '인테리어']
# ['032-672-5917', '\t\t', '상호정보', '(주)디와이테크', '경기도 부천시 고강동', '액세서리제조']
# ['02-572-3305', '\t\t', '상호정보', '(주)디자인디플랜', '서울특별시 강남구 도곡동', '인테리어']
# ['02-3444-4573', '\t\t', '상호정보', '(주)디자인메소', '서울특별시 강남구 논현동', '인테리어']
# ['031-812-7799', '\t\t', '상호정보', '(주)디자인마니', '경기도 고양시 일산서구 주엽동', '인테리어']
# ['02-790-9385', '\t\t', '상호정보', '(주)디자인모스트', '서울특별시 용산구 한남동', '주방가구, 주방기기']
# ['02-467-4110', '\t\t', '상호정보', '(주)디자인배가', '서울특별시 성동구 성수1가동', '실내장식품']
# ['041-640-5451', '\t\t', '상호정보', '(주)디자인벤쳐스', '충청남도 천안시 동남구 신부동', '주방가구, 주방기기']
# ['070-7733-6173', '\t\t', '상호정보', '(주)디자인뷰인터내셔날', '서울특별시 마포구 합정동', '인테리어']
# ['053-473-4413', '\t\t', '상호정보', '(주)디자인비젼', '대구광역시 수성구 상동', '인테리어']
# ['031-901-5976', '\t\t', '상호정보', '(주)디자인수련', '경기도 고양시 일산동구 정발산동', '인테리어']
# ['032-715-7222', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-473-4485', '\t\t', '상호정보', '(주)디자인디스퀘어', '서울특별시 송파구 문정동', '인테리어']
# ['02-597-2933', '\t\t', '상호정보', '(주)디자인수안', '서울특별시 서초구 방배3동', '실내장식품']
# ['02-441-0380', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6927-9938', '\t\t', '상호정보', '(주)디자인시대', '서울특별시 강남구 수서동', '인테리어']
# ['02-578-1896', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-701-7354', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2613-4411', '\t\t', '상호정보', '(주)디자인안', '서울특별시 금천구 가산동', '인테리어']
# ['02-558-8750', '\t\t', '상호정보', '(주)디자인애피타이저샐러드', '서울특별시 강남구 도곡동', '인테리어']
# ['02-3141-5266', '\t\t', '상호정보', '(주)디자인아트라인', '서울특별시 마포구 서교동', '실내장식광섬유']
# ['02-2697-6386', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-967-0730', '\t\t', '상호정보', '(주)디자인엔케이알', '서울특별시 용산구 갈월동', '인테리어']
# ['02-477-8237', '\t\t', '상호정보', '(주)디자인에너지', '서울특별시 강동구 성내동', '실내장식품']
# ['051-464-1331', '\t\t', '상호정보', '(주)디자인연구소엠', '부산광역시 부산진구 양정1동', '산업디자인']
# ['02-585-5730', '\t\t', '상호정보', '(주)디자인예테크', '서울특별시 서초구 방배1동', '인테리어']
# ['02-795-3190', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-525-5429', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-515-0781', '\t\t', '상호정보', '(주)디자인혜', '서울특별시 서초구 잠원동', '인테리어']
# ['02-2214-4622', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3412-3285', '\t\t', '상호정보', '(주)디자인풍경', '서울특별시 강남구 수서동', '관리사무소']
# ['02-575-9305', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-577-6134', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-673-8651', '\t\t', '상호정보', '(주)디제이무역', '경기도 부천시 삼정동', '가죽의류판매']
# ['041-577-0361', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2120-1600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-528-7912', '\t\t', '상호정보', '(주)유봉산업', '경기도 남양주시 진접읍 금곡리', '금속처리(종합)']
# ['070-7788-1444', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3491-3495', '\t\t', '상호정보', '디케이비엠시구도일주유소도봉', '서울특별시 도봉구 방학동', '주유소']
# ['02-776-0600', '\t\t', '상호정보', '(주)디카몰', '서울특별시 중구 남대문로4가', '의복,액세서리도매']
# ['02-784-4666', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2602-0156', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2608-5693', '\t\t', '상호정보', '(주)디케이스파랜드', '서울특별시 양천구 신월2동', '목욕탕,사우나']
# ['061-691-9000', '\t\t', '상호정보', '(주)디케이엠지스', '전라남도 여수시 중흥동', '슈퍼마켓']
# ['02-562-8587', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2183-0181', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-587-5251', '\t\t', '상호정보', '(주)디코랜드', '서울특별시 구로구 구로동', '잡화점']
# ['053-571-9979', '\t\t', '상호정보', '(주)디티에프앤비', '대구광역시 서구 이현동', '치킨']
# ['070-4123-3949', '\t\t', '상호정보', '(주)뚜띠제화', '대전광역시 중구 은행동', '잡화점']
# ['02-830-0072', '\t\t', '상호정보', '(주)제이케이글로벌', '서울특별시 영등포구 문래동3가', '무역업(종합)']
# ['053-622-9122', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-593-6572', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2693-5663', '\t\t', '상호정보', '(주)뛰는친구들', '서울특별시 강서구 화곡6동', '인테리어']
# ['070-4635-2138', '\t\t', '상호정보', '(주)떡보의하루', '대구광역시 달서구 이곡1동', '떡집']
# ['02-583-5234', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-518-6860', '\t\t', '상호정보', '(주)띵크커피코리아', '서울특별시 강남구 청담동', '카페']
# ['053-766-3677', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-423-3259', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-367-7897', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-237-0330', '\t\t', '상호정보', '(주)라마지에르', '충청북도 청주시 흥덕구 신성동', '수입가구판매']
# ['02-2232-0071', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-444-1176', '\t\t', '공유정보', '라온국어논술']
# ['02-578-3788', '\t\t', '상호정보', '(주)라베', '서울특별시 서초구 양재2동', '부동산']
# ['031-502-8452', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-487-0976', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-516-5793', '\t\t', '상호정보', '(주)라온아이디', '서울특별시 서초구 서초동', '인테리어']
# ['032-821-0975', '\t\t', '상호정보', '(주)라온애니멀헬스', '인천광역시 연수구 동춘3동', '동물병원']
# ['051-919-9298', '\t\t', '상호정보', '(주)라온테크', '부산광역시 강서구 죽림동', '선박수리']
# ['070-7872-7708', '\t\t', '상호정보', '(주)라온테크', '부산광역시 강서구 죽림동', '선박건조,수리(종합)']
# ['031-901-2131', '\t\t', '상호정보', '(주)라이저', '경기도 고양시 일산동구 장항동', '건물분양(종합)']
# ['053-721-7790', '\t\t', '상호정보', '(주)라이온스관광', '대구광역시 달서구 성당동', '전세버스']
# ['041-732-1913', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6363-3733', '\t\t', '상호정보', '(주)라움에프앤씨', '서울특별시 중구 회현동2가', '한식']
# ['061-811-0009', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-322-2392', '\t\t', '상호정보', '라이즈유통', '경기도 용인시 처인구 일산리', '화장지도매']
# ['02-762-6657', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-981-9375', '\t\t', '상호정보', '(주)라인이앤디', '서울특별시 강북구 미아동', '인테리어']
# ['051-518-3636', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-496-8743', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-267-7500', '\t\t', '상호정보', '(주)라임주택', '경상남도 창원시 성산구 상남동', '부동산']
# ['02-2666-0259', '\t\t', '상호정보', '(주)라코스', '서울특별시 강서구 염창동', '관리사무소']
# ['02-388-5800', '\t\t', '상호정보', '(주)라익코퍼레이션', '서울특별시 은평구 응암동', '부동산']
# ['02-2653-1134', '\t\t', '상호정보', '(주)라이프종합관리', '서울특별시 양천구 목1동', '관리사무소']
# ['070-7725-9670', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4909-4091', '\t\t', '상호정보', '(주)람스트리', '서울특별시 종로구 와룡동', '아동복판매']
# ['02-956-7991', '\t\t', '상호정보', '(주)라페스포츠', '서울특별시 도봉구 도봉동', '스포츠웨어판매']
# ['053-857-1966', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-567-5100', '\t\t', '상호정보', '(주)랜드마크월드와이드', '서울특별시 강남구 역삼동', '부동산']
# ['053-591-2895', '\t\t', '상호정보', '(주)래드시스', '대구광역시 달성군 다사읍 죽곡리', '자연과학연구개발(기타)']
# ['054-733-0200', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7011-3955', '\t\t', '상호정보', '(주)랜드마크월드와이드', '서울특별시 강남구 역삼동', '부동산']
# ['053-751-2005', '\t\t', '상호정보', '(주)랜드앤하우징', '대구광역시 수성구 범어3동', '건물분양(종합)']
# ['032-859-1301', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-734-7889', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-511-7280', '\t\t', '상호정보', '(주)랜드피아', '경기도 남양주시 화도읍 답내리', '부동산']
# ['043-852-9423', '\t\t', '상호정보', '(주)현성인베스트먼트', '충청북도 충주시 칠금동', '철근도매(종합)']
# ['031-798-3501', '\t\t', '상호정보', '(주)랠리스포츠', '경기도 광주시 곤지암읍 신촌리', '스포츠웨어도매']
# ['031-743-5012', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-272-8436', '\t\t', '상호정보', '(주)랩지노믹스', '경기도 용인시 수지구 동천동', '공학연구소']
# ['02-499-1579', '\t\t', '상호정보', '레드컨테이너건대점', '서울특별시 광진구 화양동', '성인용품']
# ['02-585-8205', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-427-9481', '\t\t', '상호정보', '(주)랩지노믹스', '인천광역시 계양구 귤현동', '의학연구소']
# ['02-857-4879', '\t\t', '상호정보', '(주)러닝스페이스', '서울특별시 마포구 서교동', '인터넷교육']
# ['02-544-7510', '\t\t', '상호정보', '(주)러쉬코리아', '서울특별시 강남구 신사동', '부동산']
# ['032-551-1147', '\t\t', '상호정보', '(주)럭키쎄븐', '인천광역시 계양구 계산3동', '슈퍼마켓']
# ['063-263-8804', '\t\t', '상호정보', '(주)럭키강업', '전라북도 전주시 덕진구 송천동2가', '부동산']
# ['032-566-1212', '\t\t', '상호정보', '(주)럭키마트', '인천광역시 서구 검암동', '슈퍼마켓']
# ['032-833-0800', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2155-1799', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3445-6301', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-222-3309', '\t\t', '상호정보', '(주)레드', '충청북도 청주시 청원구 우암동', '부동산']
# ['033-435-1114', '\t\t', '상호정보', '디비지(주)', '강원도 홍천군 홍천읍 진리', '프랜차이즈']
# ['052-296-6001', '\t\t', '상호정보', '(주)럭키원일', '울산광역시 북구 진장동', '지물판매']
# ['032-515-6867', '\t\t', '상호정보', '(주)더레드락', '인천광역시 부평구 부평5동', '치킨']
# ['02-2051-7264', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-224-8620', '\t\t', '상호정보', '라인호텔', '경기도 수원시 팔달구 인계동', '모텔']
# ['02-3487-0550', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2088-3061', '\t\t', '상호정보', '(주)레드캡투어', '서울특별시 강서구 마곡동', '렌트카']
# ['02-2635-2787', '\t\t', '상호정보', '(주)레비시스', '서울특별시 마포구 상수동', '가구']
# ['031-371-5461', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-674-1623', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-583-1378', '\t\t', '상호정보', '(주)레비아이', '대구광역시 달서구 장기동', '부동산']
# ['031-557-0427', '\t\t', '상호정보', '(주)레스모아', '경기도 구리시 인창동', '신발도매(종합)']
# ['031-8017-9561', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-883-5921', '\t\t', '상호정보', '(주)레스모아', '경기도 여주시 상거동', '신발도매(종합)']
# ['033-251-2173', '\t\t', '상호정보', '(주)레스모아', '강원도 춘천시 조양동', '신발도매(종합)']
# ['031-996-6341', '\t\t', '상호정보', '(주)레스모아', '경기도 김포시 장기동', '신발도매(종합)']
# ['061-287-5766', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-566-4177', '\t\t', '상호정보', '(주)케이디베딩시스템', '서울특별시 서초구 반포동', '침대판매']
# ['062-236-1928', '\t\t', '상호정보', '(주)레스모아', '광주광역시 동구 충장로3가', '신발도매(종합)']
# ['053-253-1497', '\t\t', '상호정보', '(주)레스모아', '대구광역시 중구 동성로2가', '신발도매(종합)']
# ['02-451-7776', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-8820-1099', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-850-3223', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-761-1526', '\t\t', '상호정보', '(주)레이센', '경기도 용인시 처인구 매산리', '스포츠웨어판매']
# ['031-988-6515', '\t\t', '상호정보', '(주)레이디앤맘', '경기도 김포시 고촌읍 전호리', '내의도매']
# ['02-2642-4547', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-634-9114', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-545-4596', '\t\t', '상호정보', '(주)레이몽', '서울특별시 서초구 잠원동', '건물분양(종합)']
# ['02-419-0041', '\t\t', '상호정보', '(주)레이크인', '서울특별시 송파구 석촌동', '호텔']
# ['02-955-0552', '\t\t', '상호정보', '(주)레이앤류이', '서울특별시 도봉구 방학1동', '잡화점']
# ['02-2068-5185', '\t\t', '상호정보', '(주)레진마트', '서울특별시 영등포구 당산동1가', '합성수지도매']
# ['031-572-4499', '\t\t', '상호정보', '(주)레저월드', '경기도 남양주시 진접읍 진벌리', '의류판매(종합)']
# ['043-648-0614', '\t\t', '상호정보', '(주)레프코', '충청북도 제천시 강제동', '벽돌조적,석축공사']
# ['051-747-2938', '\t\t', '상호정보', '(주)렉스원', '부산광역시 해운대구 중동', '부동산']
# ['031-983-4753', '\t\t', '상호정보', '(주)렙쇼메이', '경기도 김포시 월곶면 갈산리', '여성의류']
# ['055-332-0098', '\t\t', '상호정보', '(주)려은', '경상남도 김해시 서상동', '부동산']
# ['031-983-4720', '\t\t', '상호정보', '(주)렙쇼메이', '경기도 김포시 월곶면 갈산리', '의류판매(종합)']
# ['02-525-5330', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2192-3331', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['063-252-5277', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-984-2926', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-936-6688', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-241-0879', '\t\t', '상호정보', '(주)로뎀이엔씨', '강원도 춘천시 효자동', '부동산']
# ['032-888-1311', '\t\t', '상호정보', '(주)로드로지스', '인천광역시 중구 신흥동3가', '부동산']
# ['02-2168-3171', '\t\t', '상호정보', '(주)로드마트', '서울특별시 양천구 목1동', '자동차부품판매(기타)']
# ['053-384-4655', '\t\t', '상호정보', '(주)로라애슐리코리아', '대구광역시 북구 검단동', '침구류도매']
# ['051-668-4147', '\t\t', '상호정보', '(주)제이에스티나', '부산광역시 동래구 온천2동', '마구류제조(종합)']
# ['053-742-4660', '\t\t', '상호정보', '(주)로라애슐리코리아', '대구광역시 수성구 범어동', '가구판매(종합)']
# ['042-933-9123', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-973-5280', '\t\t', '상호정보', '(주)로렌츠라온', '경상북도 칠곡군 북삼읍 인평리', '잡지도매']
# ['1566-0219', '\t\t', '상호정보', '바비', '전자부품도매']
# ['031-372-0166', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-730-3237', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-547-1396', '\t\t', '상호정보', '(주)로베르토앤컴퍼니', '서울특별시 강남구 삼성동', '잡화점']
# ['042-221-5009', '\t\t', '상호정보', '(주)로보쿡', '대전광역시 중구 은행동', '양식']
# ['02-792-0489', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-248-1255', '\t\t', '상호정보', '(주)로얄관광호텔', '부산광역시 중구 광복동2가', '부동산']
# ['031-559-3248', '\t\t', '상호정보', '(주)로빈힐', '경기도 남양주시 화도읍 금남리', '수입가구판매']
# ['031-687-3053', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3053', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3053', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3053', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-523-6633', '\t\t', '상호정보', '(주)로아인벤션랩', '서울특별시 서초구 서초동', '부동산']
# ['032-426-6611', '\t\t', '상호정보', '(주)로얄관광호텔', '인천광역시 남동구 간석3동', '관광호텔']
# ['031-687-3035', '\t\t', '상호정보', '지원인력(주)', '경기도 의왕시 고천동', '고용알선(종합)']
# ['031-687-3065', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3105', '\t\t', '상호정보', '동명공인중개사사무소', '경기도 이천시 대월면 대대리', '부동산']
# ['031-687-3075', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3274', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3209', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3227', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3179', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3261', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3282', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3301', '\t\t', '상호정보', '국일샷시유리', '경기도 안양시 동안구 관양동', '유리,거울판매']
# ['031-687-3334', '\t\t', '상호정보', '동양인력', '경기도 안양시 동안구 관양동', '고용알선(종합)']
# ['031-687-3450', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3349', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3780', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3480', '\t\t', '상호정보', '태진유리샷시', '경기도 의왕시 내손동', '유리,거울판매']
# ['031-687-3833', '\t\t', '상호정보', '진가구', '경기도 화성시 우정읍 조암리', '주방가구']
# ['031-687-3930', '\t\t', '스팸이력', '3개월 내 스팸신고 12건', '                \t', '텔레마케팅 8건', '대출안내 3건', '기타유형스팸 1건']
# ['031-687-3970', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3620', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3560', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-687-3982', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8042-2280', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8042-4522', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8042-4662', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8042-4866', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-279-3557', '\t\t', '상호정보', '루이까또즈셔츠롯데창원점', '경상남도 창원시 성산구 상남동', '셔츠,내의소매(종합)']
# ['031-231-6413', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-463-2447', '\t\t', '상호정보', '(주)로얄비엔비', '경기도 안양시 만안구 안양1동', '의류판매(종합)']
# ['031-8042-4887', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8042-6466', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-323-4489', '\t\t', '상호정보', '(주)로얄아트텍', '경상남도 김해시 지내동', '잡화점']
# ['053-637-7937', '\t\t', '상호정보', '(주)로얄주택', '대구광역시 수성구 시지동', '부동산']
# ['031-381-9077', '\t\t', '공유정보', '로얄마트']
# ['055-635-8576', '\t\t', '상호정보', '(주)로이젠', '경상남도 거제시 장목면 송진포리', '부동산']
# ['02-777-9906', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4603-2237', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['063-836-7184', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-364-3737', '\t\t', '상호정보', '(주)로지원', '경상남도 양산시 남부동', '기타']
# ['031-971-4183', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-508-6226', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-464-5000', '\t\t', '상호정보', '(주)로히', '경기도 안양시 동안구 호계2동', '온천']
# ['031-477-9179', '\t\t', '상호정보', '(주)로히', '경기도 안양시 동안구 호계동', '온천']
# ['031-464-8888', '\t\t', '상호정보', '(주)로히', '경기도 안양시 만안구 안양동', '온천']
# ['032-818-0025', '\t\t', '상호정보', '(주)롬퍼니쳐', '인천광역시 남동구 논현동', '목재가구제조']
# ['02-313-0451', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-730-3768', '\t\t', '상호정보', '(주)롬퍼니쳐', '부산광역시 해운대구 우동', '주방가구제조']
# ['02-706-1352', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-901-8908', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2695-3005', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-635-8696', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-279-3672', '\t\t', '상호정보', '(주)롬퍼니쳐', '경상남도 창원시 성산구 상남동', '주방가구제조']
# ['02-433-8015', '\t\t', '상호정보', '(주)루미지디자인', '서울특별시 중랑구 신내동', '인테리어']
# ['053-719-0557', '\t\t', '상호정보', '(주)롯데아이엔씨', '대구광역시 달서구 두류3동', '부동산']
# ['02-2658-5892', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3452-3917', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-558-1128', '\t\t', '상호정보', '(주)류', '서울특별시 강남구 삼성동', '부동산']
# ['02-706-3930', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-736-5314', '\t\t', '상호정보', '(주)리노기획', '서울특별시 서대문구 현저동', '부동산']
# ['031-901-2119', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-231-1771', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-387-0204', '\t\t', '상호정보', '(주)위프랜즈', '서울특별시 은평구 갈현동', '부동산']
# ['02-586-9877', '\t\t', '상호정보', '(주)리더스빌', '서울특별시 서초구 방배3동', '건물분양(종합)']
# ['031-979-0843', '\t\t', '상호정보', '(주)제이에스월드', '경기도 고양시 덕양구 행주내동', '스포츠웨어판매']
# ['02-2068-5181', '\t\t', '상호정보', '(주)리더스스타코리아', '서울특별시 구로구 신도림동', '부동산']
# ['051-747-8719', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-337-8823', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-464-1137', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-585-0551', '\t\t', '상호정보', '(주)리드앤석세스', '서울특별시 서초구 서초동', '건물분양(종합)']
# ['02-1688-4480', '\t\t', '공유정보', '리더스텍, 다나와 다케어 PC A/S']
# ['042-826-7081', '\t\t', '상호정보', '(주)리드앤석세스', '대전광역시 유성구 봉명동', '부동산']
# ['044-864-2662', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-744-8501', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-882-0858', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-636-8233', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-706-5017', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-786-6868', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-783-8901', '\t\t', '상호정보', '(주)리브로', '경기도 성남시 분당구 야탑1동', '서점']
# ['070-7788-7911', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-616-2185', '\t\t', '상호정보', '(주)리본', '광주광역시 광산구 장덕동', '의류판매(종합)']
# ['02-3474-3303', '\t\t', '상호정보', '(주)리베에코', '서울특별시 서초구 서초1동', '부동산']
# ['02-400-4945', '\t\t', '상호정보', '(주)리보에스티', '서울특별시 송파구 문정동', '부동산']
# ['053-660-3220', '\t\t', '상호정보', '(주)리본', '대구광역시 북구 칠성동2가', '여성의류도매']
# ['053-421-9872', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-891-1420', '\t\t', '공유정보', '리빙글로리']
# ['02-2118-7633', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3468-7342', '\t\t', '상호정보', '(주)리브인', '서울특별시 강남구 대치동', '부동산']
# ['1899-7560', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-238-9797', '\t\t', '상호정보', '(주)리슈랜드', '충청북도 청주시 서원구 사창동', '부동산']
# ['032-446-0607', '\t\t', '상호정보', '(주)리빙데코', '인천광역시 남동구 고잔동', '가구제조']
# ['032-624-2499', '\t\t', '상호정보', '(주)리빙우드', '경기도 부천시 삼정동', '사무용가구제조']
# ['031-966-0645', '\t\t', '상호정보', '(주)리스디씨아울렛', '경기도 고양시 덕양구 성사동', '슈퍼마켓']
# ['043-251-1000', '\t\t', '상호정보', '(주)리슈시티개발', '충청북도 청주시 서원구 개신동', '부동산']
# ['02-569-4300', '\t\t', '상호정보', '(주)리스토어', '서울특별시 광진구 자양동', '사무용가구']
# ['031-8071-3913', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-822-4995', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-441-9032', '\t\t', '상호정보', '(주)리앤컴퍼니', '경기도 안양시 만안구 안양5동', '의류판매(종합)']
# ['02-482-3346', '\t\t', '상호정보', '(주)리씨백', '서울특별시 강동구 성내동', '가방제조']
# ['070-4120-8499', '\t\t', '상호정보', '(주)리안에프앤씨', '경기도 고양시 일산서구 탄현동', '샤브샤브']
# ['02-482-3347', '\t\t', '상호정보', '(주)리씨백', '서울특별시 강동구 성내3동', '가방제조']
# ['02-2135-2999', '\t\t', '상호정보', '(주)리싸이클세상', '서울특별시 강남구 역삼동', '중고사무용가구판매']
# ['02-2135-2999', '\t\t', '상호정보', '(주)리싸이클세상', '서울특별시 강남구 역삼동', '중고사무용가구판매']
# ['02-585-2477', '\t\t', '상호정보', '(주)리앤콤', '서울특별시 서초구 서초3동', '관리사무소']
# ['031-640-8900', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-823-3300', '\t\t', '상호정보', '(주)리얼티디자인', '서울특별시 동작구 노량진동', '부동산']
# ['02-539-3224', '\t\t', '상호정보', '(주)리얼탑코리아', '서울특별시 강남구 역삼동', '부동산']
# ['055-688-5660', '\t\t', '상호정보', '(주)리오그릴', '경상남도 거제시 옥포1동', '양식']
# ['02-586-5403', '\t\t', '상호정보', '정겨운집', '서울특별시 서초구 서초동', '한식']
# ['031-337-7333', '\t\t', '상호정보', '(주)리얼플랜', '경기도 안양시 동안구 관양동', '건물분양(기타)']
# ['044-864-3173', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-567-3667', '\t\t', '상호정보', '강남역센트럴푸르지오시티관리사무소', '서울특별시 강남구 역삼동', '관리사무소']
# ['02-722-3077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2214-7799', '\t\t', '상호정보', '(주)리오부동산중개법인', '서울특별시 동대문구 장안동', '부동산']
# ['042-551-0600', '\t\t', '상호정보', '서울떡집', '충청남도 계룡시 엄사면 엄사리', '떡집']
# ['02-333-8995', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-558-4090', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-637-0941', '\t\t', '상호정보', '(주)리즈', '부산광역시 동구 범일2동', '액세서리제조']
# ['02-584-2751', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-514-7544', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-457-4040', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-979-1306', '\t\t', '상호정보', '(주)리차드미용실', '경기도 고양시 덕양구 화정동', '미용실']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
len(result2)
# Out:
# 407

# %%
result2 = pd.DataFrame(result2, columns = ['phone_num', 'co_name_rr','addr', 'cate'])
result2
# Out:
#          phone_num         co_name_rr              addr       cate
# 0     031-314-8209            마이드림하우스
# 1      02-838-1676            (주)드림시티     서울특별시 금천구 가산동   의류판매(종합)
# 2      07077661470
# 3     051-743-7760       (주)드림월드관리사무실     부산광역시 해운대구 우동      관리사무소
# 4     053-527-0144          (주)드림이노테크      대구광역시 중구 달성동     직장위탁교육
# 5       0323279061
# 6     031-888-6380          알보젠코리아연구소   경기도 수원시 영통구 이의동      의약품제조
# 7       0322809111
# 8        023557775
# 9     053-741-3908              (주)디딤     대구광역시 남구 봉덕3동      관리사무소
# 10    031-768-1224             (주)등용문   경기도 광주시 초월읍 지월리     학원(종합)
# 11    031-768-1224             (주)등용문   경기도 광주시 초월읍 지월리     학원(종합)
# 12      0317643910
# 13    033-746-3884          (주)디.에스.씨       강원도 원주시 단계동        부동산
# 14    041-358-2870             (주)디덴탈      충청남도 당진시 읍내동      의학연구소
# 15      0317694471
# 16    033-243-0471           (주)디딤돌건설       강원도 춘천시 운교동    건설업(종합)
# 17       027857310
# 18       028710965
# 19    054-254-0779        디에떼에스프레소양덕점   경상북도 포항시 북구 양덕동         카페
# 20     02-458-2502         (주)디멘션아이이지     서울특별시 광진구 광장동       인테리어
# 21    055-973-4602        (주)디럭스테크놀러지  경상남도 산청군 금서면 매촌리    스포츠웨어도매
# 22    02-2677-8730           (주)디멘파이브  서울특별시 영등포구 당산동3가        부동산
# 23    055-757-2323           (주)디럭스개발      경상남도 진주시 상대동      관리사무소
# 24     02-561-1385          (주)디딤돌이엔씨    서울특별시 강남구 역삼1동       미술학원
# 25    064-739-8421             (주)디딤인  제주특별자치도 서귀포시 강정동  의복,액세서리도매
# 26       023530199
# 27     02-562-2888             (주)디벨코     서울특별시 강남구 신사동        부동산
# 28    02-2695-9091            (주)디베스트    서울특별시 양천구 신월5동       슈퍼마켓
# 29      0417421170
# ..             ...                ...               ...        ...
# 377   031-966-0645         (주)리스디씨아울렛   경기도 고양시 덕양구 성사동       슈퍼마켓
# 378   043-251-1000          (주)리슈시티개발  충청북도 청주시 서원구 개신동        부동산
# 379    02-569-4300            (주)리스토어     서울특별시 광진구 자양동      사무용가구
# 380    03180713913
# 381     0428224995
# 382   031-441-9032           (주)리앤컴퍼니  경기도 안양시 만안구 안양5동   의류판매(종합)
# 383    02-482-3346             (주)리씨백     서울특별시 강동구 성내동       가방제조
# 384  070-4120-8499          (주)리안에프앤씨  경기도 고양시 일산서구 탄현동       샤브샤브
# 385    02-482-3347             (주)리씨백    서울특별시 강동구 성내3동       가방제조
# 386   02-2135-2999          (주)리싸이클세상     서울특별시 강남구 역삼동  중고사무용가구판매
# 387   02-2135-2999          (주)리싸이클세상     서울특별시 강남구 역삼동  중고사무용가구판매
# 388    02-585-2477             (주)리앤콤    서울특별시 서초구 서초3동      관리사무소
# 389     0316408900
# 390    02-823-3300          (주)리얼티디자인    서울특별시 동작구 노량진동        부동산
# 391    02-539-3224          (주)리얼탑코리아     서울특별시 강남구 역삼동        부동산
# 392   055-688-5660            (주)리오그릴     경상남도 거제시 옥포1동         양식
# 393    02-586-5403               정겨운집     서울특별시 서초구 서초동         한식
# 394   031-337-7333            (주)리얼플랜   경기도 안양시 동안구 관양동   건물분양(기타)
# 395     0448643173
# 396    02-567-3667  강남역센트럴푸르지오시티관리사무소     서울특별시 강남구 역삼동      관리사무소
# 397      027223077
# 398   02-2214-7799       (주)리오부동산중개법인    서울특별시 동대문구 장안동        부동산
# 399   042-551-0600               서울떡집  충청남도 계룡시 엄사면 엄사리         떡집
# 400      023338995
# 401      025584090
# 402   051-637-0941              (주)리즈     부산광역시 동구 범일2동     액세서리제조
# 403      025842751
# 404      025147544
# 405      024574040
# 406   031-979-1306          (주)리차드미용실   경기도 고양시 덕양구 화정동        미용실
#
# [407 rows x 4 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium
import json
from urllib.request import urlopen

# %%
test = pd.read_pickle('company_test.pkl')
test = test[20001:30000]

# %%
# %%time
result = []
count = 0
for phone_num in test['REP_PHONE_NUM']:
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(2)
    html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
    
    data = urlopen(html)
    resp = json.loads(data.read())
    r = pd.DataFrame(resp)
    r = pd.DataFrame(r['data'][0])
    if r['results']['totalCount'] == 0:
        info = []
        info.append(phone_num)
        info.append('')
        info.append('')
        info.append('')
        info.append('')
        info.append('')
        continue
    else:
        r = pd.DataFrame(r['results']['result'])
        r = pd.DataFrame(r['field'][0])
        info = []
        info.append(r['value'][1])
        info.append(r['value'][2])
        info.append(r['value'][3])
        info.append(r['value'][7])
        info.append(r['value'][8])
        info.append(r['value'][9])
        result.append(info)
    count+=1
# Out:
# running... 0622343311 0.0
# running... 0553315999 1.0
# running... 0536519989 2.0
# running... 0314179393 3.0
# running... 0415554546 4.0
# running... 0613337878 5.0
# running... 024719922 6.0
# running... 0522469945 7.0
# running... 024705322 8.0
# running... 0432181935 8.0
# running... 07087781391 9.0
# running... 0536218585 9.0
# running... 0322151969 10.0
# running... 07077175861 11.0
# running... 01026162115 11.0
# running... 0542328856 11.0
# running... 01045369226 11.0
# running... 0236611925 11.0
# running... 0221830440 11.0
# running... 0234423618 12.0
# running... 0315591877 12.0
# running... 0269293535 12.0
# running... 0315747904 12.0
# running... 024124556 12.0
# running... 0629591963 12.0
# running... 0634670553 13.0
# running... 0263331062 14.0
# running... 0263332525 14.0
# running... 0317190333 14.0
# running... 0617252616 14.0
# running... 0315849070 15.0
# running... 03246655805 15.0
# running... 0324223656 15.0
# running... 0324225173 15.0
# running... 0324263345 15.0
# running... 0324334213 15.0
# running... 0325458321 16.0
# running... 0325522058 16.0
# running... 07088705025 16.0
# running... 0325479170 16.0
# running... 0325533663 17.0
# running... 0324617322 17.0
# running... 0324265827 17.0
# running... 03246388845 17.0
# running... 024667731 17.0
# running... 0312088660 18.0
# running... 029489220 18.0
# running... 029372155 18.0
# running... 029340559 18.0
# running... 07075190142 19.0
# running... 028337600 19.0
# running... 029569552 19.0
# running... 07077479544 20.0
# running... 05222100747 20.0
# running... 0614533880 20.0
# running... 0323620132 21.0
# running... 0326236116 21.0
# running... 025843536 22.0
# running... 025329074 22.0
# running... 0234716289 22.0
# running... 025789078 22.0
# running... 025250790 22.0
# running... 025220528 22.0
# running... 025879151 22.0
# running... 025887595 22.0
# running... 025324487 22.0
# running... 0234729651 22.0
# running... 025816240 22.0
# running... 0312034045 23.0
# running... 0312517838 23.0
# running... 0312342257 23.0
# running... 0312455589 23.0
# running... 0314082353 24.0
# running... 0314060151 24.0
# running... 0314020093 24.0
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\anaconda\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\anaconda\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# C:\anaconda\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# C:\anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <timed exec> in <module>()
#
# C:\anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\anaconda\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\anaconda\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다>
