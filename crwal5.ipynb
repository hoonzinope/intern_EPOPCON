# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium

test = pd.read_pickle('company_test.pkl')
test = test[8001:10000]
path = 'C:\chromedriver.exe'

# %%
# %%time
driver2 = webdriver.Chrome(path)
result2 = []
for phone_num in test.REP_PHONE_NUM:
    driver2.get('https://www.whox2.com/view/main.jsp')
    driver2.implicitly_wait(3)
    input = driver2.find_element_by_id("search")
    driver2.implicitly_wait(3)
    input.clear()
    driver2.implicitly_wait(3)
    input.send_keys(phone_num)
    driver2.implicitly_wait(3)
    input.send_keys(keys.Keys.ENTER)
    html = driver2.page_source
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.find('dl').get_text().split('\n')
    while True:
        try:
            text.remove("")
        except ValueError:
            break
    print(text)
    for t in text:
        if '검색결과가 없습니다.' in t:
            text = [phone_num,'','','','','','']
    info = []
    info.append(text[0])
    info.append(text[3])
    if len(text) < 5:
        info.append('')
        info.append('')
    else:
        info.append(text[4])
        if len(text) < 6:
            info.append("")
        else:
            info.append(text[5])
    result2.append(info)
result2 = pd.DataFrame(result2, columns = ['phone_num', 'co_name_rr','addr', 'cate'])
result2
# Out:
# ['032-547-5500', '\t\t', '상호정보', '태영로드산업(주)', '인천광역시 계양구 계산1동', '토지정지공사', '스팸이력', '3개월 내 스팸신고 46건', '                \t', '성인, 유흥 33건', '텔레마케팅 6건', '기타유형스팸 4건']
# ['02-485-0902', '\t\t', '상호정보', '(주)서경산업개발', '서울특별시 강동구 성내동', '건설업(종합)']
# ['02-433-3105', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-819-8263', '\t\t', '상호정보', '(주)서광까뜨리네뜨본사', '서울특별시 금천구 가산동', '액세서리소매(종합)']
# ['063-461-6930', '\t\t', '상호정보', '(주)서강에스엘피영어학당', '전라북도 군산시 수송동', '영어학원']
# ['053-327-0311', '\t\t', '상호정보', '(주)서교', '대구광역시 북구 팔달동', '수학학원']
# ['02-725-8340', '\t\t', '상호정보', '(주)서광이엔씨', '서울특별시 서대문구 홍제동', '관리사무소']
# ['031-256-1412', '\t\t', '상호정보', '(주)서로좋은가게', '경기도 수원시 장안구 정자동', '잡화점']
# ['02-2067-2179', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-257-2600', '\t\t', '상호정보', '(주)서농', '강원도 춘천시 효자1동', '곡물종자도매(종합)']
# ['032-866-5644', '\t\t', '상호정보', '(주)서남', '인천광역시 남구 학익동', '부동산']
# ['042-824-5133', '\t\t', '상호정보', '(주)서림', '대전광역시 유성구 노은동', '부동산']
# ['02-512-0196', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-633-3355', '\t\t', '상호정보', '육봉달333', '대구광역시 달서구 진천동', '한식']
# ['02-2608-8125', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-318-2715', '\t\t', '상호정보', '쌀빵', '서울특별시 중구 태평로2가', '제과점']
# ['055-326-9481', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-635-0633', '\t\t', '상호정보', '(주)서보디앤씨', '대구광역시 달서구 월성2동', '상가분양']
# ['055-266-0111', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-521-9600', '\t\t', '상호정보', '(주)서보사', '서울특별시 서초구 서초3동', '사무실임대']
# ['032-456-4010', '\t\t', '상호정보', '(주)서부티엔디', '인천광역시 연수구 동춘동', '쇼핑센터임대']
# ['032-456-4114', '\t\t', '상호정보', '(주)서부티엔디', '인천광역시 연수구 동춘동', '부동산']
# ['02-486-9935', '\t\t', '상호정보', '(주)서보통상', '서울특별시 강동구 천호동', '액세서리판매']
# ['02-2049-7766', '\t\t', '상호정보', '(주)서브원', '서울특별시 광진구 광장동', '관리사무소']
# ['02-704-5858', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3436-5559', '\t\t', '상호정보', '(주)서브원', '서울특별시 광진구 화양동', '비주거용건물임대(종합)']
# ['02-373-1600', '\t\t', '상호정보', '(주)서부흥업', '서울특별시 은평구 수색동', '주차장']
# ['042-533-9196', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-376-0201', '\t\t', '상호정보', '(주)서브원', '서울특별시 마포구 상암동', '부동산']
# ['041-753-1597', '\t\t', '상호정보', '(주)서브원', '충청남도 금산군 제원면 명암리', '부동산']
# ['02-822-1175', '\t\t', '상호정보', '(주)서브원', '서울특별시 동작구 흑석동', '부동산']
# ['032-872-0318', '\t\t', '상호정보', '(주)서브원', '인천광역시 남구 용현동', '부동산']
# ['02-3442-2458', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-935-5826', '\t\t', '상호정보', '(주)서브원', '대전광역시 대덕구 신일동', '부동산']
# ['032-325-7391', '\t\t', '상호정보', '(주)서빈TSC', '경기도 부천시 원미구 상2동', '관리사무소']
# ['042-934-1558', '\t\t', '상호정보', '(주)서브원', '대전광역시 대덕구 목상동', '부동산']
# ['02-575-4661', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-410-5678', '\t\t', '상호정보', '(주)서연미디어', '경기도 안산시 상록구 사이[사2동]', '의류판매(종합)']
# ['061-723-6932', '\t\t', '상호정보', '(주)서연', '전라남도 순천시 연향동', '건물분양(종합)']
# ['070-4250-6801', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-405-0278', '\t\t', '상호정보', '(주)서연미디어', '경기도 안산시 단원구 초지동', '의류판매(종합)']
# ['02-714-2933', '\t\t', '상호정보', '(주)서연씨엠씨', '서울특별시 용산구 서계동', '부동산']
# ['070-8891-6284', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-747-8029', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-899-8893', '\t\t', '상호정보', '(주)서연테크', '경기도 광명시 소하동', '관리사무소']
# ['02-771-6889', '\t\t', '상호정보', '(주)서영개발', '서울특별시 중구 서소문동', '부동산']
# ['051-506-5504', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['063-288-0555', '\t\t', '상호정보', '(주)서영주택지안리즈아파트관리사무소', '전라북도 전주시 완산구 평화동1가', '관리사무소']
# ['031-8016-3396', '\t\t', '공유정보', '보령마트']
# ['031-761-7029', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-722-2881', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-556-7118', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-232-8377', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-710-7111', '\t\t', '상호정보', '(주)서울가든', '서울특별시 마포구 도화동', '관광호텔']
# ['031-759-5542', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-741-8119', '\t\t', '상호정보', '(주)서울동물병원', '경기도 성남시 중원구 금광1동', '동물병원']
# ['031-889-2059', '\t\t', '상호정보', '(주)서울나무병원', '경기도 용인시 수지구 죽전동', '건설업(종합)']
# ['02-374-8244', '\t\t', '상호정보', '(주)서울에스엔에스', '서울특별시 중랑구 중화동', '잡화점']
# ['02-3445-0182', '\t\t', '상호정보', '(주)서울씨알오', '서울특별시 강남구 역삼동', '임상병리과']
# ['02-548-1899', '\t\t', '상호정보', '(주)서울비젼', '서울특별시 강남구 논현동', '광고물제작(종합)']
# ['02-552-7870', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02
'\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3446-5316', '\t\t', '상호정보', '(주)석노', '서울특별시 강남구 압구정동', '액세서리제조']
# ['032-422-4976', '\t\t', '상호정보', '석바위지하상가', '인천광역시 남구 주안6동', '관리사무소']
# ['02-832-1241', '\t\t', '상호정보', '(주)석봉토스트', '서울특별시 영등포구 신길1동', '토스트']
# ['063-468-9810', '\t\t', '상호정보', '(주)서흥건설', '전라북도 군산시 지곡동', '관리사무소']
# ['032-321-0360', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-743-9501', '\t\t', '상호정보', '(주)석우건설', '대구광역시 동구 신천3동', '관리사무소']
# ['02-3443-5313', '\t\t', '상호정보', '(주)석우인터내셔널', '서울특별시 강남구 삼성동', '인테리어']
# ['051-506-2798', '\t\t', '상호정보', '(주)석은', '부산광역시 연제구 거제1동', '단독주택임대']
# ['062-221-1169', '\t\t', '공유정보', '롯데백화점샤링']
# ['053-381-7733', '\t\t', '상호정보', '(주)석주', '대구광역시 북구 산격2동', '실내골프연습장']
# ['053-742-1266', '\t\t', '상호정보', '(주)석천', '대구광역시 수성구 만촌3동', '부동산']
# ['063-221-2087', '\t\t', '상호정보', '(주)석탑', '전라북도 전주시 완산구 효자동3가', '부동산']
# ['053-383-0707', '\t\t', '상호정보', '(주)석주', '대구광역시 북구 산격동', '실내골프연습장']
# ['033-434-0043', '\t\t', '상호정보', '(주)석화', '강원도 홍천군 홍천읍 진리', '부동산']
# ['031-478-4433', '\t\t', '상호정보', '(주)선경알지피', '경기도 안양시 동안구 평촌동', '안경렌즈제조']
# ['02-3397-3742', '\t\t', '상호정보', '(주)선경홀로그램', '서울특별시 금천구 가산동', '사무실임대']
# ['042-222-2148', '\t\t', '상호정보', '(주)선광패브릭', '대전광역시 동구 원동', '침구류도매']
# ['042-252-2612', '\t\t', '상호정보', '(주)선광패브릭', '대전광역시 중구 부사동', '침구류도매']
# ['053-753-0405', '\t\t', '상호정보', '(주)선남개발', '대구광역시 수성구 범어3동', '부동산']
# ['042-252-2612', '\t\t', '상호정보', '(주)선광패브릭', '대전광역시 중구 부사동', '침구류도매']
# ['070-4251-7776', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-507-9634', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-793-2153', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-574-7417', '\t\t', '상호정보', '(주)선메딕스', '경기도 남양주시 진접읍 팔야리', '의료용품도매(종합)']
# ['043-652-8373', '\t\t', '상호정보', 'KS테크', '충청북도 제천시 강제동', '산업용기계장비무역']
# ['032-565-0422', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3775-4777', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-416-0838', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-503-4131', '\t\t', '상호정보', '(주)선암에너지판매', '경기도 과천시 과천동', '주유소']
# ['042-528-0071', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-402-0808', '\t\t', '상호정보', '(주)선우마트', '경기도 안산시 단원구 와동', '슈퍼마켓']
# ['031-402-3838', '\t\t', '상호정보', '(주)선우마트', '경기도 안산시 단원구 와동', '슈퍼마켓']
# ['053-741-7676', '\t\t', '공유정보', '누들맨범어점']
# ['064-722-6330', '\t\t', '상호정보', '(주)선우메디칼', '제주특별자치도 제주시 일도1동', '부동산']
# ['055-337-4581', '\t\t', '상호정보', '(주)선익', '경상남도 김해시 대청동', '관리사무소']
# ['054-843-4580', '\t\t', '상호정보', '(주)선익구조안전연구소', '경상북도 안동시 천리동', '건축,엔지니어링,기술서비스(기타)']
# ['02-2213-2708', '\t\t', '상호정보', '(주)선재향', '서울특별시 성동구 용답동', '부동산']
# ['031-922-0733', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-325-0885', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-646-7204', '\t\t', '상호정보', '(주)선진', '충청북도 제천시 신백동', '간판제작(종합)']
# ['02-423-2995', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-462-3012', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-311-4748', '\t\t', '상호정보', '(주)선진디자인테크', '부산광역시 동래구 사직동', '인테리어']
# ['052-256-2670', '\t\t', '상호정보', '영천돼지국밥', '울산광역시 남구 신정동', '한식']
# ['031-477-2400', '\t\t', '상호정보', '(주)선진산업개발', '경기도 안양시 동안구 호계2동', '건물분양(기타)']
# ['02-485-8621', '\t\t', '상호정보', '(주)선진알앤디', '서울특별시 강동구 길동', '관리사무소']
# ['032-746-4135', '\t\t', '상호정보', '(주)선진알앤디', '인천광역시 중구 운서동', '관리사무소']
# ['055-298-1600', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4630', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4630', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4630', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4631', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4632', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4633', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4635', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4634', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4646', '\t\t', '상호정보', '오빠대리운전,오빠잔심부름', '충청북도 음성군 대소면 오류리', '대리운전']
# ['070-7385-4647', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4960', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4961', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4962', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4964', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4963', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4965', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4968', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4966', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4969', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4970', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4971', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4973', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4978', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4979', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4975', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4974', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4982', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4981', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4980', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4983', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4984', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4986', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4988', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4989', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4993', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4991', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4994', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4995', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4998', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4997', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7385-4999', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-511-1863', '\t\t', '상호정보', '(주)선창인터내쇼날', '인천광역시 부평구 부평1동', '장식용품도매']
# ['031-453-0270', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-513-7711', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-637-2121', '\t\t', '상호정보', '(주)설악안전서비스', '강원도 속초시 동명동', '관리사무소']
# ['053-524-3578', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-556-3083', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-766-1177', '\t\t', '스팸이력', '3개월 내 스팸신고 12건', '                \t', '기타유형스팸 8건', '텔레마케팅 4건', '공유정보', '성경마트', '성경기업마트']
# ['02-2209-5131', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-556-9607', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-363-0057', '\t\t', '상호정보', '세종석유성광주유소', '경상남도 양산시 북정동', '주유소']
# ['054-955-0916', '\t\t', '상호정보', '(주)성광목재산업', '경상북도 고령군 개진면 반운리', '가구장식품제조']
# ['055-342-4198', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-350-7351', '\t\t', '상호정보', '(주)성광에스엠', '서울특별시 은평구 대조동', '부동산']
# ['051-752-2152', '\t\t', '상호정보', '(주)성광옵틱', '부산광역시 수영구 광안동', '안경부속품제조']
# ['062-952-6661', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-755-3345', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-604-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-608-7077', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-533-8556', '\t\t', '상호정보', '(주)성동', '경상남도 창녕군 창녕읍 교리', '부동산']
# ['061-283-7757', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-821-2111', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-533-8889', '\t\t', '상호정보', '(주)성동', '경상남도 창녕군 창녕읍 교리', '건물건설(종합)']
# ['032-428-6201', '\t\t', '상호정보', '(주)성록', '인천광역시 남동구 구월1동', '부동산']
# ['070-8817-9881', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-863-9996', '\t\t', '상호정보', '(주)성림개발', '부산광역시 부산진구 양정2동', '부동산']
# ['032-324-1649', '\t\t', '상호정보', '(주)성록', '경기도 부천시 원미구 상3동', '관리사무소']
# ['053-983-7100', '\t\t', '상호정보', '(주)성림개발', '대구광역시 동구 봉무동', '부동산']
# ['032-811-9210', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031
'\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-960-0009', '\t\t', '상호정보', '(주)성정', '서울특별시 동대문구 휘경동', '가구']
# ['055-247-2311', '\t\t', '상호정보', '(주)성주', '경상남도 창원시 마산합포구 산호동', '부동산']
# ['051-723-2093', '\t\t', '상호정보', '(주)성제', '부산광역시 기장군 기장읍 대라리', '상점임대']
# ['051-759-3700', '\t\t', '상호정보', '(주)케이원스', '부산광역시 수영구 광안동', '통신,방송장비제조(종합)']
# ['043-652-8464', '\t\t', '상호정보', '(주)성주건설', '충청북도 제천시 화산동', '철근콘크리트공사']
# ['02-2194-6719', '\t\t', '상호정보', '(주)성주디앤디', '서울특별시 강남구 청담동', '마구류제조(종합)']
# ['02-2194-6719', '\t\t', '상호정보', '(주)성주디앤디', '서울특별시 강남구 청담동', '마구류제조(종합)']
# ['02-2194-6728', '\t\t', '상호정보', '(주)성주디앤디', '서울특별시 강남구 청담1동', '마구류제조(종합)']
# ['02-541-6519', '\t\t', '상호정보', '(주)성주디앤디', '서울특별시 강남구 압구정동', '핸드백제조']
# ['02-2658-8175', '\t\t', '상호정보', '(주)성준무역', '서울특별시 강서구 가양1동', '마구류제조(종합)']
# ['053-609-2574', '\t\t', '상호정보', '(주)성주디앤디', '대구광역시 중구 사일동', '마구류제조(종합)']
# ['02-972-3784', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-867-1199', '\t\t', '상호정보', '(주)성지씨앤디', '부산광역시 수영구 광안동', '부동산']
# ['053-943-5931', '\t\t', '상호정보', '(주)성지주택무궁맨션관리소', '대구광역시 북구 대현동', '관리사무소']
# ['044-868-6773', '\t\t', '상호정보', '(주)성진디엔씨', '세종특별자치시 소담동', '부동산']
# ['02-890-8372', '\t\t', '상호정보', '(주)성진씨에이', '서울특별시 구로구 구로동', '가구장식품제조']
# ['041-681-9883', '\t\t', '상호정보', '(주)성진아이비이에스', '충청남도 서산시 동문동', '관리사무소']
# ['041-681-9884', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2217-5507', '\t\t', '상호정보', '(주)성진아이앤씨', '서울특별시 동대문구 장안2동', '액세서리제조']
# ['02-436-5833', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-908-5721', '\t\t', '상호정보', '성진엠디', '경기도 고양시 일산동구 장항동', '철구조물제조']
# ['051-342-6420', '\t\t', '상호정보', '(주)성진주택건설', '부산광역시 동래구 온천동', '주택공급']
# ['063-247-0709', '\t\t', '상호정보', '성하개발', '전라북도 전주시 완산구 고사동', '골프장']
# ['02-338-2495', '\t\t', '상호정보', '(주)성창트레스코포레이션', '서울특별시 관악구 남현동', '가발제조']
# ['031-719-2055', '\t\t', '상호정보', '(주)성학', '경기도 광주시 오포읍 능평리', '입시학원']
# ['051-302-0027', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-544-7588', '\t\t', '상호정보', '(주)성한', '서울특별시 서초구 잠원동', '부동산']
# ['032-574-5551', '\t\t', '상호정보', '(주)성한', '인천광역시 서구 가좌동', '목욕탕,사우나']
# ['051-302-6655', '\t\t', '상호정보', '(주)성한화학', '부산광역시 사상구 삼락동', '신발제조(종합)']
# ['051-518-2897', '\t\t', '상호정보', '(주)성한기업', '부산광역시 금정구 부곡3동', '부동산']
# ['043-645-7981', '\t\t', '상호정보', '(주)성현건설', '충청북도 제천시 모산동', '건설업(종합)']
# ['02-809-9407', '\t\t', '상호정보', '(주)성현에셋', '서울특별시 금천구 독산동', '부동산']
# ['051-257-9458', '\t\t', '상호정보', '(주)성화디앤씨', '부산광역시 중구 창선동1가', '부동산']
# ['054-632-0602', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-402-4455', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2157-6701', '\t\t', '상호정보', '(주)성화텍스', '서울특별시 송파구 문정동', '가방제조']
# ['054-277-9595', '\t\t', '상호정보', '(주)성희개발', '경상북도 포항시 남구 대잠동', '부동산']
# ['054-272-5335', '\t\t', '상호정보', '(주)성희개발', '경상북도 포항시 남구 효자동', '부동산']
# ['033-262-1331', '\t\t', '상호정보', '(주)세경할인마트', '강원도 춘천시 석사동', '슈퍼마켓']
# ['031-986-0663', '\t\t', '상호정보', '(주)세계로더블유스토어', '경기도 김포시 양촌읍 양곡리', '슈퍼마켓']
# ['053-421-9173', '\t\t', '상호정보', '(주)세경', '대구광역시 중구 공평동', '비주거용건물임대(종합)']
# ['02-955-3293', '\t\t', '상호정보', '(주)세계로마트', '서울특별시 도봉구 방학2동', '슈퍼마켓']
# ['054-459-0502', '\t\t', '상호정보', '(주)세계물산(AB.F.Z)', '경상북도 구미시 송정동', '의류판매(종합)']
# ['031-986-0831', '\t\t', '상호정보', '세계로마트장기점', '경기도 김포시 장기동', '슈퍼마켓']
# ['02-391-0143', '\t\t', '상호정보', '(주)세계엠앤에이', '서울특별시 종로구 평창동', '부동산']
# ['02-2668-2611', '\t\t', '상호정보', '(주)세고산업', '서울특별시 강서구 등촌동', '사무실임대']
# ['043-847-8066', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-521-0455', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-623-6390', '\t\t', '상호정보', '(주)세기알앤디', '인천광역시 부평구 청천동', '부동산']
# ['032-623-6390', '\t\t', '상호정보', '(주)세기알앤디', '인천광역시 부평구 청천동', '부동산']
# ['055-346-7595', '\t\t', '상호정보', '(주)세동정밀', '경상남도 김해시 한림면 안하리', '선박수리']
# ['031-605-9590', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-532-9749', '\t\t', '상호정보', '(주)세라터', '강원도 동해시 천곡동', '캠프장']
# ['070-8835-5204', '\t\t', '상호정보', '(주)세리엔지니어링', '강원도 원주시 관설동', '정보통신기기수리']
# ['055-332-0972', '\t\t', '상호정보', '(주)세루', '경상남도 김해시 서상동', '관리사무소']
# ['054-286-4400', '\t\t', '상호정보', '(주)세림', '경상북도 포항시 남구 동문리', '남성의류도매']
# ['053-811-4352', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-254-0606', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2667-1020', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-784-3330', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-539-0141', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-583-1701', '\t\t', '상호정보', '(주)세명실업', '서울특별시 서초구 방배1동', '비주거용건물임대(종합)']
# ['031-796-4056', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4265-0040', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-731-1500', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-742-2999', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02
'\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-866-0197', '\t\t', '상호정보', '(주)세움', '세종특별자치시 나성동', '관리사무소']
# ['02-508-1022', '\t\t', '상호정보', '(주)세움에이엠씨', '서울특별시 강남구 역삼동', '부동산']
# ['052-716-1050', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-988-3088', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-442-9445', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-8889-3050', '\t\t', '상호정보', '(주)세웅산업개발', '울산광역시 남구 신정5동', '부동산']
# ['032-511-1122', '\t\t', '상호정보', '(주)세원글로벌', '인천광역시 부평구 청천동', '부동산']
# ['055-324-0301', '\t\t', '상호정보', '(주)세원럭키', '경상남도 김해시 화목동', '인테리어']
# ['061-720-5188', '\t\t', '상호정보', '(주)세원상사', '전라남도 순천시 조례동', '양말도매']
# ['02-466-4557', '\t\t', '상호정보', '에스이아이(S.E.I)', '서울특별시 강남구 청담동', '부동산']
# ['02-541-7086', '\t\t', '상호정보', '(주)세원아이티씨', '서울특별시 강남구 압구정동', '잡화점']
# ['02-598-6872', '\t\t', '상호정보', '(주)세원엘디', '서울특별시 서초구 서초동', '의약품도매(종합)']
# ['02-598-6876', '\t\t', '상호정보', '(주)세원엘디', '서울특별시 서초구 서초동', '의약품도매(종합)']
# ['02-805-1500', '\t\t', '상호정보', '(주)세원합성', '서울특별시 금천구 독산동', '주형,금형제조']
# ['02-501-3986', '\t\t', '상호정보', '(주)세원홀딩스', '서울특별시 강남구 역삼동', '안경원']
# ['062-974-0777', '\t\t', '상호정보', '(주)세이글로벌', '광주광역시 광산구 월계동', '중국어학원']
# ['064-751-8861', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-521-2959', '\t\t', '상호정보', '소원암', '경상남도 창녕군 계성면 계성리', '종교단체']
# ['051-301-5929', '\t\t', '상호정보', '(주)세윤산업', '부산광역시 사상구 삼락동', '신발제조(종합)']
# ['051-506-6001', '\t\t', '상호정보', '(주)세은', '부산광역시 동래구 사직동', '부동산']
# ['063-231-0555', '\t\t', '상호정보', '(주)세이브존아이앤씨', '전라북도 전주시 완산구 서노송동', '백화점']
# ['031-962-5433', '\t\t', '상호정보', '(주)세이브', '경기도 고양시 덕양구 벽제동', '가정용연료소매(종합)']
# ['02-463-0700', '\t\t', '상호정보', '(주)세이노', '서울특별시 금천구 가산동', '부동산']
# ['02-463-0700', '\t\t', '상호정보', '(주)세이노', '서울특별시 금천구 가산동', '부동산']
# ['02-463-0700', '\t\t', '상호정보', '(주)세이노', '서울특별시 금천구 가산동', '부동산']
# ['02-795-6115', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-972-5570', '\t\t', '상호정보', '(주)세이프티글러브', '경상북도 칠곡군 가산면 학상리', '장갑제조']
# ['02-587-4586', '\t\t', '상호정보', '(주)세일디자인', '서울특별시 서초구 서초동', '인테리어']
# ['051-583-5763', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-216-2347', '\t\t', '상호정보', '(주)세일하이텍연구소', '충청북도 청주시 청원구 오창면 양청리', '접착테이프제조']
# ['032-573-1584', '\t\t', '상호정보', '세일마트', '인천광역시 서구 가좌2동', '슈퍼마켓']
# ['031-295-0611', '\t\t', '상호정보', '(주)세인', '경기도 수원시 권선구 평동', '렌트카']
# ['055-370-1800', '\t\t', '상호정보', '(주)세정어패럴', '경상남도 양산시 소주동', '의복,액세서리도매']
# ['02-2207-7520', '\t\t', '상호정보', '(주)세정유알씨', '서울특별시 중랑구 중화동', '관리사무소']
# ['062-955-1444', '\t\t', '상호정보', '(주)세종TS', '광주광역시 광산구 오선동', '벨트제조']
# ['063-833-5540', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-863-8853', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4113-5999', '\t\t', '상호정보', '(주)세종메디아', '충청북도 청주시 흥덕구 송정동', '바이오,미생물연구개발']
# ['044-866-5885', '\t\t', '상호정보', '(주)세종시티2030', '세종특별자치시 도담동', '부동산']
# ['1599-2283', '\t\t', '상호정보', '(주)세종세계관광', '여행사']
# ['044-867-8845', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-766-1816', '\t\t', '상호정보', '(주)세종문고', '경기도 광주시 오포읍 추자리', '서점']
# ['042-824-8993', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-888-5605', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-863-9070', '\t\t', '공유정보', '세종비에이치개발']
# ['063-229-0180', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-269-6000', '\t\t', '상호정보', '(주)세종종합관리', '광주광역시 북구 우산동', '관리사무소']
# ['043-239-2131', '\t\t', '공유정보', '세종코리아']
# ['063-543-7416', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['044-867-7070', '\t\t', '상호정보', '(주)세종이엠씨', '세종특별자치시 장군면 도계리', '부동산']
# ['02-457-4356', '\t\t', '상호정보', '(주)세종에스엠에스', '서울특별시 광진구 구의동', '한식']
# ['054-338-7118', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-651-2005', '\t\t', '상호정보', '(주)세중건설', '충청북도 제천시 신백동', '철근콘크리트공사']
# ['032-561-9286', '\t\t', '상호정보', '(주)세중', '인천광역시 서구 당하동', '가구주문제작']
# ['054-443-2130', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-601-3913', '\t\t', '상호정보', '(주)세창', '대전광역시 서구 괴정동', '부동산']
# ['02-812-4820', '\t\t', '상호정보', '(주)세창씨앤디', '서울특별시 동작구 대방동', '부동산']
# ['070-4280-6062', '\t\t', '상호정보', '(주)세진에프엔디', '인천광역시 서구 왕길동', '홀딩도어']
# ['02-476-0168', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-635-1277', '\t\t', '상호정보', '(주)복있는사람들', '충청남도 홍성군 홍북면 신경리', '전기전자공학엔지니어링']
# ['041-635-1270', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-586-0762', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-586-0761', '\t\t', '상호정보', '(주)세코기술연구소', '경상남도 함안군 칠서면 회산리', '기계부속품제조']
# ['02-2634-7404', '\t\t', '상호정보', '(주)세창전기', '서울특별시 서초구 서초동', '건물분양(종합)']
# ['054-277-5667', '\t\t', '상호정보', '(주)세창알엔디', '경상북도 포항시 남구 대잠동', '부동산']
# ['054-632-1358', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-541-1411', '\t\t', '상호정보', '(주)세코닉스', '충청남도 아산시 신창면 수장리', '안경제조']
# ['041-532-9123', '\t\t', '상호정보', '(주)세프라', '충청남도 아산시 둔포면 산전리', '침대,가구제조']
# ['052-232-2338', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053
'\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-472-6790', '\t\t', '상호정보', '소리나무교육', '서울특별시 강동구 천호2동', '학습지']
# ['041-334-7475', '\t\t', '상호정보', '(주)소슬', '충청남도 예산군 예산읍 창소리', '인테리어']
# ['02-465-7975', '\t\t', '상호정보', '(주)소슬이앤드씨', '서울특별시 광진구 중곡동', '건설업(종합)']
# ['02-455-0466', '\t\t', '상호정보', '(주)손면', '서울특별시 광진구 광장동', '한식']
# ['070-4711-5211', '\t\t', '상호정보', '(주)소울디자인', '서울특별시 강남구 자곡동', '인테리어']
# ['033-241-5592', '\t\t', '상호정보', '(주)소양관광개발', '강원도 춘천시 북산면 청평리', '국내여객선터미널']
# ['02-3143-5826', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-918-7061', '\t\t', '상호정보', '소이어페럴(주)', '경기도 고양시 일산서구 주엽동', '아동복판매']
# ['02-585-1510', '\t\t', '상호정보', '(주)소호디자인', '서울특별시 서초구 서초동', '인테리어']
# ['02-564-0103', '\t\t', '상호정보', '(주)소정앤컴퍼니', '서울특별시 강남구 역삼1동', '부동산']
# ['02-2117-0531', '\t\t', '상호정보', '(주)소울랜드스케이프', '서울특별시 성동구 성수1가동', '조경공사']
# ['02-900-3362', '\t\t', '상호정보', '(주)손앤패밀리', '서울특별시 도봉구 창5동', '사무실임대']
# ['070-7728-5486', '\t\t', '상호정보', '(주)손정완', '경기도 부천시 중동', '여성의류']
# ['051-557-2800', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-586-8090', '\t\t', '상호정보', '(주)솔맥스', '서울특별시 서초구 서초동', '소프트웨어개발']
# ['02-427-7457', '\t\t', '상호정보', '(주)솔지원', '서울특별시 강동구 명일동', '건물분양(종합)']
# ['043-231-5665', '\t\t', '상호정보', '가구중개소', '충청북도 청주시 흥덕구 오송면 연제리', '가구판매(종합)']
# ['02-555-5008', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3667-7878', '\t\t', '상호정보', '(주)솔로젠', '서울특별시 금천구 가산동', '액세서리제조']
# ['02-2648-5689', '\t\t', '상호정보', '(주)솔토디앤씨', '서울특별시 양천구 신월5동', '부동산']
# ['051-852-0322', '\t\t', '상호정보', '(주)솔토', '부산광역시 연제구 연산5동', '관리사무소']
# ['031-704-5542', '\t\t', '상호정보', '(주)솜코리아', '경기도 성남시 분당구 서현1동', '숙박']
# ['032-831-5993', '\t\t', '상호정보', '(주)송도마트', '인천광역시 연수구 송도동', '슈퍼마켓']
# ['054-975-3242', '\t\t', '상호정보', '(주)송덕패키징', '경상북도 칠곡군 석적읍 중지리', '부동산']
# ['032-556-8272', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['052-250-4965', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-375-9400', '\t\t', '상호정보', '(주)송강', '전라남도 화순군 화순읍 교리', '찜질방']
# ['053-633-0103', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-293-4512', '\t\t', '상호정보', '(주)송문도시개발', '경상북도 포항시 남구 원리', '부동산']
# ['043-882-2361', '\t\t', '상호정보', '(주)송아퍼니처', '충청북도 음성군 감곡면 문촌리', '목재가구제조']
# ['042-586-5819', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-835-7112', '\t\t', '        \t검색결과가 없습니다.', '        ']
# 
'\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-324-8589', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 생림면 사촌리', '부동산']
# ['055-325-8249', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 주촌면 내삼리', '부동산']
# ['055-332-8589', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-326-8249', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 상동면 우계리', '부동산']
# ['055-321-8249', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 구산동', '부동산']
# ['055-329-8589', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 어방동', '부동산']
# ['055-332-8249', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-327-8589', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 외동', '부동산']
# ['055-338-8249', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 내동', '부동산']
# ['055-343-8589', '\t\t', '상호정보', '(주)수영파트너스', '경상남도 김해시 한림면 퇴래리', '부동산']
# ['043-643-2808', '\t\t', '상호정보', '(주)수이엔씨', '충청북도 제천시 화산동', '토목건설(종합)']
# ['02-3463-2371', '\t\t', '상호정보', '(주)수일개발', '서울특별시 강남구 도곡동', '의료기구제조']
# ['054-455-2215', '\t\t', '상호정보', '(주)수인터내셔날', '경상북도 구미시 송정동', '의류판매(종합)']
# ['051-503-0095', '\t\t', '상호정보', '(주)에스엔아이솔루션', '부산광역시 연제구 거제1동', '관리사무소']
# ['053-522-3991', '\t\t', '상호정보', '테크닉', '대구광역시 달서구 본리동', '모텔']
# ['031-968-5596', '\t\t', '상호정보', '원당PMC', '경기도 고양시 덕양구 성사동', '부동산']
# ['051-730-3432', '\t\t', '상호정보', '(주)수인터내셔날', '부산광역시 해운대구 우동', '의복,액세서리도매']
# ['032-327-5640', '\t\t', '상호정보', '(주)수웅', '경기도 부천시 원미구 상동', '관리사무소']
# ['032-327-5640', '\t\t', '상호정보', '(주)수웅', '경기도 부천시 원미구 상동', '관리사무소']
# ['032-327-5640', '\t\t', '상호정보', '(주)수웅', '경기도 부천시 원미구 상동', '관리사무소']
# ['041-549-0048', '\t\t', '상호정보', '(주)수정관리사무소', '충청남도 아산시 온천동', '부동산']
# ['032-424-6992', '\t\t', '상호정보', '(주)수정디앤씨', '인천광역시 남동구 간석1동', '벽지,장판']
# ['031-783-5799', '\t\t', '상호정보', '(주)수지기코리아', '경기도 성남시 분당구 서현1동', '스포츠웨어도매']
# ['02-333-2336', '\t\t', '상호정보', '(주)수지무역', '서울특별시 마포구 동교동', '부동산']
# ['032-472-7753', '\t\t', '상호정보', '(주)수정디앤씨', '인천광역시 남동구 만수6동', '벽지,장판']
# ['031-908-2334', '\t\t', '상호정보', '(주)수지무역', '경기도 고양시 일산동구 백석동', '부동산']
# ['02-786-3151', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-362-9545', '\t\t', '상호정보', '(주)수창상사', '서울특별시 마포구 아현동', '부동산']
# ['051-312-2631', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-941-2932', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['063-831-7336', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4189-5001', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-497-7004', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7169-2355', '\t\t', '공유정보', '베가 이벤트 운영사무국 입니다']
# ['02-2067-2343', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-726-0074', '\t\t', '상호정보', '(주)순천프뢰벨', '전라남도 순천시 연향동', '서적출판(종합)']
# ['053-313-1177', '\t\t', '상호정보', '(주)숭선', '대구광역시 북구 태전동', '부동산']
# ['055-265-5115', '\t\t', '상호정보', '(주)숙위홈', '경상남도 창원시 의창구 팔용동', '가구']
# ['051-516-3852', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-564-3311', '\t\t', '상호정보', '(주)순흥목재', '인천광역시 서구 오류동', '목재가구제조']
# ['032-937-8196', '\t\t', '상호정보', '(주)대승가구', '인천광역시 강화군 불은면 두운리', '침대,가구제조']
# ['043-645-4680', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-363-3625', '\t\t', '상호정보', '(주)숲속랜드', '서울특별시 서대문구 봉원동', '스포츠마사지']
# ['033-256-8801', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-583-2365', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-4710-8088', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-714-2552', '\t\t', '상호정보', '(주)씨투팩', '서울특별시 송파구 신천동', '광고기획']
# ['070-7707-8055', '\t\t', '상호정보', '(주)슈렉스코리아', '부산광역시 사상구 모라동', '안전용품판매']
# ['051-304-4141', '\t\t', '상호정보', '(주)슈데코', '부산광역시 사상구 모라1동', '신발제조(기타)']
# ['02-466-8282', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-658-2809', '\t\t', '상호정보', '(주)슈마커', '경기도 평택시 평택동', '스포츠웨어판매']
# ['051-941-4595', '\t\t', '상호정보', '(주)슈맥스', '부산광역시 강서구 대저1동', '신발제조(종합)']
# ['02-579-2841', '\t\t', '상호정보', '(주)슈텍', '서울특별시 강남구 개포동', '무역업(종합)']
# ['070-7773-5510', '\t\t', '상호정보', '(주)슈젠므', '경기도 안산시 상록구 사사동', '구두도매']
# ['031-230-7466', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-796-2658', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-507-4576', '\t\t', '상호정보', '(주)스노마드', '경기도 과천시 별양동', '부동산']
# ['031-752-2682', '\t\t', '상호정보', '(주)슈페리어', '경기도 성남시 중원구 성남동', '의류판매(종합)']
# ['051-316-8400', '\t\t', '상호정보', '대호우레탄', '부산광역시 사상구 주례1동', '우레탄제조,판매']
# ['061-274-1945', '\t\t', '상호정보', '홈마트연산', '전라남도 목포시 연산동', '슈퍼마켓']
# ['02-3397-3355', '\t\t', '공유정보', '슈페리어 광고 문자']
# ['053-795-9111', '\t\t', '상호정보', '(주)스마일관광', '대구광역시 수성구 사월동', '관광안내소']
# ['02-425-3373', '\t\t', '상호정보', '(주)스마일컴퍼니', '서울특별시 송파구 잠실동', '주방가구제조']
# ['02-406-0909', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-721-9949', '\t\t', '상호정보', '하나지게차', '대전광역시 서구 변동', '지게차']
# ['042-721-2223', '\t\t', '상호정보', '경동보일러', '대전광역시 서구 정림동', '보일러판매']
# ['042-861-2454', '\t\t', '상호정보', '(주)스마트시티단지내상가', '대전광역시 유성구 도룡동', '건물분양(종합)']
# ['02-2064-0700', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-338-8412', '\t\t', '상호정보', '(주)스마트카고서비스', '서울특별시 영등포구 양평동3가', '부동산']
# ['02-549-7001', '\t\t', '상호정보', '(주)스마트푸드디엠', '경기도 양주시 덕계동', '공학연구소']
# ['031-410-3436', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-535-7325', '\t\t', '상호정보', '(주)스맥동탄', '서울특별시 서초구 서초동', '정보통신기기수리']
# ['031-767-6464', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-219-9210', '\t\t', '상호정보', '(주)스와로브스키코리아', '충청북도 청주시 상당구 남문로1가', '귀금속,장신구제조(종합)']
# ['061-742-1237', '\t\t', '상호정보', '우나기', '전라남도 순천시 풍덕동', '한식']
# ['051-552-1544', '\t\t', '상호정보', '(주)스와로브스키코리아', '부산광역시 동래구 온천2동', '인테리어']
# ['02-861-2171', '\t\t', '상호정보', '(주)스웰', '서울특별시 구로구 구로5동', '가구']
# ['02-555-5152', '\t\t', '상호정보', '(주)스위스퍼펙션', '서울특별시 용산구 한남동', '화장품,향수']
# ['02-325-2522', '\t\t', '상호정보', '(주)스칸웰항운', '서울특별시 마포구 동교동', '부동산']
# ['063-289-3150', '\t\t', '상호정보', '(주)스와로브스키코리아', '전라북도 전주시 완산구 서신동', '잡화점']
# ['02-514-5979', '\t\t', '상호정보', '(주)스케이터코리아', '서울특별시 서초구 방배4동', '잡화점']
# ['02-6912-8888', '\t\t', '상호정보', '(주)스코노코리아', '서울특별시 구로구 구로3동', '신발제조(종합)']
# ['070-7758-2300', '\t\t', '상호정보', '(주)스타라인', '경기도 가평군 가평읍 금대리', '펜션']
# ['02-2246-8977', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-719-3418', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-551-7052', '\t\t', '상호정보', '(주)스타럭스', '서울특별시 강남구 삼성1동', '마구류제조(종합)']
# ['042-222-0600', '\t\t', '상호정보', '(주)스타라인', '대전광역시 동구 중동', '부동산']
# ['1688-5501', '\t\t', '상호정보', '(주)스타럭스', '가죽제품소매(기타)', '스팸이력', '안심등록 13건', '3개월 내 스팸신고 102건', '                \t', '텔레마케팅 57건', '기타유형스팸 31건', '불법게임, 도박 5건']
# ['031-217-3807', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2638-2636', '\t\t', '상호정보', '(주)스타럭스', '서울특별시 영등포구 영등포동4가', '액세서리판매']
# ['031-936-3520', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-551-7003', '\t\t', '상호정보', '(주)스타럭스', '서울특별시 강남구 삼성동', '마구류제조(종합)']
# ['051-730-3207', '\t\t', '상호정보', '(주)스타럭스구찌시계', '부산광역시 해운대구 우동', '시계,귀금속도매(종합)']
# ['02-551-7083', '\t\t', '상호정보', '(주)스타럭스', '서울특별시 강남구 삼성동', '액세서리판매']
# ['070-8853-0010', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-272-8888', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-452-7719', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7008-7770', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3442-1712', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2668-0042', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3442-1852', '\t\t', '상호정보', '(주)스타캐슬커뮤니케이션즈', '서울특별시 강남구 논현동', '연기학원']
# ['070-4135-1280', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-412-9559', '\t\t', '상호정보', '(주)엑스터디', '서울특별시 송파구 신천동', '장신구제조']
# ['02-463-6163', '\t\t', '상호정보', '(주)엑스터디', '서울특별시 성동구 성수2가동', '장신구제조']
# ['052-235-0627', '\t\t', '상호정보', '(주)스탑코리아', '울산광역시 동구 방어동', '아파트임대']
# ['070-8671-2025', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-957-3713', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-867-6488', '\t\t', '상호정보', '(주)스탠더드시험연구소', '대전광역시 유성구 장동', '공학연구소']
# ['070-8671-2304', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-3273-0133', '\t\t', '상호정보', '(주)알엔씨개발', '서울특별시 마포구 용강동', '부동산']
# ['02-2638-2668', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-253-1337', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-325-5953', '\t\t', '상호정보', '도토리식당', '서울특별시 마포구 상수동', '일식']
# ['02-586-8856', '\t\t', '상호정보', '스튜디오윤', '서울특별시 관악구 성현[봉천2/5동]동', '사진,스튜디오']
# ['02-565-2071', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-679-2962', '\t\t', '상호정보', '(주)스페스(SPESCO.LTD)', '경기도 부천시 삼정동', '액세서리소매(종합)']
# ['032-434-8082', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-851-6443', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2057-5775', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-354-0123', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['033-648-3800', '\t\t', '상호정보', '(주)스펙트럼통신기술', '강원도 강릉시 대전동', '정보통신기기수리']
# ['031-521-8737', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-572-9403', '\t\t', '상호정보', '(주)스피트옥션', '대구광역시 중구 동인동1가', '부동산']
# ['031-435-2550', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-553-7771', '\t\t', '상호정보', '(주)스피드이엔지', '대구광역시 달서구 본리동', '정보통신기기수리']
# ['031-706-1239', '\t\t', '상호정보', '(주)스포츠어빌리티', '경기도 성남시 분당구 서현동', '스포츠웨어도매']
# ['02-557-8866', '\t\t', '상호정보', '(주)승광실업', '서울특별시 강남구 삼성동', '주거용건물임대(종합)']
# ['033-644-7466', '\t\t', '상호정보', '(주)승산', '강원도 강릉시 안현동', '부동산']
# ['02-565-8494', '\t\t', '상호정보', '(주)광양불고기본가승달집', '서울특별시 강남구 대치동', '농산물공판장']
# ['031-378-9751', '\t\t', '상호정보', '(주)승세', '경기도 오산시 누읍동', '의류판매(종합)']
# ['02-878-2184', '\t\t', '상호정보', '(주)승연', '서울특별시 관악구 은천[봉천9/본동]동', '시장']
# ['051-301-2704', '\t\t', '상호정보', '(주)승일산업', '부산광역시 강서구 대저2동', '신발제조(종합)']
# ['043-646-3637', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['070-7720-3999', '\t\t', '상호정보', '(주)승인인터내셔널', '경기도 양주시 고암동', '잡화점']
# ['051-636-9071', '\t\t', '상호정보', '한성해수월드', '부산광역시 동구 범일1동', '목욕탕,사우나']
# ['051-747-8785', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-642-4501', '\t\t', '상호정보', '(주)승진', '충청북도 제천시 화산동', '중장비부품도매']
# ['042-256-6372', '\t\t', '상호정보', '대제개발(주)', '대전광역시 중구 선화동', '건물건설(종합)']
# ['051-532-8775', '\t\t', '상호정보', '(주)승학', '부산광역시 동래구 안락2동', '관리사무소']
# ['051-894-2851', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-896-6085', '\t\t', '상호정보', '(주)승현', '부산광역시 부산진구 개금2동', '부동산']
# ['031-925-2580', '\t\t', '상호정보', '(주)승형실업', '경기도 고양시 일산서구 탄현동', '부동산']
# ['052-267-4300', '\t\t', '상호정보', '(주)시그마알엠에스', '울산광역시 북구 명촌동', '건물분양(종합)']
# ['031-957-4845', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-586-6746', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-999-4911', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['054-782-2334', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-502-2155', '\t\t', '상호정보', '(주)시네마파티션', '인천광역시 강화군 불은면 신현리', '침대,가구제조']
# ['051-866-0399', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-552-5050', '\t\t', '상호정보', '(주)시대', '부산광역시 동래구 수안동', '인테리어']
# ['053-744-2024', '\t\t', '상호정보', '(주)시대', '대구광역시 수성구 범어3동', '부동산']
# ['02-502-2244', '\t\t', '상호정보', '(주)시대산업관리소', '경기도 과천시 별양동', '부동산']
# ['02-567-0010', '\t\t', '상호정보', '(주)시대디엔씨', '서울특별시 강남구 역삼동', '부동산']
# ['02-539-7089', '\t\t', '상호정보', '(주)시모나아이디', '서울특별시 강남구 역삼동', '건물분양(종합)']
# ['02-2253-7000', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-421-0898', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['041-522-0530', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-545-4041', '\t\t', '상호정보', '(주)시몬스', '서울특별시 강남구 논현동', '침대판매']
# ['02-569-4070', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['042-626-4071', '\t\t', '상호정보', '(주)시몬스', '대전광역시 동구 용전동', '침대도매']
# ['053-742-2820', '\t\t', '상호정보', '(주)시몬스', '대구광역시 수성구 범어2동', '침대판매']
# ['051-971-8588', '\t\t', '상호정보', '(주)시민부동산중개법인', '부산광역시 강서구 녹산동', '부동산']
# ['02-562-1117', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-922-9953', '\t\t', '상호정보', '(주)시사아이엔매거진', '경기도 고양시 일산서구 가좌동', '서적도매']
# ['02-597-6020', '\t\t', '상호정보', '(주)시선알디아이', '서울특별시 서초구 서초동', '부동산']
# ['02-584-0634', '\t\t', '상호정보', '(주)시선', '서울특별시 서초구 서초동', '부동산']
# ['02-558-3978', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-597-6024', '\t\t', '상호정보', '(주)시선산업개발', '서울특별시 서초구 서초동', '부동산']
# ['031-336-6506', '\t\t', '상호정보', '(주)시선인터내셔널', '경기도 용인시 처인구 봉명리', '의류판매(종합)']
# ['052-293-4034', '\t\t', '상호정보', '(주)시앤디', '울산광역시 북구 호계동', '척추교정치료']
# ['051-921-4242', '\t\t', '상호정보', '(주)시온산의영광', '부산광역시 금정구 구서동', '인테리어']
# ['02-3411-8851', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['052-260-4281', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['055-633-6286', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-586-1971', '\t\t', '상호정보', '(주)시앤디', '대구광역시 달서구 이곡동', '척추교정치료']
# ['031-248-4982', '\t\t', '상호정보', '(주)시온스포츠', '경기도 수원시 장안구 조원동', '스포츠웨어판매']
# ['02-783-1595', '\t\t', '상호정보', '(주)시스월드파워', '서울특별시 영등포구 여의도동', '소프트웨어개발']
# ['02-3448-4027', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-467-9731', '\t\t', '상호정보', '(주)시우', '인천광역시 남동구 만수1동', '정보통신기기수리']
# ['062-655-0868', '\t\t', '상호정보', '(주)시은', '광주광역시 서구 매월동', '부동산']
# ['051-746-5801', '\t\t', '상호정보', '(주)시윰', '부산광역시 해운대구 중1동', '실내장식품']
# ['043-211-2772', '\t\t', '상호정보', '(주)시작', '충청북도 청주시 서원구 사직동', '관리사무소']
# ['031-392-9610', '\t\t', '상호정보', '시호안경', '경기도 군포시 광정동', '안경원']
# ['070-4262-6928', '\t\t', '상호정보', '시장닷컴', '서울특별시 종로구 숭인동', '인터넷관련사업(기타)']
# ['02-3445-5230', '\t\t', '상호정보', '(주)시전', '서울특별시 강남구 신사동', '출장요리']
# ['02-522-3971', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-527-2526', '\t\t', '상호정보', '(주)시장슈퍼체인', '경기도 남양주시 진접읍 연평리', '주류도매(종합)']
# ['02-577-5577', '\t\t', '상호정보', '(주)시즌', '서울특별시 강남구 개포동', '건물분양(종합)']
# ['02-3662-4884', '\t\t', '상호정보', '(주)시호가양지펙스', '서울특별시 강서구 가양3동', '안경원']
# ['052-287-9060', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-486-3740', '\t\t', '상호정보', '(주)시호안산지펙스', '경기도 안산시 상록구 성포동', '콘택트렌즈제조']
# ['043-295-9101', '\t\t', '상호정보', '(주)시호청주지펙스', '충청북도 청주시 서원구 미평동', '안경원']
# ['070-8867-0181', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-337-2089', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-481-9874', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-8016-4060', '\t\t', '상호정보', '(주)신강', '경기도 성남시 수정구 창곡동', '건물분양(종합)']
# ['02-2635-6114', '\t\t', '상호정보', '(주)식의', '서울특별시 영등포구 양평동2가', '한식']
# ['02-3158-0214', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-373-2666', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-513-0472', '\t\t', '상호정보', '(주)신광에스엔알', '광주광역시 광산구 안청동', '관리사무소']
# ['031-411-4495', '\t\t', '상호정보', '(주)신광유통', '경기도 안산시 단원구 중앙[고잔2동]', '잡화점']
# ['055-256-2841', '\t\t', '상호정보', '(주)신광', '경상남도 창원시 마산회원구 양덕2동', '안경렌즈제조']
# ['02-376-2666', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-841-9007', '\t\t', '상호정보', '(주)신니개발', '충청북도 충주시 신니면 대화리', '골프장']
# ['02-3476-0110', '\t\t', '상호정보', '(주)신기양행', '서울특별시 구로구 구로동', '의약품소매(종합)']
# ['02-2193-6004', '\t\t', '상호정보', '(주)신대한관리', '서울특별시 강남구 역삼동', '관리사무소']
# ['054-821-8589', '\t\t', '상호정보', '(주)신덕연수원', '경상북도 안동시 임하면 신덕리', '부동산']
# ['02-507-6168', '\t\t', '상호정보', '(주)신대한관리', '경기도 과천시 별양동', '관리사무소']
# ['031-216-2345', '\t\t', '상호정보', '(주)신덕팜', '경기도 용인시 수지구 동천동', '의약품소매(종합)']
# ['053-954-8880', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-972-2213', '\t\t', '상호정보', '(주)신도시부동산중개', '경기도 고양시 덕양구 행신동', '부동산']
# ['053-633-7107', '\t\t', '상호정보', '(주)신도시산업개발', '대구광역시 달서구 월성1동', '부동산']
# ['061-791-6551', '\t\t', '상호정보', '(주)신도시프라임캐슬', '전라남도 광양시 중동', '부동산']
# ['02-913-5149', '\t\t', '상호정보', '(주)신동방석유', '서울특별시 성북구 장위1동', '주유소']
# ['031-790-1670', '\t\t', '상호정보', '(주)신동양', '경기도 하남시 덕풍동', '경보기']
# ['02-928-1491', '\t\t', '상호정보', '(주)신동화', '서울특별시 동대문구 신설동', '사무실임대']
# ['054-772-3992', '\t\t', '상호정보', '(주)신라', '경상북도 경주시 황남동', '부동산']
# ['041-574-0093', '\t\t', '상호정보', '(주)신동해홀딩스', '충청남도 천안시 서북구 성정1동', '부동산']
# ['02-3471-9657', '\t\t', '상호정보', '(주)신동진', '서울특별시 서초구 방배동', '주거용건물임대(종합)']
# ['043-297-1408', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6713-8211', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6713-8227', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-412-3205', '\t\t', '상호정보', '(주)신라인코리아', '서울특별시 송파구 방이동', '가방제조']
# ['02-6713-8366', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6713-8330', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6713-8388', '\t\t', '상호정보', '량인력개발', '서울특별시 강남구 역삼동', '고용알선(종합)']
# ['02-6713-8272', '\t\t', '상호정보', '(주)탑항공여행사', '서울특별시 강남구 논현동', '여행사']
# ['02-6713-8311', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6713-8806', '\t\t', '상호정보', '호박플라워', '서울특별시 강동구 상일동', '꽃집,꽃배달']
# ['02-6713-8816', '\t\t', '스팸이력', '3개월 내 스팸신고 137건', '                \t', '불법게임, 도박 84건', '텔레마케팅 35건', '기타유형스팸 12건', '공유정보', '스포츠토토', '스포츠토토홍보', '스포츠토토 ', '공유정보 키워드', '스포츠토토']
# ['02-6927-8008', '\t\t', '상호정보', '고려신용정보(주)', '서울특별시 강남구 삼성동', '신용조사업']
# ['02-6927-8020', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-6713-8827', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-778-8580', '\t\t', '상호정보', '스마트워커직장인력개발(하남지점)', '경기도 하남시 망월동', '고용알선(종합)']
# ['02-6927-8777', '\t\t', '상호정보', '이안노동법률사무소', '서울특별시 송파구 방이동', '공인노무사']
# ['02-6927-8060', '\t\t', '상호정보', '아이티모드컴퓨터학원', '경기도 광명시 소하동', '컴퓨터학원']
# ['02-6956-5533', '\t\t', '상호정보', '알프스먹는샘물', '서울특별시 서대문구 대현동', '생수']
# ['02-6927-8799', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['032-710-8578', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-895-5772', '\t\t', '상호정보', '창준미니중기', '경기도 용인시 수지구 풍덕천동', '미니중기대여']
# ['02-555-2223', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-951-5960', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['043-882-9236', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-374-1053', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-428-7655', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-376-1281', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-839-3151', '\t\t', '상호정보', '(주)신산디엔아이', '서울특별시 구로구 구로동', '부동산']
# ['054-777-1888', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['053-811-5502', '\t\t', '상호정보', '(주)신생활화장품피부과학연구소', '경상북도 경산시 삼풍동', '화장품제조']
# ['042-544-5257', '\t\t', '상호정보', '(주)신선', '대전광역시 서구 관저동', '사무실임대']
# ['043-833-6619', '\t\t', '상호정보', '(주)신선촌', '충청북도 괴산군 연풍면 삼풍리', '콩나물재배']
# ['051-206-8900', '\t\t', '상호정보', '(주)신성', '부산광역시 사하구 신평1동', '관리사무소']
# ['041-666-0617', '\t\t', '상호정보', '(주)신성', '충청남도 서산시 동문동', '주거용건물임대(종합)']
# ['051-759-1133', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-371-1297', '\t\t', '상호정보', '(주)신성기공', '전라남도 화순군 동면 운농리', '금속가구제조']
# ['061-811-0360', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-810-5110', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-710-5330', '\t\t', '상호정보', '한마음모터스(유한)', '광주광역시 서구 매월동', '중고자동차판매']
# ['062-710-5750', '\t\t', '상호정보', '스카이라이프유선방송가입설치', '광주광역시 광산구 신창동', '유선방송']
# ['062-710-5410', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-710-5790', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-753-0021', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['062-710-5780', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2665-6189', '\t\t', '상호정보', '(주)신성비엠씨', '서울특별시 강서구 공항동', '관리사무소']
# ['02-522-3329', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-2663-3055', '\t\t', '상호정보', '(주)신성비엠씨', '서울특별시 강서구 공항동', '관리사무소']
# ['02-943-0244', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-435-1600', '\t\t', '상호정보', '(주)신성아이앤디', '경기도 시흥시 월곶동', '건물분양(종합)']
# ['041-622-9937', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-358-8459', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['051-304-9301', '\t\t', '상호정보', '(주)신성켐텍', '부산광역시 사상구 모라1동', '신발제조(종합)']
# ['051-304-9300', '\t\t', '상호정보', '(주)신성켐택', '부산광역시 사상구 모라1동', '신발제조(종합)']
# ['031-911-4763', '\t\t', '상호정보', '(주)신성티엠', '경기도 고양시 일산서구 대화동', '관리사무소']
# ['02-3448-5305', '\t\t', '상호정보', '(주)신세계개발', '서울특별시 강남구 논현동', '호텔']
# ['062-529-7799', '\t\t', '상호정보', '(주)신성플래닝', '광주광역시 동구 계림동', '부동산']
# ['055-582-7400', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-677-5833', '\t\t', '상호정보', '(주)신세계관광항공여행사', '경기도 안성시 봉남동', '여행사']
# ['02-2185-1234', '\t\t', '상호정보', '(주)신세계사이먼', '서울특별시 강남구 청담동', '부동산']
# ['051-742-0021', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-862-7253', '\t\t', '상호정보', '(주)신세계에스브이엔', '서울특별시 구로구 구로5동', '제과점']
# ['02-900-5414', '\t\t', '상호정보', '(주)신세계에스브이엔', '서울특별시 도봉구 쌍문동', '제과점']
# ['063-631-8142', '\t\t', '상호정보', '(주)신세계에스브이엔', '전라북도 남원시 왕정동', '제과점']
# ['054-857-8067', '\t\t', '상호정보', '(주)신세계인터내셔날', '경상북도 안동시 옥동', '의류판매(종합)']
# ['031-207-1291', '\t\t', '상호정보', '(주)신세계인터내셔날', '경기도 수원시 권선구 권선동', '의류판매(종합)']
# ['051-816-9419', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-925-9082', '\t\t', '상호정보', '(주)신세계인터내셔날', '경기도 고양시 일산서구 덕이동', '의류판매(종합)']
# ['02-2155-1399', '\t\t', '상호정보', '(주)신세계인터내셔날', '서울특별시 서초구 양재동', '의류판매(종합)']
# ['031-237-4301', '\t\t', '상호정보', '(주)신세계인터내셔널FCN', '경기도 수원시 팔달구 인계동', '의류판매(종합)']
# ['02-3147-1191', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-507-1194', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['02-552-0061', '\t\t', '상호정보', '(주)신세계푸드', '서울특별시 강남구 역삼동', '패스트푸드(기타)']
# ['054-462-1143', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['061-375-6400', '\t\t', '        \t검색결과가 없습니다.', '        ']
# ['031-902-7480', '\t\t', '상호정보', '(주)신세기시스템', '경기도 고양시 덕양구 행신동', '관리사무소']
# ['031-336-0721', '\t\t', '상호정보', '(주)신신물산', '경기도 용인시 처인구 봉명리', '의류판매(종합)']
# ['055-292-8390', '\t\t', '상호정보', '(주)신신', '경상남도 창원시 의창구 소답동', '부동산']
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <timed exec> in <module>()
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     357             element = driver.find_element_by_id('foo')
#     358         """
# --> 359         return self.find_element(by=By.ID, value=id_)
#     360
#     361     def find_elements_by_id(self, id_):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# C:\anaconda\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"id","selector":"search"}
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 6.1.7601 SP1 x86_64)

# %%
len(result2)
# Out:
# 839

# %%
import pandas as pd
from sqlalchemy import create_engine
from selenium import webdriver
from selenium.webdriver.support.select import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import time
from selenium.webdriver.common import action_chains, keys
import selenium
import json
from urllib.request import urlopen

# %%
test = pd.read_pickle('company_test.pkl')
test = test[40001:50000]

# %%
# %%time
result = []
count = 0
for phone_num in test['REP_PHONE_NUM']:
    if count % 100 == 0:
        print('running...', phone_num, count / 100)
        time.sleep(2)
    html = """https://114search.114.co.kr/NextenGateway/general/info/?areaCode=0201002086000&latitude=37.4890604237&longitude=126.9924828985&type=A&query={}&originalQuery={}&address=%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C+%EC%84%9C%EC%B4%88%EA%B5%AC+%EB%B0%A9%EB%B0%B04%EB%8F%99&poiLatitude=&poiLongitude=&sortType=D&radius=-1&size=5&page=1""".format(phone_num,phone_num)
    
    data = urlopen(html, timeout = 20)
    resp = json.loads(data.read())
    r = pd.DataFrame(resp)
    r = pd.DataFrame(r['data'][0])
    if r['results']['totalCount'] == 0:
        info = []
        info.append(phone_num)
        info.append('')
        info.append('')
        info.append('')
        info.append('')
        info.append('')
        continue
    else:
        r = pd.DataFrame(r['results']['result'])
        r = pd.DataFrame(r['field'][0])
        info = []
        info.append(r['value'][1])
        info.append(r['value'][2])
        info.append(r['value'][3])
        info.append(r['value'][7])
        info.append(r['value'][8])
        info.append(r['value'][9])
        result.append(info)
    count+=1
# Out:
# running... 0513255667 0.0
# running... 07046677227 0.0
# running... 0313857717 0.0
# running... 0617234149 0.0
# running... 0617224149 0.0
# running... 0335210676 0.0
# running... 0323309944 1.0
# running... 01027671471 1.0
# running... 0519022848 1.0
# running... 0216979463 1.0
# running... 0220682078 1.0
# running... 0327779983 1.0
# running... 0535840037 1.0
# running... 16612057 1.0
# running... 0262122468 1.0
# running... 0436518373 1.0
# running... 0315267300 2.0
# running... 0316420600 3.0
# running... 0332628701 4.0
# running... 0317989500 5.0
# running... 0315951324 6.0
# running... 028583700 6.0
# running... 0415653008 6.0
# running... 07073855476 7.0
# running... 0553882789 8.0
# running... 0319072813 9.0
# running... 025166865 10.0
# running... 0432367676 10.0
# running... 0234827799 11.0
# running... 0617512004 11.0
# running... 0547418611 12.0
# running... 0267133696 13.0
# running... 0267133996 13.0
# running... 0267134298 13.0
# running... 0267134096 13.0
# running... 0267136791 13.0
# running... 0267136009 13.0
# running... 0267139010 13.0
# running... 0267138092 13.0
# running... 0269270027 13.0
# running... 0269330121 13.0
# running... 0269330199 13.0
# running... 0552887590 14.0
# running... 0336359001 15.0
# running... 0539630770 16.0
# running... 01064551713 16.0
# running... 0415230014 16.0
# running... 0617913800 17.0
# running... 0617226100 18.0
# running... 0535931480 19.0
# running... 0222934171 19.0
# running... 0522260800 20.0
# running... 0313834200 21.0
# running... 0547776612 22.0
# running... 024551500 23.0
# running... 0544767666 24.0
# running... 0543716636 24.0
# running... 0556385560 25.0
# running... 0226182411 26.0
# running... 0422260664 26.0
# running... 07075644438 27.0
# running... 0512431236 27.0
# running... 07082821137 27.0
# running... 0522372615 27.0
# running... 024628141 27.0
# running... 0616511052 27.0
# running... 16889711 27.0
# running... 0555425544 27.0
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\anaconda\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\anaconda\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# C:\anaconda\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# C:\anaconda\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <timed exec> in <module>()
#
# C:\anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\anaconda\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\anaconda\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# C:\anaconda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error timed out>
